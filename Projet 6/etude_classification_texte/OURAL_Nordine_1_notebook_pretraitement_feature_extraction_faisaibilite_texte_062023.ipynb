# %%
# !pip install wordcloud
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: wordcloud in /home/jupyter/.local/lib/python3.8/site-packages (1.9.2)
# Requirement already satisfied: numpy>=1.6.1 in /usr/local/lib/python3.8/dist-packages (from wordcloud) (1.23.5)
# Requirement already satisfied: pillow in /home/jupyter/.local/lib/python3.8/site-packages (from wordcloud) (9.5.0)
# Requirement already satisfied: matplotlib in /home/jupyter/.local/lib/python3.8/site-packages (from wordcloud) (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in /home/jupyter/.local/lib/python3.8/site-packages (from matplotlib->wordcloud) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in /home/jupyter/.local/lib/python3.8/site-packages (from matplotlib->wordcloud) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /home/jupyter/.local/lib/python3.8/site-packages (from matplotlib->wordcloud) (4.39.4)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/jupyter/.local/lib/python3.8/site-packages (from matplotlib->wordcloud) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.8/dist-packages (from matplotlib->wordcloud) (23.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/jupyter/.local/lib/python3.8/site-packages (from matplotlib->wordcloud) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /home/jupyter/.local/lib/python3.8/site-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: importlib-resources>=3.2.0 in /home/jupyter/.local/lib/python3.8/site-packages (from matplotlib->wordcloud) (5.12.0)
# Requirement already satisfied: zipp>=3.1.0 in /usr/local/lib/python3.8/dist-packages (from importlib-resources>=3.2.0->matplotlib->wordcloud) (3.15.0)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.14.0)

# %%
# !pip install nltk
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: nltk in /home/jupyter/.local/lib/python3.8/site-packages (3.8.1)
# Requirement already satisfied: click in /home/jupyter/.local/lib/python3.8/site-packages (from nltk) (8.1.3)
# Requirement already satisfied: joblib in /home/jupyter/.local/lib/python3.8/site-packages (from nltk) (1.2.0)
# Requirement already satisfied: regex>=2021.8.3 in /home/jupyter/.local/lib/python3.8/site-packages (from nltk) (2023.5.5)
# Requirement already satisfied: tqdm in /home/jupyter/.local/lib/python3.8/site-packages (from nltk) (4.65.0)

# %%
# !pip install fastparquet
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: fastparquet in /home/jupyter/.local/lib/python3.8/site-packages (2023.4.0)
# Requirement already satisfied: pandas>=1.5.0 in /home/jupyter/.local/lib/python3.8/site-packages (from fastparquet) (2.0.1)
# Requirement already satisfied: numpy>=1.20.3 in /usr/local/lib/python3.8/dist-packages (from fastparquet) (1.23.5)
# Requirement already satisfied: cramjam>=2.3 in /home/jupyter/.local/lib/python3.8/site-packages (from fastparquet) (2.6.2)
# Requirement already satisfied: fsspec in /home/jupyter/.local/lib/python3.8/site-packages (from fastparquet) (2023.5.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.8/dist-packages (from fastparquet) (23.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/jupyter/.local/lib/python3.8/site-packages (from pandas>=1.5.0->fastparquet) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/jupyter/.local/lib/python3.8/site-packages (from pandas>=1.5.0->fastparquet) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in /home/jupyter/.local/lib/python3.8/site-packages (from pandas>=1.5.0->fastparquet) (2023.3)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.8.2->pandas>=1.5.0->fastparquet) (1.14.0)

# %%
# !pip install gensim
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: gensim in /home/jupyter/.local/lib/python3.8/site-packages (4.3.1)
# Requirement already satisfied: numpy>=1.18.5 in /usr/local/lib/python3.8/dist-packages (from gensim) (1.23.5)
# Requirement already satisfied: scipy>=1.7.0 in /usr/local/lib/python3.8/dist-packages (from gensim) (1.10.1)
# Requirement already satisfied: smart-open>=1.8.1 in /home/jupyter/.local/lib/python3.8/site-packages (from gensim) (6.3.0)

# %%
# !pip install --upgrade tensorflow_hub
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: tensorflow_hub in /home/jupyter/.local/lib/python3.8/site-packages (0.13.0)
# Requirement already satisfied: numpy>=1.12.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow_hub) (1.23.5)
# Requirement already satisfied: protobuf>=3.19.6 in /usr/local/lib/python3.8/dist-packages (from tensorflow_hub) (4.22.1)

# %%
# !pip install tensorflow-text
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: tensorflow-text in /home/jupyter/.local/lib/python3.8/site-packages (2.12.1)
# Requirement already satisfied: tensorflow-hub>=0.8.0 in /home/jupyter/.local/lib/python3.8/site-packages (from tensorflow-text) (0.13.0)
# Requirement already satisfied: tensorflow<2.13,>=2.12.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow-text) (2.12.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow<2.13,>=2.12.0->tensorflow-text) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow<2.13,>=2.12.0->tensorflow-text) (1.6.3)
# Requirement already satisfied: flatbuffers>=2.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow<2.13,>=2.12.0->tensorflow-text) (23.3.3)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /usr/local/lib/python3.8/dist-packages (from tensorflow<2.13,>=2.12.0->tensorflow-text) (0.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.8/dist-packages (from tensorflow<2.13,>=2.12.0->tensorflow-text) (0.2.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.8/dist-packages (from tensorflow<2.13,>=2.12.0->tensorflow-text) (1.51.3)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow<2.13,>=2.12.0->tensorflow-text) (3.8.0)
# Requirement already satisfied: jax>=0.3.15 in /usr/local/lib/python3.8/dist-packages (from tensorflow<2.13,>=2.12.0->tensorflow-text) (0.4.6)
# Requirement already satisfied: keras<2.13,>=2.12.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow<2.13,>=2.12.0->tensorflow-text) (2.12.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow<2.13,>=2.12.0->tensorflow-text) (16.0.0)
# Requirement already satisfied: numpy<1.24,>=1.22 in /usr/local/lib/python3.8/dist-packages (from tensorflow<2.13,>=2.12.0->tensorflow-text) (1.23.5)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.8/dist-packages (from tensorflow<2.13,>=2.12.0->tensorflow-text) (3.3.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.8/dist-packages (from tensorflow<2.13,>=2.12.0->tensorflow-text) (23.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.8/dist-packages (from tensorflow<2.13,>=2.12.0->tensorflow-text) (4.22.1)
# Requirement already satisfied: setuptools in /home/jupyter/.local/lib/python3.8/site-packages (from tensorflow<2.13,>=2.12.0->tensorflow-text) (67.7.2)
# Requirement already satisfied: six>=1.12.0 in /usr/lib/python3/dist-packages (from tensorflow<2.13,>=2.12.0->tensorflow-text) (1.14.0)
# Requirement already satisfied: tensorboard<2.13,>=2.12 in /usr/local/lib/python3.8/dist-packages (from tensorflow<2.13,>=2.12.0->tensorflow-text) (2.12.0)
# Requirement already satisfied: tensorflow-estimator<2.13,>=2.12.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow<2.13,>=2.12.0->tensorflow-text) (2.12.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow<2.13,>=2.12.0->tensorflow-text) (2.2.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.8/dist-packages (from tensorflow<2.13,>=2.12.0->tensorflow-text) (4.5.0)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow<2.13,>=2.12.0->tensorflow-text) (1.14.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.8/dist-packages (from tensorflow<2.13,>=2.12.0->tensorflow-text) (0.31.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.8/dist-packages (from astunparse>=1.6.0->tensorflow<2.13,>=2.12.0->tensorflow-text) (0.40.0)
# Requirement already satisfied: scipy>=1.5 in /usr/local/lib/python3.8/dist-packages (from jax>=0.3.15->tensorflow<2.13,>=2.12.0->tensorflow-text) (1.10.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.8/dist-packages (from tensorboard<2.13,>=2.12->tensorflow<2.13,>=2.12.0->tensorflow-text) (2.16.2)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.8/dist-packages (from tensorboard<2.13,>=2.12->tensorflow<2.13,>=2.12.0->tensorflow-text) (0.4.6)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.8/dist-packages (from tensorboard<2.13,>=2.12->tensorflow<2.13,>=2.12.0->tensorflow-text) (3.4.3)
# Requirement already satisfied: requests<3,>=2.21.0 in /home/jupyter/.local/lib/python3.8/site-packages (from tensorboard<2.13,>=2.12->tensorflow<2.13,>=2.12.0->tensorflow-text) (2.30.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.8/dist-packages (from tensorboard<2.13,>=2.12->tensorflow<2.13,>=2.12.0->tensorflow-text) (0.7.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.8/dist-packages (from tensorboard<2.13,>=2.12->tensorflow<2.13,>=2.12.0->tensorflow-text) (1.8.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.8/dist-packages (from tensorboard<2.13,>=2.12->tensorflow<2.13,>=2.12.0->tensorflow-text) (2.2.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow<2.13,>=2.12.0->tensorflow-text) (5.3.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.8/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow<2.13,>=2.12.0->tensorflow-text) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.8/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow<2.13,>=2.12.0->tensorflow-text) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.8/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.13,>=2.12->tensorflow<2.13,>=2.12.0->tensorflow-text) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.8/dist-packages (from markdown>=2.6.8->tensorboard<2.13,>=2.12->tensorflow<2.13,>=2.12.0->tensorflow-text) (6.1.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/jupyter/.local/lib/python3.8/site-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow<2.13,>=2.12.0->tensorflow-text) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/lib/python3/dist-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow<2.13,>=2.12.0->tensorflow-text) (2.8)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/lib/python3/dist-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow<2.13,>=2.12.0->tensorflow-text) (1.25.8)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/lib/python3/dist-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow<2.13,>=2.12.0->tensorflow-text) (2019.11.28)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.8/dist-packages (from werkzeug>=1.0.1->tensorboard<2.13,>=2.12->tensorflow<2.13,>=2.12.0->tensorflow-text) (2.1.2)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.8/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.13,>=2.12->tensorflow<2.13,>=2.12.0->tensorflow-text) (3.15.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.8/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow<2.13,>=2.12.0->tensorflow-text) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.8/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.13,>=2.12->tensorflow<2.13,>=2.12.0->tensorflow-text) (3.2.2)

# %%
import pandas as pd
import numpy as np
import plotly.express as px
from plotly.subplots import make_subplots
import plotly.graph_objects as go
import plotly.io as pio
import math
import scipy.stats as stats
import nltk
import string
from nltk.stem import WordNetLemmatizer, PorterStemmer
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords, wordnet
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.preprocessing import StandardScaler, MinMaxScaler

import zipfile
import os, sys
import requests

from collections import defaultdict
from wordcloud import WordCloud
import matplotlib.pyplot as plt
import matplotlib.font_manager

from sklearn.decomposition import PCA
from sklearn.decomposition import LatentDirichletAllocation
from sklearn.manifold import TSNE
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.metrics import silhouette_score
from sklearn.cluster import KMeans
from sklearn.metrics import adjusted_rand_score,confusion_matrix,classification_report

from yellowbrick.cluster import SilhouetteVisualizer

import gensim
from gensim.models import Word2Vec

import tensorflow as tf
import tensorflow_text as tf_text

module_path = os.path.abspath(os.path.join(".."))
if module_path not in sys.path:
    sys.path.append(module_path)
from lib.graphUtils import (
    show_pie,
    show_lines,
    show_pca_variance_graph,
    show_pca_correlation_graph,
    show_scatter_graph,
    show_cols_boxplots_by_col,
    view_clustered_heatmap,
)
pio.renderers.default = "iframe"

import matplotlib.pyplot as plt
import seaborn as sns

working_dir = "working"
if not os.path.isdir(working_dir):
    os.mkdir(working_dir)
    
import tensorflow_hub as hub
# Out:
# 2023-05-26 14:44:24.075129: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# # Récupération des données

# %%
if not os.path.isdir("assets"):
    os.mkdir("assets")

if not os.path.isfile('assets/data1.zip'):
    url = 'https://s3-eu-west-1.amazonaws.com/static.oc-static.com/prod/courses/files/Parcours_data_scientist/Projet+-+Textimage+DAS+V2/Dataset+projet+pre%CC%81traitement+textes+images.zip'
    r = requests.get(url, allow_redirects=True)
    open('assets/data1.zip', 'wb').write(r.content)

# %%
import zipfile
with zipfile.ZipFile('assets/data1.zip', 'r') as zip_ref:
    zip_ref.extractall('assets')

# %% [markdown]
# # Chargement des données dans un Dataframe

# %%
df = pd.read_csv("assets/Flipkart/flipkart_com-ecommerce_sample_1050.csv")

# %%
df.head()
# Out:
#                             uniq_id            crawl_timestamp
# 0  55b85ea15a1536d46b7190ad6fff8ce7  2016-04-30 03:22:56 +0000  \
# 1  7b72c92c2f6c40268628ec5f14c6d590  2016-04-30 03:22:56 +0000
# 2  64d5d4a258243731dc7bbb1eef49ad74  2016-04-30 03:22:56 +0000
# 3  d4684dcdc759dd9cdf41504698d737d8  2016-06-20 08:49:52 +0000
# 4  6325b6870c54cd47be6ebfbffa620ec7  2016-06-20 08:49:52 +0000
#
#                                          product_url
# 0  http://www.flipkart.com/elegance-polyester-mul...  \
# 1  http://www.flipkart.com/sathiyas-cotton-bath-t...
# 2  http://www.flipkart.com/eurospa-cotton-terry-f...
# 3  http://www.flipkart.com/santosh-royal-fashion-...
# 4  http://www.flipkart.com/jaipur-print-cotton-fl...
#
#                                         product_name
# 0  Elegance Polyester Multicolor Abstract Eyelet ...  \
# 1                         Sathiyas Cotton Bath Towel
# 2                Eurospa Cotton Terry Face Towel Set
# 3  SANTOSH ROYAL FASHION Cotton Printed King size...
# 4  Jaipur Print Cotton Floral King sized Double B...
#
#                                product_category_tree               pid
# 0  ["Home Furnishing >> Curtains & Accessories >>...  CRNEG7BKMFFYHQ8Z  \
# 1  ["Baby Care >> Baby Bath & Skin >> Baby Bath T...  BTWEGFZHGBXPHZUH
# 2  ["Baby Care >> Baby Bath & Skin >> Baby Bath T...  BTWEG6SHXTDB2A2Y
# 3  ["Home Furnishing >> Bed Linen >> Bedsheets >>...  BDSEJT9UQWHDUBH4
# 4  ["Home Furnishing >> Bed Linen >> Bedsheets >>...  BDSEJTHNGWVGWWQU
#
#    retail_price  discounted_price                                 image
# 0        1899.0             899.0  55b85ea15a1536d46b7190ad6fff8ce7.jpg  \
# 1         600.0             449.0  7b72c92c2f6c40268628ec5f14c6d590.jpg
# 2           NaN               NaN  64d5d4a258243731dc7bbb1eef49ad74.jpg
# 3        2699.0            1299.0  d4684dcdc759dd9cdf41504698d737d8.jpg
# 4        2599.0             698.0  6325b6870c54cd47be6ebfbffa620ec7.jpg
#
#    is_FK_Advantage_product                                        description
# 0                    False  Key Features of Elegance Polyester Multicolor ...  \
# 1                    False  Specifications of Sathiyas Cotton Bath Towel (...
# 2                    False  Key Features of Eurospa Cotton Terry Face Towe...
# 3                    False  Key Features of SANTOSH ROYAL FASHION Cotton P...
# 4                    False  Key Features of Jaipur Print Cotton Floral Kin...
#
#         product_rating       overall_rating                  brand
# 0  No rating available  No rating available               Elegance  \
# 1  No rating available  No rating available               Sathiyas
# 2  No rating available  No rating available                Eurospa
# 3  No rating available  No rating available  SANTOSH ROYAL FASHION
# 4  No rating available  No rating available           Jaipur Print
#
#                               product_specifications
# 0  {"product_specification"=>[{"key"=>"Brand", "v...
# 1  {"product_specification"=>[{"key"=>"Machine Wa...
# 2  {"product_specification"=>[{"key"=>"Material",...
# 3  {"product_specification"=>[{"key"=>"Brand", "v...
# 4  {"product_specification"=>[{"key"=>"Machine Wa...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1050 entries, 0 to 1049
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   uniq_id                  1050 non-null   object
#  1   crawl_timestamp          1050 non-null   object
#  2   product_url              1050 non-null   object
#  3   product_name             1050 non-null   object
#  4   product_category_tree    1050 non-null   object
#  5   pid                      1050 non-null   object
#  6   retail_price             1049 non-null   float64
#  7   discounted_price         1049 non-null   float64
#  8   image                    1050 non-null   object
#  9   is_FK_Advantage_product  1050 non-null   bool
#  10  description              1050 non-null   object
#  11  product_rating           1050 non-null   object
#  12  overall_rating           1050 non-null   object
#  13  brand                    712 non-null    object
#  14  product_specifications   1049 non-null   object
# dtypes: bool(1), float64(2), object(12)
# memory usage: 116.0+ KB

# %%
df.describe(include='all')
# Out:
#                                  uniq_id            crawl_timestamp
# count                               1050                       1050  \
# unique                              1050                        149
# top     55b85ea15a1536d46b7190ad6fff8ce7  2015-12-01 12:40:44 +0000
# freq                                   1                        150
# mean                                 NaN                        NaN
# std                                  NaN                        NaN
# min                                  NaN                        NaN
# 25%                                  NaN                        NaN
# 50%                                  NaN                        NaN
# 75%                                  NaN                        NaN
# max                                  NaN                        NaN
#
#                                               product_url
# count                                                1050  \
# unique                                               1050
# top     http://www.flipkart.com/elegance-polyester-mul...
# freq                                                    1
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                                              product_name
# count                                                1050  \
# unique                                               1050
# top     Elegance Polyester Multicolor Abstract Eyelet ...
# freq                                                    1
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                                     product_category_tree               pid
# count                                                1050              1050  \
# unique                                                642              1050
# top     ["Home Furnishing >> Bed Linen >> Blankets, Qu...  CRNEG7BKMFFYHQ8Z
# freq                                                   56                 1
# mean                                                  NaN               NaN
# std                                                   NaN               NaN
# min                                                   NaN               NaN
# 25%                                                   NaN               NaN
# 50%                                                   NaN               NaN
# 75%                                                   NaN               NaN
# max                                                   NaN               NaN
#
#          retail_price  discounted_price                                 image
# count     1049.000000       1049.000000                                  1050  \
# unique            NaN               NaN                                  1050
# top               NaN               NaN  55b85ea15a1536d46b7190ad6fff8ce7.jpg
# freq              NaN               NaN                                     1
# mean      2186.197331       1584.527169                                   NaN
# std       7639.229411       7475.099680                                   NaN
# min         35.000000         35.000000                                   NaN
# 25%        555.000000        340.000000                                   NaN
# 50%        999.000000        600.000000                                   NaN
# 75%       1999.000000       1199.000000                                   NaN
# max     201000.000000     201000.000000                                   NaN
#
#        is_FK_Advantage_product
# count                     1050  \
# unique                       2
# top                      False
# freq                       993
# mean                       NaN
# std                        NaN
# min                        NaN
# 25%                        NaN
# 50%                        NaN
# 75%                        NaN
# max                        NaN
#
#                                               description
# count                                                1050  \
# unique                                               1050
# top     Key Features of Elegance Polyester Multicolor ...
# freq                                                    1
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#              product_rating       overall_rating         brand
# count                  1050                 1050           712  \
# unique                   27                   27           490
# top     No rating available  No rating available  PRINT SHAPES
# freq                    889                  889            11
# mean                    NaN                  NaN           NaN
# std                     NaN                  NaN           NaN
# min                     NaN                  NaN           NaN
# 25%                     NaN                  NaN           NaN
# 50%                     NaN                  NaN           NaN
# 75%                     NaN                  NaN           NaN
# max                     NaN                  NaN           NaN
#
#                                    product_specifications
# count                                                1049
# unique                                                984
# top     {"product_specification"=>[{"key"=>"Type", "va...
# freq                                                   22
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN

# %% [markdown]
# Ici, nous allons travailler sur les features:
# - product_name
# - description
# - product_category_tree

# %%
df["product_category_tree"].unique().shape
# Out:
# (642,)

# %% [markdown]
# Nous avons 642 catégories pour 1050 produits. Nous allons retenir le 1er niveau.

# %%
all_cats = []
for cat in df["product_category_tree"].unique():
    #print(cat)
    cat = cat.strip()[2:-2]
    cat = cat.split(">>")
    #print(cat)
    all_cats.append(cat[0].strip().lower())
    #print(all_cats)
    #1/0
all_cats = set(all_cats)
print(len(all_cats))
# Out:
# 7

# %%
all_cats
# Out:
# {'baby care',
#  'beauty and personal care',
#  'computers',
#  'home decor & festive needs',
#  'home furnishing',
#  'kitchen & dining',
#  'watches'}

# %%
def get_category_level_0(x):
    c = x["product_category_tree"].strip()[2:-2]
    c = c.split(">>")
    return c[0].strip().lower()

df["category0"] = df.apply(lambda x: get_category_level_0(x), axis=1)

# %%
df.head()
# Out:
#                             uniq_id            crawl_timestamp
# 0  55b85ea15a1536d46b7190ad6fff8ce7  2016-04-30 03:22:56 +0000  \
# 1  7b72c92c2f6c40268628ec5f14c6d590  2016-04-30 03:22:56 +0000
# 2  64d5d4a258243731dc7bbb1eef49ad74  2016-04-30 03:22:56 +0000
# 3  d4684dcdc759dd9cdf41504698d737d8  2016-06-20 08:49:52 +0000
# 4  6325b6870c54cd47be6ebfbffa620ec7  2016-06-20 08:49:52 +0000
#
#                                          product_url
# 0  http://www.flipkart.com/elegance-polyester-mul...  \
# 1  http://www.flipkart.com/sathiyas-cotton-bath-t...
# 2  http://www.flipkart.com/eurospa-cotton-terry-f...
# 3  http://www.flipkart.com/santosh-royal-fashion-...
# 4  http://www.flipkart.com/jaipur-print-cotton-fl...
#
#                                         product_name
# 0  Elegance Polyester Multicolor Abstract Eyelet ...  \
# 1                         Sathiyas Cotton Bath Towel
# 2                Eurospa Cotton Terry Face Towel Set
# 3  SANTOSH ROYAL FASHION Cotton Printed King size...
# 4  Jaipur Print Cotton Floral King sized Double B...
#
#                                product_category_tree               pid
# 0  ["Home Furnishing >> Curtains & Accessories >>...  CRNEG7BKMFFYHQ8Z  \
# 1  ["Baby Care >> Baby Bath & Skin >> Baby Bath T...  BTWEGFZHGBXPHZUH
# 2  ["Baby Care >> Baby Bath & Skin >> Baby Bath T...  BTWEG6SHXTDB2A2Y
# 3  ["Home Furnishing >> Bed Linen >> Bedsheets >>...  BDSEJT9UQWHDUBH4
# 4  ["Home Furnishing >> Bed Linen >> Bedsheets >>...  BDSEJTHNGWVGWWQU
#
#    retail_price  discounted_price                                 image
# 0        1899.0             899.0  55b85ea15a1536d46b7190ad6fff8ce7.jpg  \
# 1         600.0             449.0  7b72c92c2f6c40268628ec5f14c6d590.jpg
# 2           NaN               NaN  64d5d4a258243731dc7bbb1eef49ad74.jpg
# 3        2699.0            1299.0  d4684dcdc759dd9cdf41504698d737d8.jpg
# 4        2599.0             698.0  6325b6870c54cd47be6ebfbffa620ec7.jpg
#
#    is_FK_Advantage_product                                        description
# 0                    False  Key Features of Elegance Polyester Multicolor ...  \
# 1                    False  Specifications of Sathiyas Cotton Bath Towel (...
# 2                    False  Key Features of Eurospa Cotton Terry Face Towe...
# 3                    False  Key Features of SANTOSH ROYAL FASHION Cotton P...
# 4                    False  Key Features of Jaipur Print Cotton Floral Kin...
#
#         product_rating       overall_rating                  brand
# 0  No rating available  No rating available               Elegance  \
# 1  No rating available  No rating available               Sathiyas
# 2  No rating available  No rating available                Eurospa
# 3  No rating available  No rating available  SANTOSH ROYAL FASHION
# 4  No rating available  No rating available           Jaipur Print
#
#                               product_specifications        category0
# 0  {"product_specification"=>[{"key"=>"Brand", "v...  home furnishing
# 1  {"product_specification"=>[{"key"=>"Machine Wa...        baby care
# 2  {"product_specification"=>[{"key"=>"Material",...        baby care
# 3  {"product_specification"=>[{"key"=>"Brand", "v...  home furnishing
# 4  {"product_specification"=>[{"key"=>"Machine Wa...  home furnishing

# %% [markdown]
# # Analyse du corpus des descriptions

# %% [markdown]
# ## Description

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /home/jupyter/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
punkt_folder = "/home/jupyter/nltk_data/tokenizers/punkt"

# %%
nltk.download('wordnet')
nltk.download("omw-1.4")
# Out:
# [nltk_data] Downloading package wordnet to /home/jupyter/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /home/jupyter/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# True

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /home/jupyter/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
tokenizer = nltk.data.load(f'{punkt_folder}/english.pickle')

# %%
stop_words = stopwords.words('english')

# %%
def add_to_corpus(s, corpus=None, tokenizer=None, lemmatizer=None, stemmer=None, stop_words=[]):
    if tokenizer is None:
        tokenizer = nltk.data.load(f'{punkt_folder}/english.pickle')
        
    if corpus is None:
        corpus = defaultdict(int)
        
    words = [word.lower() for word in nltk.word_tokenize(s)]
    for w in words:
        if lemmatizer is not None:
            w = lemmatizer.lemmatize(w, "v")
        if len(w)>3 and w.isalpha() and w.lower() not in stop_words:
            if stemmer is not None:
                w = stemmer.stem(w)
            if w.lower() not in stop_words:
                corpus[w] += 1
        
    return corpus

# %%
corpus_description = None
lemmatizer = WordNetLemmatizer()
stemmer = PorterStemmer()

for desc in df["description"]:
    corpus_description = add_to_corpus(desc, corpus=corpus_description, tokenizer=tokenizer, lemmatizer=lemmatizer, stemmer=stemmer, stop_words=stop_words)

# %%
nb_shown = 0
for index, (key, value) in enumerate(dict(sorted(corpus_description.items(), key=lambda item: item[1], reverse=True)).items()):
    print(f"{key}: {value}")
    nb_shown += 1
    if nb_shown>100:
        break
# Out:
# product: 868
# free: 613
# replac: 570
# ship: 569
# deliveri: 567
# genuin: 564
# cash: 564
# price: 558
# guarante: 473
# featur: 408
# onlin: 396
# design: 395
# specif: 379
# color: 369
# watch: 360
# pack: 341
# make: 338
# type: 324
# babi: 321
# materi: 310
# cotton: 296
# gener: 292
# print: 290
# packag: 275
# sale: 262
# analog: 255
# number: 250
# warranti: 249
# brand: 247
# detail: 246
# qualiti: 243
# girl: 242
# laptop: 234
# best: 230
# inch: 227
# model: 220
# gift: 220
# ceram: 217
# fabric: 210
# showpiec: 207
# cover: 205
# size: 196
# perfect: 190
# great: 189
# india: 180
# dimens: 175
# skin: 170
# home: 169
# ideal: 167
# multicolor: 160
# content: 157
# light: 154
# beauti: 152
# combo: 148
# power: 144
# water: 142
# women: 139
# discount: 134
# love: 134
# adapt: 131
# width: 129
# give: 128
# black: 127
# also: 126
# batteri: 125
# comfort: 124
# care: 122
# wash: 122
# pattern: 118
# coffe: 116
# style: 115
# height: 114
# blue: 113
# high: 110
# look: 109
# shape: 109
# name: 107
# length: 107
# towel: 106
# dress: 105
# come: 104
# round: 104
# weight: 102
# easi: 102
# wall: 102
# bodi: 101
# decor: 101
# craft: 98
# addit: 96
# bring: 92
# lead: 92
# casual: 92
# boy: 91
# dial: 91
# safe: 91
# strap: 90
# sleev: 87
# resist: 86
# soft: 85
# singl: 85
# steel: 82

# %%
len(corpus_description)
# Out:
# 3436

# %% [markdown]
# On voit certains mots qui ont des fréquences très élevées mais qui n'ont pas d'interet, exemples: product, free, discount
#
# Nous allons ajouter ces mots au tableau stop_words

# %%
stop_words2 = []
for index, (key, value) in enumerate(corpus_description.items()):
    if value>=243 and key!="cotton" and key!="babi" and key!="watch" and key!="analog":
        stop_words2.append(key)
stop_words2 += ["also", "look", "make", "use", "height", "width", "size", "brand", "inch", "model", "name", "discount", "perfect", "made", "gift", "ideal", "code"]

# %%
stop_words2
# Out:
# ['featur',
#  'pack',
#  'price',
#  'make',
#  'qualiti',
#  'design',
#  'print',
#  'specif',
#  'gener',
#  'brand',
#  'type',
#  'color',
#  'number',
#  'sale',
#  'packag',
#  'materi',
#  'product',
#  'warranti',
#  'onlin',
#  'genuin',
#  'replac',
#  'guarante',
#  'free',
#  'ship',
#  'cash',
#  'deliveri',
#  'detail',
#  'also',
#  'look',
#  'make',
#  'use',
#  'height',
#  'width',
#  'size',
#  'brand',
#  'inch',
#  'model',
#  'name',
#  'discount',
#  'perfect',
#  'made',
#  'gift',
#  'ideal',
#  'code']

# %%
corpus_description = None
stop_words2 = stop_words+stop_words2
for desc in df["description"]:
    corpus_description = add_to_corpus(desc, corpus=corpus_description, tokenizer=tokenizer, lemmatizer=lemmatizer, stemmer=stemmer, stop_words=stop_words2)

# %%
nb_words = []
txt_words = []
for index, (key, value) in enumerate(dict(sorted(corpus_description.items(), key=lambda item: item[1], reverse=True)).items()):
    if index<=20:
        print(f"{key}: {value}")
    nb_words.append(value)
    txt_words.append(key)
# Out:
# watch: 360
# babi: 321
# cotton: 296
# analog: 255
# girl: 242
# laptop: 234
# best: 230
# ceram: 217
# fabric: 210
# showpiec: 207
# cover: 205
# great: 189
# india: 180
# dimens: 175
# skin: 170
# home: 169
# multicolor: 160
# content: 157
# light: 154
# beauti: 152
# combo: 148

# %%
fig = go.Figure(data=go.Scatter(x=list(range(0, len(nb_words))),
                                y=nb_words,
                                mode='markers',
                                text=txt_words)) # hover text goes here

fig.update_layout(title='Mots utilisés dans les descriptions')
fig.show()
# Out:
# <iframe
#     scrolling="no"
#     width="100%"
#     height="545px"
#     src="iframe_figures/figure_34.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
wordcloud = WordCloud(width=1600, height=800).generate_from_frequencies(corpus_description)
plt.figure( figsize=(20,10), facecolor='k')
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad=0)
plt.show()

# %% [markdown]
# ## product_name

# %%
corpus_title = None
for desc in df["product_name"]:
    corpus_title = add_to_corpus(desc, corpus=corpus_title, tokenizer=tokenizer, lemmatizer=lemmatizer, stemmer=stemmer, stop_words=stop_words2)

# %%
nb_words = []
txt_words = []
for index, (key, value) in enumerate(dict(sorted(corpus_title.items(), key=lambda item: item[1], reverse=True)).items()):
    if index<=20:
        print(f"{key}: {value}")
    nb_words.append(value)
    txt_words.append(key)
# Out:
# watch: 151
# analog: 127
# showpiec: 105
# babi: 94
# combo: 93
# ceram: 78
# girl: 71
# cotton: 55
# women: 55
# singl: 45
# doubl: 40
# abstract: 39
# laptop: 39
# boy: 35
# light: 33
# blue: 32
# towel: 31
# lead: 31
# multicolor: 29
# comfort: 29
# floral: 27

# %%
fig = go.Figure(data=go.Scatter(x=list(range(0, len(nb_words))),
                                y=nb_words,
                                mode='markers',
                                text=txt_words)) # hover text goes here

fig.update_layout(title='Mots utilisés dans les noms de produits')
fig.show()
# Out:
# <iframe
#     scrolling="no"
#     width="100%"
#     height="545px"
#     src="iframe_figures/figure_38.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
wordcloud = WordCloud(width=1600, height=800).generate_from_frequencies(corpus_title)
plt.figure( figsize=(20,10), facecolor='k')
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad=0)
plt.show()

# %% [markdown]
# # Nettoyage des corpus

# %% [markdown]
# On constate que la marque du produit peut se retrouver dans product_name ou description.

# %%
def clean_text(x, col, tokenizer=None, lemmatizer=None, stemmer=None, stop_words=[]):
    s = x[col].lower()
    if not pd.isna(x["brand"]):
        s = s.replace(x["brand"].lower(), "")
    
    if tokenizer is None:
        tokenizer = nltk.data.load(f'{punkt_folder}/english.pickle')
                
    r = []
    words = [word.lower() for word in nltk.word_tokenize(s)]
    for w in words:
        if lemmatizer is not None:
            w = lemmatizer.lemmatize(w)
        if len(w)>3 and w.isalpha() and w.lower() not in stop_words:
            if stemmer is not None:
                w = stemmer.stem(w)
            if w.lower() not in stop_words:
                r.append(w)
    return " ".join(r)

df["cleaned_product_name"] = df.apply(lambda x: clean_text(x, "product_name", tokenizer, lemmatizer, stemmer, stop_words2), axis=1)

# %%
df.loc[:, ["product_name", "cleaned_product_name"]].tail(20)
# Out:
#                                            product_name
# 1030                      OMRD RD6697 Hot and cold Pack  \
# 1031  Kerastase Nutritive Bain Satin 1 Complete Nutr...
# 1032  PRINT SHAPES mary and max cartoon Laptop Skin ...
# 1033  Aroma Comfort Polyester Dark Blue Plain Eyelet...
# 1034  PRINT SHAPES Peacock Feather Laptop Skin with ...
# 1035  PRINT SHAPES despicable me 2 looking upwards L...
# 1036  PRINT SHAPES Red bull Laptop Skin with Mouse p...
# 1037  Aroma Comfort Polyester Brown Self Design Eyel...
# 1038  Surgical e Sstudio S0004 Gown, Pant Hospital S...
# 1039          Reiki Crystal Products Showpiece  -  6 cm
# 1040            Elite Collection Medium Acrylic Sticker
# 1041      Wallmantra Extra Large Vinyl Stickers Sticker
# 1042                     WallDesign Small Vinyl Sticker
# 1043                      999store Medium Paper Sticker
# 1044           Wallmantra Medium Vinyl Stickers Sticker
# 1045     Oren Empower Extra Large Self Adhesive Sticker
# 1046             Wallmantra Large Vinyl Sticker Sticker
# 1047  Uberlyfe Extra Large Pigmented Polyvinyl Films...
# 1048            Wallmantra Medium Vinyl Sticker Sticker
# 1049                       Uberlyfe Large Vinyl Sticker
#
#                                   cleaned_product_name
# 1030                                              cold
# 1031          nutrit bain satin complet nutrit shampoo
# 1032               mari cartoon laptop skin mous combo
# 1033     polyest dark blue plain eyelet window curtain
# 1034            peacock feather laptop skin mous combo
# 1035              despic upward laptop skin mous combo
# 1036                       bull laptop skin mous combo
# 1037            polyest brown self eyelet door curtain
# 1038                            gown pant hospit scrub
# 1039                                          showpiec
# 1040                              medium acryl sticker
# 1041                  extra larg vinyl sticker sticker
# 1042                               small vinyl sticker
# 1043                              medium paper sticker
# 1044                      medium vinyl sticker sticker
# 1045                     extra larg self adhes sticker
# 1046                        larg vinyl sticker sticker
# 1047  extra larg pigment polyvinyl film import sticker
# 1048                      medium vinyl sticker sticker
# 1049                                larg vinyl sticker

# %% [markdown]
# ## description

# %%
df["cleaned_description"] = df.apply(lambda x: clean_text(x, "description", tokenizer, lemmatizer, stemmer, stop_words2), axis=1)

# %%
df.loc[:, ["description", "cleaned_description"]]
# Out:
#                                             description
# 0     Key Features of Elegance Polyester Multicolor ...  \
# 1     Specifications of Sathiyas Cotton Bath Towel (...
# 2     Key Features of Eurospa Cotton Terry Face Towe...
# 3     Key Features of SANTOSH ROYAL FASHION Cotton P...
# 4     Key Features of Jaipur Print Cotton Floral Kin...
# ...                                                 ...
# 1045  Oren Empower Extra Large Self Adhesive Sticker...
# 1046  Wallmantra Large Vinyl Sticker Sticker (Pack o...
# 1047  Buy Uberlyfe Extra Large Pigmented Polyvinyl F...
# 1048  Buy Wallmantra Medium Vinyl Sticker Sticker fo...
# 1049  Buy Uberlyfe Large Vinyl Sticker for Rs.595 on...
#
#                                     cleaned_description
# 0     polyest multicolor abstract eyelet door curtai...
# 1     cotton bath towel bath towel yellow blue bath ...
# 2     cotton terri face towel small cotton terri fac...
# 3     cotton king doubl bedsheet royal bedsheet perf...
# 4     cotton floral king doubl bedsheet cotton cotto...
# ...                                                 ...
# 1045  extra larg self adhes sticker doubl sticker wa...
# 1046  larg vinyl sticker sticker bring home exclus p...
# 1047  extra larg pigment polyvinyl film import stick...
# 1048  medium vinyl sticker sticker medium vinyl stic...
# 1049         larg vinyl sticker larg vinyl sticker best
#
# [1050 rows x 2 columns]

# %% [markdown]
# ## Enregistrement

# %%
df.to_parquet(f"{working_dir}/cleaned.parquet")

# %%
df_experiments = pd.DataFrame({
    'algorithm': pd.Series(dtype='str'),
    'used_text': pd.Series(dtype='str'),
    'projection': pd.Series(dtype='str'),
    'silhouette': pd.Series(dtype='float')
})

# %%
def log_experiment(df_experiments, algo, used_text, projection, XX, ref_category):
    score = silhouette_score(XX, ref_category)
    df_experiments = pd.concat(
        [
            df_experiments,
            pd.DataFrame(
                [{
                    "algorithm": algo,
                    "used_text": used_text,
                    "projection": projection,
                    "silhouette": score,
                }]
            )
        ],
        ignore_index=True,
    )
    print(f"Silhouette score = {score}")
    return df_experiments

# %% [markdown]
# # Création d'un bag of words avec CountVectorizer

# %% [markdown]
# ## Expérience 1
# Ici, nous concaténons cleaned_product_name et cleaned_description et faisons une décomposition sur cette nouvelle colonne (fit et transform)

# %%
df = pd.read_parquet(f"{working_dir}/cleaned.parquet")
df["cleaned_text"] = df["cleaned_product_name"].astype(str) + " " + df["cleaned_description"].astype(str)

# %%
vectorizer_product_name_description= CountVectorizer()
X = vectorizer_product_name_description.fit_transform(df["cleaned_text"]).toarray()

# %%
vectorizer_product_name_description.get_feature_names_out()
# Out:
# array(['aari', 'abil', 'abl', ..., 'zone', 'zoom', 'zora'], dtype=object)

# %%
X.shape
# Out:
# (1050, 3076)

# %%
scaler = MinMaxScaler()
#X = scaler.fit_transform(df.loc[:, num_cols])
X = scaler.fit_transform(X)

# %%
algo="CountVectorizer"

# %%
df_experiments = log_experiment(df_experiments, algo, "cleaned_product_name + cleaned_description", "None", X, df["category0"])
# Out:
# Silhouette score = -0.07123464396195678

# %% [markdown]
# ### Projection PCA

# %%
pca = PCA(n_components=1000)
pca.fit(X)
# Out:
# PCA(n_components=1000)

# %%
show_pca_variance_graph(pca)
# Out:
# <iframe
#     scrolling="no"
#     width="820px"
#     height="820"
#     src="iframe_figures/figure_55.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %% [markdown]
# Nous allons garder les 623 premières composantes de la PCA, ce qui représente une variance totale à 99% de la variance totale

# %%
pca = PCA(n_components=623)

pca.fit(X)
X_pca = pca.transform(X)
df_experiments = log_experiment(df_experiments, algo, "cleaned_product_name + cleaned_description", "PCA - 623", X_pca, df["category0"])
# Out:
# Silhouette score = -0.07194315451365305

# %%
show_scatter_graph(
    x=X_pca[:,0],
    y=X_pca[:,1],
    colors=df["category0"],
    title="Projection PCA sur les 2 premiers axes",
)
# Out:
# <iframe
#     scrolling="no"
#     width="820px"
#     height="620"
#     src="iframe_figures/figure_57.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
show_scatter_graph(
    x=X_pca[:,2],
    y=X_pca[:,3],
    colors=df["category0"],
    title="Projection PCA sur les axes 2 et 3",
)
# Out:
# <iframe
#     scrolling="no"
#     width="820px"
#     height="620"
#     src="iframe_figures/figure_58.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
show_scatter_graph(
    x=X_pca[:,4],
    y=X_pca[:,5],
    colors=df["category0"],
    title="Projection PCA sur les axes 4 et 5",
)
# Out:
# <iframe
#     scrolling="no"
#     width="820px"
#     height="620"
#     src="iframe_figures/figure_59.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %% [markdown]
# ### Projection LDA

# %%
lda = LatentDirichletAllocation(n_components=7, n_jobs=-1, random_state=0)
X_lda = lda.fit_transform(X)
df_experiments = log_experiment(df_experiments, algo, "cleaned_product_name + cleaned_description", "LDA", X_lda, df["category0"])
# Out:
# Silhouette score = -0.0046006880523141785

# %%
terms = vectorizer_product_name_description.get_feature_names_out()

lda_components=lda.components_
for index, component in enumerate(lda_components):
    zipped = zip(terms, component)
    top_terms_key=sorted(zipped, key = lambda t: t[1], reverse=True)[:7]
    top_terms_list=list(dict(top_terms_key).keys())
    print("Topic "+str(index)+": ",top_terms_list)
# Out:
# Topic 0:  ['summari', 'ensur', 'exclus', 'year', 'fresh', 'microwav', 'dishwash']
# Topic 1:  ['lowest', 'denver', 'combo', 'content', 'pavilion', 'sticker', 'vinyl']
# Topic 2:  ['enjoy', 'coffe', 'prithish', 'bring', 'abstract', 'love', 'fantast']
# Topic 3:  ['best', 'timewel', 'soft', 'moment', 'apparel', 'vari', 'cloth']
# Topic 4:  ['analog', 'india', 'great', 'woman', 'clasp', 'watch', 'buckl']
# Topic 5:  ['showpiec', 'best', 'perform', 'portabl', 'authent', 'stone', 'highest']
# Topic 6:  ['content', 'fabric', 'pattern', 'babi', 'length', 'addit', 'girl']

# %% [markdown]
# ### Projection tSNE

# %%
tsne = TSNE(n_components=2, random_state=0)
X_embedded = tsne.fit_transform(X)
df_experiments = log_experiment(df_experiments, algo, "cleaned_product_name + cleaned_description", "tSNE", X_embedded, df["category0"])
# Out:
# Silhouette score = 0.031903285533189774

# %%
show_scatter_graph(
    x=X_embedded[:,0],
    y=X_embedded[:,1],
    colors=df["category0"],
    title="Projection tSNE de X sur les 2 premiers axes"
)
# Out:
# <iframe
#     scrolling="no"
#     width="820px"
#     height="620"
#     src="iframe_figures/figure_63.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
tsne = TSNE(n_components=2, random_state=0)
X_embedded = tsne.fit_transform(X_pca)
df_experiments = log_experiment(df_experiments, algo, "cleaned_product_name + cleaned_description", "PCA-623+ tSNE", X_embedded, df["category0"])
# Out:
# Silhouette score = 0.057413991540670395

# %%
show_scatter_graph(
    x=X_embedded[:,0],
    y=X_embedded[:,1],
    colors=df["category0"],
    title="Projection tSNE de X_pca sur les 2 premiers axes"
)
# Out:
# <iframe
#     scrolling="no"
#     width="820px"
#     height="620"
#     src="iframe_figures/figure_65.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
tsne = TSNE(n_components=2, random_state=0)
X_embedded = tsne.fit_transform(X_lda)
df_experiments = log_experiment(df_experiments, algo, "cleaned_product_name + cleaned_description", "LDA + tSNE", X_embedded, df["category0"])
# Out:
# Silhouette score = -0.0461549311876297

# %%
show_scatter_graph(
    x=X_embedded[:,0],
    y=X_embedded[:,1],
    colors=df["category0"],
    title="Project tSNE de X_lda sur les 2 premiers axes"
)
# Out:
# <iframe
#     scrolling="no"
#     width="820px"
#     height="620"
#     src="iframe_figures/figure_67.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %% [markdown]
# ## Expérience 2
#
# Dans ce cas, nous concatenons cleaned_product_name et cleaned_description et faisons une décomposition sur cette nouvelle colonne (transform) après avoir fait le fit sur cleaned_product_name

# %%
df = pd.read_parquet(f"{working_dir}/cleaned.parquet")

# %%
df["cleaned_text"] = df["cleaned_product_name"].astype(str) + " " + df["cleaned_description"].astype(str)
vectorizer_product_name = CountVectorizer()
vectorizer_product_name.fit(df["cleaned_product_name"])
X = vectorizer_product_name.transform(df["cleaned_text"])

# %%
scaler = MinMaxScaler()
X = scaler.fit_transform(X.toarray())
df_experiments = log_experiment(df_experiments, algo, "cleaned_product_name(fit,transform) + cleaned_description(transform)", "None", X, df["category0"])
# Out:
# Silhouette score = -0.06013716801126762

# %% [markdown]
# ### Projection PCA

# %%
pca = PCA(n_components=1000)
pca.fit(X)
# Out:
# PCA(n_components=1000)

# %%
show_pca_variance_graph(pca)
# Out:
# <iframe
#     scrolling="no"
#     width="820px"
#     height="820"
#     src="iframe_figures/figure_72.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %% [markdown]
# Nous allons garder les 590 premières composantes de la PCA, ce qui représente une variance totale à 99% de la variance totale

# %%
pca = PCA(n_components=590)
pca.fit(X)
X_pca = pca.transform(X)
df_experiments = log_experiment(df_experiments, algo, "cleaned_product_name(fit,transform) + cleaned_description(transform)", "PCA - 590", X_pca, df["category0"])
# Out:
# Silhouette score = -0.06089375210421531

# %%
show_scatter_graph(
    x=X_pca[:,0],
    y=X_pca[:,1],
    colors=df["category0"],
    title="Projection PCA sur les 2 premiers axes",
)
# Out:
# <iframe
#     scrolling="no"
#     width="820px"
#     height="620"
#     src="iframe_figures/figure_74.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
show_scatter_graph(
    x=X_pca[:,2],
    y=X_pca[:,3],
    colors=df["category0"],
    title="Projection PCA sur les axes 2 et 3",
)
# Out:
# <iframe
#     scrolling="no"
#     width="820px"
#     height="620"
#     src="iframe_figures/figure_75.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
show_scatter_graph(
    x=X_pca[:,4],
    y=X_pca[:,5],
    colors=df["category0"],
    title="Projection PCA sur les axes 4 et 5",
)
# Out:
# <iframe
#     scrolling="no"
#     width="820px"
#     height="620"
#     src="iframe_figures/figure_76.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %% [markdown]
# ### Projection LDA

# %%
lda = LatentDirichletAllocation(n_components=7, n_jobs=-1, random_state=0)
X_lda = lda.fit_transform(X)
df_experiments = log_experiment(df_experiments, algo, "cleaned_product_name(fit,transform) + cleaned_description(transform)", "LDA", X_lda, df["category0"])
# Out:
# Silhouette score = 0.0023717369910952408

# %%
terms = vectorizer_product_name.get_feature_names_out()

lda_components=lda.components_
for index, component in enumerate(lda_components):
    zipped = zip(terms, component)
    top_terms_key=sorted(zipped, key = lambda t: t[1], reverse=True)[:20]
    top_terms_list=list(dict(top_terms_key).keys())
    print("Topic "+str(index)+": ",top_terms_list)
# Out:
# Topic 0:  ['polyest', 'door', 'eyelet', 'portabl', 'digit', 'curtain', 'denver', 'light', 'sport', 'oxyglow', 'brown', 'long', 'appl', 'best', 'shape', 'window', 'cream', 'fruit', 'night', 'massag']
# Topic 1:  ['power', 'charger', 'area', 'light', 'best', 'adapt', 'custom', 'batteri', 'kadhai', 'seri', 'bath', 'soft', 'bodi', 'gather', 'rice', 'cell', 'year', 'laptop', 'pavilion', 'protect']
# Topic 2:  ['babi', 'girl', 'wash', 'cotton', 'dress', 'neck', 'router', 'casual', 'printland', 'coffe', 'wireless', 'care', 'stylish', 'serv', 'solid', 'timewel', 'combo', 'round', 'love', 'pink']
# Topic 3:  ['vaniti', 'pari', 'best', 'showpiec', 'andr', 'anna', 'mini', 'combo', 'steel', 'pyjama', 'dark', 'beauti', 'sunscreen', 'tradit', 'indian', 'natur', 'hookah', 'makeup', 'piec', 'valentin']
# Topic 4:  ['fresh', 'year', 'ceram', 'love', 'prithish', 'rockmantra', 'give', 'best', 'safe', 'coffe', 'start', 'showpiec', 'cute', 'share', 'express', 'happi', 'show', 'attract', 'craft', 'mxofer']
# Topic 5:  ['multicolor', 'cover', 'abstract', 'floral', 'singl', 'mous', 'showpiec', 'rang', 'beauti', 'best', 'pure', 'combo', 'doubl', 'vinyl', 'give', 'cushion', 'cotton', 'comfort', 'wash', 'cloth']
# Topic 6:  ['analog', 'woman', 'watch', 'maximum', 'strap', 'dial', 'sonata', 'time', 'round', 'perucci', 'girl', 'digit', 'decker', 'handl', 'water', 'gold', 'classic', 'steel', 'heat', 'shape']

# %% [markdown]
# ### Projection tSNE

# %%
tsne = TSNE(n_components=2, random_state=0)
X_embedded = tsne.fit_transform(X)
df_experiments = log_experiment(df_experiments, algo, "cleaned_product_name(fit,transform) + cleaned_description(transform)", "tSNE", X_embedded, df["category0"])
# Out:
# Silhouette score = 0.04478485882282257

# %%
show_scatter_graph(
    x=X_embedded[:,0],
    y=X_embedded[:,1],
    colors=df["category0"],
    title="Project tSNE de X sur les 2 premiers axes"
)
# Out:
# <iframe
#     scrolling="no"
#     width="820px"
#     height="620"
#     src="iframe_figures/figure_80.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
tsne = TSNE(n_components=2, random_state=0)
X_embedded = tsne.fit_transform(X_pca)
df_experiments = log_experiment(df_experiments, algo, "cleaned_product_name(fit,transform) + cleaned_description(transform)", "PCA-590 + tSNE", X_embedded, df["category0"])

show_scatter_graph(
    x=X_embedded[:,0],
    y=X_embedded[:,1],
    colors=df["category0"],
    title="Project tSNE de X_pca sur les 2 premiers axes"
)
# Out:
# Silhouette score = 0.04431743174791336
# <iframe
#     scrolling="no"
#     width="820px"
#     height="620"
#     src="iframe_figures/figure_81.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
tsne = TSNE(n_components=2, random_state=0)
X_embedded = tsne.fit_transform(X_lda)
df_experiments = log_experiment(df_experiments, algo, "cleaned_product_name(fit,transform) + cleaned_description(transform)", "LDA + tSNE", X_embedded, df["category0"])

show_scatter_graph(
    x=X_embedded[:,0],
    y=X_embedded[:,1],
    colors=df["category0"],
    title="Project tSNE de X_lda sur les 2 premiers axes"
)
# Out:
# Silhouette score = -0.04569461569190025
# <iframe
#     scrolling="no"
#     width="820px"
#     height="620"
#     src="iframe_figures/figure_82.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %% [markdown]
# ## Expérience 3
# Ici, nous n'allons prendre que la feature product_name

# %%
df = pd.read_parquet(f"{working_dir}/cleaned.parquet")
vectorizer_product_name = CountVectorizer()
X = vectorizer_product_name.fit_transform(df["cleaned_product_name"])

# %%
scaler = MinMaxScaler()
X = scaler.fit_transform(X.toarray())
df_experiments = log_experiment(df_experiments, algo, "cleaned_description", "None", X, df["category0"])
# Out:
# Silhouette score = 0.024018783783203206

# %% [markdown]
# ### Projection PCA

# %%
pca = PCA(n_components=1000)
pca.fit(X)
# Out:
# PCA(n_components=1000)

# %%
show_pca_variance_graph(pca)
# Out:
# <iframe
#     scrolling="no"
#     width="820px"
#     height="820"
#     src="iframe_figures/figure_86.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
pca = PCA(n_components=560)
pca.fit(X)
X_pca = pca.transform(X)
df_experiments = log_experiment(df_experiments, algo, "cleaned_description", "PCA-560", X_pca, df["category0"])
# Out:
# Silhouette score = 0.024790412205591184

# %%
show_scatter_graph(
    x=X_pca[:,0],
    y=X_pca[:,1],
    colors=df["category0"],
    title="Projection PCA sur les 2 premiers axes",
)
# Out:
# <iframe
#     scrolling="no"
#     width="820px"
#     height="620"
#     src="iframe_figures/figure_88.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
show_scatter_graph(
    x=X_pca[:,2],
    y=X_pca[:,3],
    colors=df["category0"],
    title="Projection PCA sur les axes 2 et 3",
)
# Out:
# <iframe
#     scrolling="no"
#     width="820px"
#     height="620"
#     src="iframe_figures/figure_89.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %% [markdown]
# ### Projection LDA

# %%
lda = LatentDirichletAllocation(n_components=7, n_jobs=-1, random_state=0)
X_lda = lda.fit_transform(X)
df_experiments = log_experiment(df_experiments, algo, "cleaned_description", "LDA", X_lda, df["category0"])
# Out:
# Silhouette score = -0.003718140065493649

# %%
terms = vectorizer_product_name.get_feature_names_out()

lda_components=lda.components_
for index, component in enumerate(lda_components):
    zipped = zip(terms, component)
    top_terms_key=sorted(zipped, key = lambda t: t[1], reverse=True)[:20]
    top_terms_list=list(dict(top_terms_key).keys())
    print("Topic "+str(index)+": ",top_terms_list)
# Out:
# Topic 0:  ['laptop', 'batteri', 'polyest', 'curtain', 'eyelet', 'cushion', 'showpiec', 'digit', 'cover', 'door', 'ceram', 'printland', 'pavilion', 'cell', 'charger', 'adapt', 'seri', 'self', 'oxyglow', 'fruit']
# Topic 1:  ['cotton', 'dress', 'babi', 'kadhai', 'bath', 'girl', 'towel', 'sticker', 'blue', 'white', 'gather', 'orang', 'bottl', 'kitchen', 'vinyl', 'bulb', 'bodysuit', 'wrap', 'nutcas', 'larg']
# Topic 2:  ['blue', 'grey', 'timewel', 'black', 'combo', 'showpiec', 'babi', 'dohar', 'prithish', 'mobil', 'ceram', 'power', 'neck', 'round', 'portabl', 'smart', 'paper', 'stripe', 'pari', 'andr']
# Topic 3:  ['combo', 'tabl', 'mous', 'laptop', 'stone', 'showpiec', 'steel', 'portabl', 'lamp', 'light', 'skin', 'mini', 'stainless', 'glass', 'babi', 'wild', 'frame', 'photo', 'pyjama', 'nail']
# Topic 4:  ['floral', 'comfort', 'quilt', 'singl', 'rockmantra', 'multicolor', 'router', 'wireless', 'ceram', 'mxofer', 'soap', 'combo', 'decor', 'showpiec', 'honey', 'jasmin', 'rice', 'aloevera', 'green', 'almond']
# Topic 5:  ['doubl', 'blanket', 'singl', 'prithish', 'cotton', 'abstract', 'bedsheet', 'showpiec', 'multicolor', 'casual', 'plain', 'ceram', 'king', 'denver', 'shirt', 'buddha', 'combo', 'geometr', 'paint', 'ganesha']
# Topic 6:  ['analog', 'watch', 'woman', 'maximum', 'gold', 'sonata', 'time', 'cutter', 'pizza', 'girl', 'perucci', 'wheel', 'decker', 'roll', 'classic', 'fastrack', 'flippd', 'sleepsuit', 'embroid', 'wrapper']

# %% [markdown]
# ### Projection tSNE

# %%
tsne = TSNE(n_components=2, random_state=0)
X_embedded = tsne.fit_transform(X)
df_experiments = log_experiment(df_experiments, algo, "cleaned_description", "tSNE", X_embedded, df["category0"])
# Out:
# Silhouette score = 0.015635928139090538

# %%
show_scatter_graph(
    x=X_embedded[:,0],
    y=X_embedded[:,1],
    colors=df["category0"],
    title="Project tSNE de X sur les 2 premiers axes"
)
# Out:
# <iframe
#     scrolling="no"
#     width="820px"
#     height="620"
#     src="iframe_figures/figure_93.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
tsne = TSNE(n_components=2, random_state=0)
X_embedded = tsne.fit_transform(X_pca)
df_experiments = log_experiment(df_experiments, algo, "cleaned_description", "PCA-560 + tSNE", X_embedded, df["category0"])
# Out:
# Silhouette score = 0.05713846534490585

# %%
show_scatter_graph(
    x=X_embedded[:,0],
    y=X_embedded[:,1],
    colors=df["category0"],
    title="Project tSNE de X_pca sur les 2 premiers axes"
)
# Out:
# <iframe
#     scrolling="no"
#     width="820px"
#     height="620"
#     src="iframe_figures/figure_95.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
tsne = TSNE(n_components=2, random_state=0)
X_embedded = tsne.fit_transform(X_lda)
df_experiments = log_experiment(df_experiments, algo, "cleaned_description", "LDA + tSNE", X_embedded, df["category0"])

show_scatter_graph(
    x=X_embedded[:,0],
    y=X_embedded[:,1],
    colors=df["category0"],
    title="Project tSNE de X_lda sur les 2 premiers axes"
)
# Out:
# Silhouette score = -0.061772461980581284
# <iframe
#     scrolling="no"
#     width="820px"
#     height="620"
#     src="iframe_figures/figure_96.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %% [markdown]
# # Création d'un bag of words avec td-idf

# %% [markdown]
# ## Expérience 1
#
# Ici, nous concatenons cleaned_product_name et cleaned_description et faisons une décomposition sur cette nouvelle colonne (fit et transform)

# %%
df = pd.read_parquet(f"{working_dir}/cleaned.parquet")
df["cleaned_text"] = df["cleaned_product_name"].astype(str) + " " + df["cleaned_description"].astype(str)

# %%
vectorizer_product_name_description = CountVectorizer()
X = vectorizer_product_name_description.fit_transform(df["cleaned_text"]).toarray()

# %%
scaler = MinMaxScaler()
X = scaler.fit_transform(X)

# %%
algo="TfIdf"

# %%
df_experiments = log_experiment(df_experiments, algo, "cleaned_product_name + cleaned_description", "None", X, df["category0"])
# Out:
# Silhouette score = -0.07123464396195678

# %% [markdown]
# ### Projection PCA

# %%
pca = PCA(n_components=1000)
pca.fit(X)
# Out:
# PCA(n_components=1000)

# %%
show_pca_variance_graph(pca)
# Out:
# <iframe
#     scrolling="no"
#     width="820px"
#     height="820"
#     src="iframe_figures/figure_103.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %% [markdown]
# Nous allons garder les 620 premières composantes de la PCA, ce qui représente une variance totale à 99% de la variance totale

# %%
pca = PCA(n_components=620)

pca.fit(X)
X_pca = pca.transform(X)
df_experiments = log_experiment(df_experiments, algo, "cleaned_product_name + cleaned_description", "PCA - 620", X_pca, df["category0"])
# Out:
# Silhouette score = -0.07200712449818185

# %%
show_scatter_graph(
    x=X_pca[:,0],
    y=X_pca[:,1],
    colors=df["category0"],
    title="Projection PCA sur les 2 premiers axes",
)
# Out:
# <iframe
#     scrolling="no"
#     width="820px"
#     height="620"
#     src="iframe_figures/figure_105.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
show_scatter_graph(
    x=X_pca[:,2],
    y=X_pca[:,3],
    colors=df["category0"],
    title="Projection PCA sur les axes 2 et 3",
)
# Out:
# <iframe
#     scrolling="no"
#     width="820px"
#     height="620"
#     src="iframe_figures/figure_106.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
show_scatter_graph(
    x=X_pca[:,4],
    y=X_pca[:,5],
    colors=df["category0"],
    title="Projection PCA sur les axes 4 et 5",
)
# Out:
# <iframe
#     scrolling="no"
#     width="820px"
#     height="620"
#     src="iframe_figures/figure_107.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
show_scatter_graph(
    x=X_pca[:,6],
    y=X_pca[:,7],
    colors=df["category0"],
    title="Project PCA sur les axes 6 et 7",
)
# Out:
# <iframe
#     scrolling="no"
#     width="820px"
#     height="620"
#     src="iframe_figures/figure_108.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %% [markdown]
# La projection des categories sur les 8 premiers axes de la PCA nous montre des clusters. Cependant on voit des clusters imbriqués (home furnishing & baby care) ainsi qu'une concentration autour d'un point central.

# %% [markdown]
# ### Projection LDA

# %%
lda = LatentDirichletAllocation(n_components=7, n_jobs=-1, random_state=0)
X_lda = lda.fit_transform(X)
df_experiments = log_experiment(df_experiments, algo, "cleaned_product_name + cleaned_description", "LDA", X_lda, df["category0"])
# Out:
# Silhouette score = -0.0046006880523141785

# %%
terms = vectorizer_product_name_description.get_feature_names_out()

lda_components=lda.components_
for index, component in enumerate(lda_components):
    zipped = zip(terms, component)
    top_terms_key=sorted(zipped, key = lambda t: t[1], reverse=True)[:7]
    top_terms_list=list(dict(top_terms_key).keys())
    print("Topic "+str(index)+": ",top_terms_list)
# Out:
# Topic 0:  ['summari', 'ensur', 'exclus', 'year', 'fresh', 'microwav', 'dishwash']
# Topic 1:  ['lowest', 'denver', 'combo', 'content', 'pavilion', 'sticker', 'vinyl']
# Topic 2:  ['enjoy', 'coffe', 'prithish', 'bring', 'abstract', 'love', 'fantast']
# Topic 3:  ['best', 'timewel', 'soft', 'moment', 'apparel', 'vari', 'cloth']
# Topic 4:  ['analog', 'india', 'great', 'woman', 'clasp', 'watch', 'buckl']
# Topic 5:  ['showpiec', 'best', 'perform', 'portabl', 'authent', 'stone', 'highest']
# Topic 6:  ['content', 'fabric', 'pattern', 'babi', 'length', 'addit', 'girl']

# %% [markdown]
# ### Projection tSNE

# %%
tsne = TSNE(n_components=2, random_state=0)
X_embedded = tsne.fit_transform(X)
df_experiments = log_experiment(df_experiments, algo, "cleaned_product_name + cleaned_description", "tSNE", X_embedded, df["category0"])
# Out:
# Silhouette score = 0.031903285533189774

# %%
show_scatter_graph(
    x=X_embedded[:,0],
    y=X_embedded[:,1],
    colors=df["category0"],
    title="Projection tSNE de X sur les 2 premiers axes"
)
# Out:
# <iframe
#     scrolling="no"
#     width="820px"
#     height="620"
#     src="iframe_figures/figure_112.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
tsne = TSNE(n_components=2, random_state=0)
X_embedded = tsne.fit_transform(X_pca)
df_experiments = log_experiment(df_experiments, algo, "cleaned_product_name + cleaned_description", "PCA-620 + tSNE", X_embedded, df["category0"])
# Out:
# Silhouette score = 0.05141352117061615

# %%
show_scatter_graph(
    x=X_embedded[:,0],
    y=X_embedded[:,1],
    colors=df["category0"],
    title="Projection tSNE de X_pca sur les 2 premiers axes"
)
# Out:
# <iframe
#     scrolling="no"
#     width="820px"
#     height="620"
#     src="iframe_figures/figure_114.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
tsne = TSNE(n_components=2, random_state=0)
X_embedded = tsne.fit_transform(X_lda)
df_experiments = log_experiment(df_experiments, algo, "cleaned_product_name + cleaned_description", "LDA + tSNE", X_embedded, df["category0"])
# Out:
# Silhouette score = -0.0461549311876297

# %%
show_scatter_graph(
    x=X_embedded[:,0],
    y=X_embedded[:,1],
    colors=df["category0"],
    title="Project tSNE de X_lda sur les 2 premiers axes"
)
# Out:
# <iframe
#     scrolling="no"
#     width="820px"
#     height="620"
#     src="iframe_figures/figure_116.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %% [markdown]
# En associant la LDA et la tSNE, on obtient un clustering net autour des catégories de produits

# %% [markdown]
# ## Expérience 2
#
# Dans ce cas, nous concatenons cleaned_product_name et cleaned_description et faisons une décomposition sur cette nouvelle colonne (transform) après avoir fait le fit sur cleaned_product_name

# %%
df = pd.read_parquet(f"{working_dir}/cleaned.parquet")

# %%
df["cleaned_text"] = df["cleaned_product_name"].astype(str) + " " + df["cleaned_description"].astype(str)
vectorizer_product_name = TfidfVectorizer()
vectorizer_product_name.fit(df["cleaned_product_name"])
X = vectorizer_product_name.transform(df["cleaned_text"])
df = pd.concat([df, pd.DataFrame(X.toarray(), columns=[f"label_{w}" for w in vectorizer_product_name.get_feature_names_out()])], axis=1)

# %%
bow_cols = []
for c in df.columns:
    if c.startswith("label_"):
        w = c[9:]
        bow_cols.append(c)
df = df.loc[:, bow_cols + ["category0"]]

# %%
num_cols = df.select_dtypes(include=[np.number]).columns
scaler = MinMaxScaler()
X = scaler.fit_transform(df.loc[:, num_cols])
df_experiments = log_experiment(df_experiments, algo, "cleaned_product_name(fit,transform) + cleaned_description(transform)", "None", X, df["category0"])
# Out:
# Silhouette score = 0.011375483785491452

# %% [markdown]
# ### Projection PCA

# %%
pca = PCA(n_components=1000)
pca.fit(X)
# Out:
# PCA(n_components=1000)

# %%
show_pca_variance_graph(pca)
# Out:
# <iframe
#     scrolling="no"
#     width="820px"
#     height="820"
#     src="iframe_figures/figure_122.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
pca = PCA(n_components=700)
pca.fit(X)
X_pca = pca.transform(X)
df_experiments = log_experiment(df_experiments, algo, "cleaned_product_name(fit,transform) + cleaned_description(transform)", "PCA-700", X_pca, df["category0"])
# Out:
# Silhouette score = 0.011520900771506032

# %%
show_scatter_graph(
    x=X_pca[:,0],
    y=X_pca[:,1],
    colors=df["category0"],
    title="Projection PCA sur les 2 premiers axes",
)
# Out:
# <iframe
#     scrolling="no"
#     width="820px"
#     height="620"
#     src="iframe_figures/figure_124.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
show_scatter_graph(
    x=X_pca[:,2],
    y=X_pca[:,3],
    colors=df["category0"],
    title="Projection PCA sur les 2 premiers axes",
)
# Out:
# <iframe
#     scrolling="no"
#     width="820px"
#     height="620"
#     src="iframe_figures/figure_125.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %% [markdown]
# ### Projection LDA

# %%
lda = LatentDirichletAllocation(n_components=7, n_jobs=-1, random_state=0)
X_lda = lda.fit_transform(X)
df_experiments = log_experiment(df_experiments, algo, "cleaned_product_name + cleaned_description", "LDA", X_lda, df["category0"])
# Out:
# Silhouette score = -0.0232629153995113

# %%
terms = vectorizer_product_name.get_feature_names_out()

lda_components=lda.components_
for index, component in enumerate(lda_components):
    zipped = zip(terms, component)
    top_terms_key=sorted(zipped, key = lambda t: t[1], reverse=True)[:7]
    top_terms_list=list(dict(top_terms_key).keys())
    print("Topic "+str(index)+": ",top_terms_list)
# Out:
# Topic 0:  ['polyest', 'eyelet', 'door', 'curtain', 'power', 'ceram', 'light']
# Topic 1:  ['cotton', 'babi', 'girl', 'towel', 'dress', 'wash', 'bath']
# Topic 2:  ['watch', 'analog', 'woman', 'dial', 'strap', 'maximum', 'cushion']
# Topic 3:  ['combo', 'tabl', 'router', 'wireless', 'pyjama', 'vaniti', 'natur']
# Topic 4:  ['give', 'love', 'showpiec', 'ceram', 'craft', 'rockmantra', 'best']
# Topic 5:  ['singl', 'doubl', 'multicolor', 'comfort', 'abstract', 'floral', 'blanket']
# Topic 6:  ['laptop', 'mous', 'pizza', 'cutter', 'skin', 'combo', 'compat']

# %% [markdown]
# ### Projection tSNE

# %%
tsne = TSNE(n_components=2, random_state=0)
X_embedded = tsne.fit_transform(X)
df_experiments = log_experiment(df_experiments, algo, "cleaned_product_name(fit,transform) + cleaned_description(transform)", "tSNE", X_embedded, df["category0"])
# Out:
# Silhouette score = 0.07087545841932297

# %%
show_scatter_graph(
    x=X_embedded[:,0],
    y=X_embedded[:,1],
    colors=df["category0"],
    title="Project tSNE de X sur les 2 premiers axes"
)
# Out:
# <iframe
#     scrolling="no"
#     width="820px"
#     height="620"
#     src="iframe_figures/figure_129.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %% [markdown]
# L'application du tSNE sur les 2 premiers axes avec les données de X n'est pas satisfaisant. Essayons avec les données de X_pca

# %%
tsne = TSNE(n_components=2, random_state=0)
X_embedded = tsne.fit_transform(X_pca)
df_experiments = log_experiment(df_experiments, algo, "cleaned_product_name(fit,transform) + cleaned_description(transform)", "PCA-700 + tSNE", X_embedded, df["category0"])

show_scatter_graph(
    x=X_embedded[:,0],
    y=X_embedded[:,1],
    colors=df["category0"],
    title="Project tSNE de X_pca sur les 2 premiers axes"
)
# Out:
# Silhouette score = 0.016196662560105324
# <iframe
#     scrolling="no"
#     width="820px"
#     height="620"
#     src="iframe_figures/figure_130.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %% [markdown]
# L'application du tSNE sur les 2 premiers axes avec les données de X_pca n'est pas satisfaisant. Essayons avec les données de X_lda

# %%
tsne = TSNE(n_components=2, random_state=0)
X_embedded = tsne.fit_transform(X_lda)
df_experiments = log_experiment(df_experiments, algo, "cleaned_product_name(fit,transform) + cleaned_description(transform)", "LDA + tSNE", X_embedded, df["category0"])

show_scatter_graph(
    x=X_embedded[:,0],
    y=X_embedded[:,1],
    colors=df["category0"],
    title="Project tSNE de X_lda sur les 2 premiers axes"
)
# Out:
# Silhouette score = -0.06700670719146729
# <iframe
#     scrolling="no"
#     width="820px"
#     height="620"
#     src="iframe_figures/figure_131.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %% [markdown]
# Nous avons ici encore un clustering satisfaisant via l'association de la décomposition LDA et du tSNE

# %% [markdown]
# ## Expérience 3
# Ici, nous n'allons prendre que la feature product_name

# %%
df = pd.read_parquet(f"{working_dir}/cleaned.parquet")
vectorizer_product_name = TfidfVectorizer()
X = vectorizer_product_name.fit_transform(df["cleaned_product_name"])
df = pd.concat([df, pd.DataFrame(X.toarray(), columns=[f"label_{w}" for w in vectorizer_product_name.get_feature_names_out()])], axis=1)

# %%
bow_cols = []
for c in df.columns:
    if c.startswith("label_"):
        w = c[9:]
        bow_cols.append(c)
df = df.loc[:, bow_cols + ["category0"]]

# %%
num_cols = df.select_dtypes(include=[np.number]).columns
scaler = MinMaxScaler()
X = scaler.fit_transform(df.loc[:, num_cols])
df_experiments = log_experiment(df_experiments, algo, "cleaned_description", "None", X, df["category0"])
# Out:
# Silhouette score = 0.018067363409909457

# %% [markdown]
# ### Projection PCA

# %%
pca = PCA(n_components=1000)
pca.fit(X)
# Out:
# PCA(n_components=1000)

# %%
show_pca_variance_graph(pca)
# Out:
# <iframe
#     scrolling="no"
#     width="820px"
#     height="820"
#     src="iframe_figures/figure_136.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
pca = PCA(n_components=600)
pca.fit(X)
X_pca = pca.transform(X)
df_experiments = log_experiment(df_experiments, algo, "cleaned_description", "PCA-600", X_pca, df["category0"])
# Out:
# Silhouette score = 0.018497143326477235

# %%
show_scatter_graph(
    x=X_pca[:,0],
    y=X_pca[:,1],
    colors=df["category0"],
    title="Projection PCA sur les 2 premiers axes",
)
# Out:
# <iframe
#     scrolling="no"
#     width="820px"
#     height="620"
#     src="iframe_figures/figure_138.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
show_scatter_graph(
    x=X_pca[:,2],
    y=X_pca[:,3],
    colors=df["category0"],
    title="Projection PCA sur les 2 premiers axes",
)
# Out:
# <iframe
#     scrolling="no"
#     width="820px"
#     height="620"
#     src="iframe_figures/figure_139.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %% [markdown]
# ### Projection tSNE

# %%
tsne = TSNE(n_components=2, random_state=0)
X_embedded = tsne.fit_transform(X)
df_experiments = log_experiment(df_experiments, algo, "cleaned_description", "tSNE", X_embedded, df["category0"])
# Out:
# Silhouette score = -0.01190196443349123

# %%
show_scatter_graph(
    x=X_embedded[:,0],
    y=X_embedded[:,1],
    colors=df["category0"],
    title="Project tSNE de X sur les 2 premiers axes"
)
# Out:
# <iframe
#     scrolling="no"
#     width="820px"
#     height="620"
#     src="iframe_figures/figure_141.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
tsne = TSNE(n_components=2, random_state=0)
X_embedded = tsne.fit_transform(X_pca)
df_experiments = log_experiment(df_experiments, algo, "cleaned_description", "PCA-600 + tSNE", X_embedded, df["category0"])
# Out:
# Silhouette score = 0.01954840123653412

# %%
show_scatter_graph(
    x=X_embedded[:,0],
    y=X_embedded[:,1],
    colors=df["category0"],
    title="Project tSNE de X_pca sur les 2 premiers axes"
)
# Out:
# <iframe
#     scrolling="no"
#     width="820px"
#     height="620"
#     src="iframe_figures/figure_143.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %% [markdown]
# # Utilisation d'un plongement Word2Vec

# %%
from gensim import corpora

# %%
algo = "word2vec"

# %%
df = pd.read_parquet(f"{working_dir}/cleaned.parquet")

# %%
def remove_brand_from(x, col):
    b = x["brand"].lower() if not pd.isna(x["brand"]) else ""
    x[col] = x[col].lower().replace(b, "")
    return x[col]

    
df["cleaned_product_name"] = df.apply(lambda x: clean_text(x, "product_name", tokenizer=tokenizer, lemmatizer=lemmatizer, stemmer=None, stop_words=stop_words2), axis=1)
df["cleaned_description"] = df.apply(lambda x: clean_text(x, "description", tokenizer=tokenizer, lemmatizer=lemmatizer, stemmer=None, stop_words=stop_words2), axis=1)

# %%
df.head()
# Out:
#                             uniq_id            crawl_timestamp
# 0  55b85ea15a1536d46b7190ad6fff8ce7  2016-04-30 03:22:56 +0000  \
# 1  7b72c92c2f6c40268628ec5f14c6d590  2016-04-30 03:22:56 +0000
# 2  64d5d4a258243731dc7bbb1eef49ad74  2016-04-30 03:22:56 +0000
# 3  d4684dcdc759dd9cdf41504698d737d8  2016-06-20 08:49:52 +0000
# 4  6325b6870c54cd47be6ebfbffa620ec7  2016-06-20 08:49:52 +0000
#
#                                          product_url
# 0  http://www.flipkart.com/elegance-polyester-mul...  \
# 1  http://www.flipkart.com/sathiyas-cotton-bath-t...
# 2  http://www.flipkart.com/eurospa-cotton-terry-f...
# 3  http://www.flipkart.com/santosh-royal-fashion-...
# 4  http://www.flipkart.com/jaipur-print-cotton-fl...
#
#                                         product_name
# 0  Elegance Polyester Multicolor Abstract Eyelet ...  \
# 1                         Sathiyas Cotton Bath Towel
# 2                Eurospa Cotton Terry Face Towel Set
# 3  SANTOSH ROYAL FASHION Cotton Printed King size...
# 4  Jaipur Print Cotton Floral King sized Double B...
#
#                                product_category_tree               pid
# 0  ["Home Furnishing >> Curtains & Accessories >>...  CRNEG7BKMFFYHQ8Z  \
# 1  ["Baby Care >> Baby Bath & Skin >> Baby Bath T...  BTWEGFZHGBXPHZUH
# 2  ["Baby Care >> Baby Bath & Skin >> Baby Bath T...  BTWEG6SHXTDB2A2Y
# 3  ["Home Furnishing >> Bed Linen >> Bedsheets >>...  BDSEJT9UQWHDUBH4
# 4  ["Home Furnishing >> Bed Linen >> Bedsheets >>...  BDSEJTHNGWVGWWQU
#
#    retail_price  discounted_price                                 image
# 0        1899.0             899.0  55b85ea15a1536d46b7190ad6fff8ce7.jpg  \
# 1         600.0             449.0  7b72c92c2f6c40268628ec5f14c6d590.jpg
# 2           NaN               NaN  64d5d4a258243731dc7bbb1eef49ad74.jpg
# 3        2699.0            1299.0  d4684dcdc759dd9cdf41504698d737d8.jpg
# 4        2599.0             698.0  6325b6870c54cd47be6ebfbffa620ec7.jpg
#
#    is_FK_Advantage_product                                        description
# 0                    False  Key Features of Elegance Polyester Multicolor ...  \
# 1                    False  Specifications of Sathiyas Cotton Bath Towel (...
# 2                    False  Key Features of Eurospa Cotton Terry Face Towe...
# 3                    False  Key Features of SANTOSH ROYAL FASHION Cotton P...
# 4                    False  Key Features of Jaipur Print Cotton Floral Kin...
#
#         product_rating       overall_rating                  brand
# 0  No rating available  No rating available               Elegance  \
# 1  No rating available  No rating available               Sathiyas
# 2  No rating available  No rating available                Eurospa
# 3  No rating available  No rating available  SANTOSH ROYAL FASHION
# 4  No rating available  No rating available           Jaipur Print
#
#                               product_specifications        category0
# 0  {"product_specification"=>[{"key"=>"Brand", "v...  home furnishing  \
# 1  {"product_specification"=>[{"key"=>"Machine Wa...        baby care
# 2  {"product_specification"=>[{"key"=>"Material",...        baby care
# 3  {"product_specification"=>[{"key"=>"Brand", "v...  home furnishing
# 4  {"product_specification"=>[{"key"=>"Machine Wa...  home furnishing
#
#                                 cleaned_product_name
# 0  polyester multicolor abstract eyelet door curtain  \
# 1                                  cotton bath towel
# 2                            cotton terry face towel
# 3          cotton printed king sized double bedsheet
# 4           cotton floral king sized double bedsheet
#
#                                  cleaned_description
# 0  feature polyester multicolor abstract eyelet d...
# 1  specification cotton bath towel bath towel yel...
# 2  feature cotton terry face towel small cotton t...
# 3  feature cotton printed king sized double bedsh...
# 4  feature cotton floral king sized double bedshe...

# %%
def get_word2vec_val(x, cols):
    t_arr = []
    for col in cols:
        t_arr.append(x[col])
    text = " ".join(t_arr)
    words = gensim.utils.simple_preprocess(" ".join(t_arr))
    _row = []
    v = None
    nb_words = 0
    for word in words:
        if word in model.wv.index_to_key:
            if v is None:
                v = model.wv[word]
            else:
                v = np.add(v, model.wv[word])
    if v is None:
        v = np.zeros(100)
    else:
        v = np.divide(v, len(words))
    return v

# %% [markdown]
# ## Expérience 1
#
# Ici, nous calculons les vecteurs de mots à partir des colonnes cleaned_description et cleaned_product_name et  concatenons cleaned_product_name et cleaned_description pour obtenir un vecteur du document

# %%
data = []
for d in df.cleaned_description.apply(gensim.utils.simple_preprocess):
    d2 = [w for w in d if w not in stop_words]
    if len(d2)>0:
        data.append(d2)
for pn in df.cleaned_product_name.apply(gensim.utils.simple_preprocess):
    pn2 = [w for w in pn if w not in stop_words]
    if len(pn2)>0:
        data.append(pn2)

# %%
model = Word2Vec(
    sentences = data,
    min_count=2,
)

# %%
for i in range(0, 100):
    df[f"wv_{i}"] = np.zeros(df.shape[0])
    
for ind in df.index:
    v = get_word2vec_val(df.loc[ind], ["cleaned_product_name", "cleaned_description"])
    if v is None:
        print(f"""{ind}: {df.loc[ind]["cleaned_product_name"] + " " + df.loc[ind]["cleaned_description"]}""")
        continue
    for i in range(0,100):
        df.at[ind, f"wv_{i}"] = v[i]
# Out:
# /tmp/ipykernel_10841/116275989.py:2: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# /tmp/ipykernel_10841/116275989.py:2: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# /tmp/ipykernel_10841/116275989.py:2: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# /tmp/ipykernel_10841/116275989.py:2: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# /tmp/ipykernel_10841/116275989.py:2: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`

# %%
df = df.copy()
df.head()
# Out:
#                             uniq_id            crawl_timestamp
# 0  55b85ea15a1536d46b7190ad6fff8ce7  2016-04-30 03:22:56 +0000  \
# 1  7b72c92c2f6c40268628ec5f14c6d590  2016-04-30 03:22:56 +0000
# 2  64d5d4a258243731dc7bbb1eef49ad74  2016-04-30 03:22:56 +0000
# 3  d4684dcdc759dd9cdf41504698d737d8  2016-06-20 08:49:52 +0000
# 4  6325b6870c54cd47be6ebfbffa620ec7  2016-06-20 08:49:52 +0000
#
#                                          product_url
# 0  http://www.flipkart.com/elegance-polyester-mul...  \
# 1  http://www.flipkart.com/sathiyas-cotton-bath-t...
# 2  http://www.flipkart.com/eurospa-cotton-terry-f...
# 3  http://www.flipkart.com/santosh-royal-fashion-...
# 4  http://www.flipkart.com/jaipur-print-cotton-fl...
#
#                                         product_name
# 0  Elegance Polyester Multicolor Abstract Eyelet ...  \
# 1                         Sathiyas Cotton Bath Towel
# 2                Eurospa Cotton Terry Face Towel Set
# 3  SANTOSH ROYAL FASHION Cotton Printed King size...
# 4  Jaipur Print Cotton Floral King sized Double B...
#
#                                product_category_tree               pid
# 0  ["Home Furnishing >> Curtains & Accessories >>...  CRNEG7BKMFFYHQ8Z  \
# 1  ["Baby Care >> Baby Bath & Skin >> Baby Bath T...  BTWEGFZHGBXPHZUH
# 2  ["Baby Care >> Baby Bath & Skin >> Baby Bath T...  BTWEG6SHXTDB2A2Y
# 3  ["Home Furnishing >> Bed Linen >> Bedsheets >>...  BDSEJT9UQWHDUBH4
# 4  ["Home Furnishing >> Bed Linen >> Bedsheets >>...  BDSEJTHNGWVGWWQU
#
#    retail_price  discounted_price                                 image
# 0        1899.0             899.0  55b85ea15a1536d46b7190ad6fff8ce7.jpg  \
# 1         600.0             449.0  7b72c92c2f6c40268628ec5f14c6d590.jpg
# 2           NaN               NaN  64d5d4a258243731dc7bbb1eef49ad74.jpg
# 3        2699.0            1299.0  d4684dcdc759dd9cdf41504698d737d8.jpg
# 4        2599.0             698.0  6325b6870c54cd47be6ebfbffa620ec7.jpg
#
#    is_FK_Advantage_product  ...     wv_90     wv_91     wv_92     wv_93
# 0                    False  ...  0.255915  0.230827 -0.094913  0.294713  \
# 1                    False  ...  0.388376  0.282886 -0.138776  0.429660
# 2                    False  ...  0.300842  0.236003 -0.113824  0.347384
# 3                    False  ...  0.319470  0.248611 -0.149940  0.391270
# 4                    False  ...  0.313136  0.257414 -0.146306  0.386546
#
#       wv_94     wv_95     wv_96     wv_97     wv_98     wv_99
# 0  0.170490  0.071449 -0.035346 -0.070845  0.103387 -0.135980
# 1  0.225907  0.082384 -0.046135 -0.099628  0.123822 -0.214524
# 2  0.194206  0.072174 -0.040969 -0.074527  0.103479 -0.162769
# 3  0.153912  0.056323 -0.071362 -0.086196  0.112015 -0.183388
# 4  0.158340  0.059296 -0.070041 -0.084908  0.116797 -0.175564
#
# [5 rows x 118 columns]

# %%
wv_cols = [f"wv_{i}" for i in range(0,100)]

# %%
df["wv_0"]
# Out:
# 0       0.321696
# 1       0.467635
# 2       0.360757
# 3       0.489125
# 4       0.469462
#           ...
# 1045    0.203121
# 1046    0.245258
# 1047   -0.082199
# 1048   -0.136836
# 1049   -0.187096
# Name: wv_0, Length: 1050, dtype: float64

# %%
scaler = MinMaxScaler()
X = scaler.fit_transform(df.loc[:, wv_cols])
df_experiments = log_experiment(df_experiments, algo, "cleaned_product_name + cleaned_description", "None", X, df["category0"])
# Out:
# Silhouette score = 0.012521083667306615

# %% [markdown]
# ### Projection PCA

# %%
pca = PCA(n_components=100)
pca.fit(X)
# Out:
# PCA(n_components=100)

# %%
show_pca_variance_graph(pca)
# Out:
# <iframe
#     scrolling="no"
#     width="820px"
#     height="820"
#     src="iframe_figures/figure_158.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %% [markdown]
# Avec les 8 premières composantes de la PCA, nous avons 99% de la variance totale.

# %%
pca = PCA(n_components=8)

pca.fit(X)
X_pca = pca.transform(X)
df_experiments = log_experiment(df_experiments, algo, "cleaned_product_name + cleaned_description", "PCA-8", X_pca, df["category0"])
# Out:
# Silhouette score = 0.012543479012927896

# %%
show_scatter_graph(
    x=X_pca[:,0],
    y=X_pca[:,1],
    colors=df["category0"],
    title="Projection PCA sur les 2 premiers axes",
)
# Out:
# <iframe
#     scrolling="no"
#     width="820px"
#     height="620"
#     src="iframe_figures/figure_160.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
show_scatter_graph(
    x=X_pca[:,2],
    y=X_pca[:,3],
    colors=df["category0"],
    title="Projection PCA sur les axes 2 et 3",
)
# Out:
# <iframe
#     scrolling="no"
#     width="820px"
#     height="620"
#     src="iframe_figures/figure_161.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %% [markdown]
# ### Projection tSNE

# %%
tsne = TSNE(n_components=2, random_state=0)
X_embedded = tsne.fit_transform(X)
df_experiments = log_experiment(df_experiments, algo, "cleaned_product_name + cleaned_description", "tSNE", X_embedded, df["category0"])
# Out:
# Silhouette score = 0.02957295998930931

# %%
show_scatter_graph(
    x=X_embedded[:,0],
    y=X_embedded[:,1],
    colors=df["category0"],
    title="Project tSNE de X sur les 2 premiers axes"
)
# Out:
# <iframe
#     scrolling="no"
#     width="820px"
#     height="620"
#     src="iframe_figures/figure_163.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
tsne = TSNE(n_components=2, random_state=0)
X_embedded = tsne.fit_transform(X_pca)
df_experiments = log_experiment(df_experiments, algo, "cleaned_product_name + cleaned_description", "PCA-8 + tSNE", X_embedded, df["category0"])
# Out:
# Silhouette score = 0.029972480610013008

# %%
show_scatter_graph(
    x=X_embedded[:,0],
    y=X_embedded[:,1],
    colors=df["category0"],
    title="Project tSNE de X_pca sur les 2 premiers axes"
)
# Out:
# <iframe
#     scrolling="no"
#     width="820px"
#     height="620"
#     src="iframe_figures/figure_165.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %% [markdown]
# ## Expérience 2
#
# Dans ce cas, nous modelisons notre vocabulaire à partir de la colonne cleaned_product_name et calculons notre vecteur de document avec en concatenant cleaned_product_name et cleaned_description

# %%
data = []
for d in df.cleaned_description.apply(gensim.utils.simple_preprocess):
    d2 = [w for w in d if w not in stop_words]
    if len(d2)>0:
        data.append(d2)

# %%
model = Word2Vec(
    sentences = data,
    min_count=2,
)

# %%
for i in range(0, 100):
    df[f"wv_{i}"] = np.zeros(df.shape[0])
    
for ind in df.index:
    v = get_word2vec_val(df.loc[ind], ["cleaned_product_name", "cleaned_description"])
    if v is None:
        print(f"""{ind}: {df.loc[ind]["cleaned_product_name", "cleaned_description"]}""")
        continue
    for i in range(0,100):
        df.at[ind, f"wv_{i}"] = v[i]

# %%
scaler = MinMaxScaler()
X = scaler.fit_transform(df.loc[:, wv_cols])
df_experiments = log_experiment(df_experiments, algo, "cleaned_product_name(fit,transform) + cleaned_description(transform)", "None", X, df["category0"])
# Out:
# Silhouette score = -0.014924006873121176

# %%
X[0]
# Out:
# array([0.82917213, 0.17195002, 0.47491234, 0.24218117, 0.17098779,
#        0.5276086 , 0.0894028 , 0.32673223, 0.72178708, 0.91864301,
#        0.06760102, 0.62648284, 0.10779663, 0.19510272, 0.15190541,
#        0.5246542 , 0.08898752, 0.48136392, 0.77860447, 0.67575337,
#        0.16430158, 0.55881426, 0.10033552, 0.5047232 , 0.36840501,
#        0.21913557, 0.50902259, 0.47257225, 0.52970552, 0.18215356,
#        0.26390309, 0.7221558 , 0.81258258, 0.92075406, 0.83195754,
#        0.38911735, 0.32355636, 0.59502144, 0.79001576, 0.50447083,
#        0.21477475, 0.49283419, 0.77366793, 0.46968894, 0.20020698,
#        0.144893  , 0.7190691 , 0.64206151, 0.52248863, 0.50359759,
#        0.2225817 , 0.79507046, 0.84472725, 0.66951847, 0.83409985,
#        0.51124113, 0.16127455, 0.54831045, 0.61496917, 0.59008733,
#        0.62090973, 0.70536354, 0.16215335, 0.35051441, 0.55375652,
#        0.08108517, 0.49600787, 0.28824084, 0.70018995, 0.1589321 ,
#        0.44012931, 0.42915873, 0.35267676, 0.33313039, 0.50263222,
#        0.643948  , 0.51017977, 0.20087035, 0.65378512, 0.72943527,
#        0.80330704, 0.68908815, 0.49883088, 0.42862908, 0.50362317,
#        0.46126379, 0.09220544, 0.5175405 , 0.4772819 , 0.74304093,
#        0.45162348, 0.2349342 , 0.47149021, 0.59668175, 0.36497507,
#        0.4515749 , 0.21140197, 0.58864426, 0.20882224, 0.31773897])

# %% [markdown]
# ### Projection PCA

# %%
pca = PCA(n_components=100)
pca.fit(X)
show_pca_variance_graph(pca)
# Out:
# <iframe
#     scrolling="no"
#     width="820px"
#     height="820"
#     src="iframe_figures/figure_171.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
pca = PCA(n_components=6)

pca.fit(X)
X_pca = pca.transform(X)
df_experiments = log_experiment(df_experiments, algo, "cleaned_product_name(fit,transform) + cleaned_description(transform)", "PCA-6", X_pca, df["category0"])
# Out:
# Silhouette score = -0.01589337289786265

# %%
show_scatter_graph(
    x=X_pca[:,0],
    y=X_pca[:,1],
    colors=df["category0"],
    title=f"Projection PCA sur les axes 0 et 1",
)
# Out:
# <iframe
#     scrolling="no"
#     width="820px"
#     height="620"
#     src="iframe_figures/figure_173.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
show_scatter_graph(
    x=X_pca[:,2],
    y=X_pca[:,3],
    colors=df["category0"],
    title=f"Projection PCA sur les axes 2 et 3",
)
# Out:
# <iframe
#     scrolling="no"
#     width="820px"
#     height="620"
#     src="iframe_figures/figure_174.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
show_scatter_graph(
    x=X_pca[:,4],
    y=X_pca[:,5],
    colors=df["category0"],
    title=f"Projection PCA sur les axes 4 et 5",
)
# Out:
# <iframe
#     scrolling="no"
#     width="820px"
#     height="620"
#     src="iframe_figures/figure_175.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %% [markdown]
# ### Projection tSNE

# %%
tsne = TSNE(n_components=2, random_state=0)
X_embedded = tsne.fit_transform(X)
df_experiments = log_experiment(df_experiments, algo, "cleaned_product_name(fit,transform) + cleaned_description(transform)", "tSNE", X_embedded, df["category0"])
# Out:
# Silhouette score = 0.016497336328029633

# %%
show_scatter_graph(
    x=X_embedded[:,0],
    y=X_embedded[:,1],
    colors=df["category0"],
    title="Project tSNE de X sur les 2 premiers axes"
)
# Out:
# <iframe
#     scrolling="no"
#     width="820px"
#     height="620"
#     src="iframe_figures/figure_177.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
tsne = TSNE(n_components=2, random_state=0)
X_embedded = tsne.fit_transform(X_pca)
df_experiments = log_experiment(df_experiments, algo, "cleaned_product_name(fit,transform) + cleaned_description(transform)", "PCA-6 + tSNE", X_embedded, df["category0"])
# Out:
# Silhouette score = 0.013381093740463257

# %%
show_scatter_graph(
    x=X_embedded[:,0],
    y=X_embedded[:,1],
    colors=df["category0"],
    title="Project tSNE de X_pca sur les 2 premiers axes"
)
# Out:
# <iframe
#     scrolling="no"
#     width="820px"
#     height="620"
#     src="iframe_figures/figure_179.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %% [markdown]
# ## Expérience 3
#
# Dans ce cas, nous n'utilisons que cleaned_product_name pour calculer nos vecteurs de mots et de documents

# %%
data = []
for d in df.cleaned_product_name.apply(gensim.utils.simple_preprocess):
    d2 = [w for w in d if w not in stop_words]
    if len(d2)>0:
        data.append(d2)

# %%
model = Word2Vec(
    sentences = data,
    min_count=2,
)

# %%
for i in range(0, 100):
    df[f"wv_{i}"] = np.zeros(df.shape[0])
    
for ind in df.index:
    v = get_word2vec_val(df.loc[ind], ["cleaned_product_name"])
    if v is None:
        print(f"""{ind}: {df.loc[ind]["cleaned_product_name"]}""")
        continue
    for i in range(0,100):
        df.at[ind, f"wv_{i}"] = v[i]

# %%
scaler = MinMaxScaler()
X = scaler.fit_transform(df.loc[:, wv_cols])

# %%
df_experiments = log_experiment(df_experiments, algo, "cleaned_product_name", "None", X, df["category0"])
# Out:
# Silhouette score = 0.03624678900196558

# %% [markdown]
# ### Projection PCA

# %%
pca = PCA(n_components=100)
pca.fit(X)
# Out:
# PCA(n_components=100)

# %%
show_pca_variance_graph(pca)
# Out:
# <iframe
#     scrolling="no"
#     width="820px"
#     height="820"
#     src="iframe_figures/figure_186.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
pca = PCA(n_components=50)
pca.fit(X)
# Out:
# PCA(n_components=50)

# %%
X_pca = pca.transform(X)
df_experiments = log_experiment(df_experiments, algo, "cleaned_product_name", "PCA-50", X_pca, df["category0"])
# Out:
# Silhouette score = 0.03255050760763001

# %%
show_scatter_graph(
    x=X_pca[:,0],
    y=X_pca[:,1],
    colors=df["category0"],
    title="Projection PCA sur les 2 premiers axes",
)
# Out:
# <iframe
#     scrolling="no"
#     width="820px"
#     height="620"
#     src="iframe_figures/figure_189.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
show_scatter_graph(
    x=X_pca[:,2],
    y=X_pca[:,3],
    colors=df["category0"],
    title="Projection PCA sur les axes 2 et 3",
)
# Out:
# <iframe
#     scrolling="no"
#     width="820px"
#     height="620"
#     src="iframe_figures/figure_190.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
show_scatter_graph(
    x=X_pca[:,4],
    y=X_pca[:,5],
    colors=df["category0"],
    title="Projection PCA sur les axes 4 et 5",
)
# Out:
# <iframe
#     scrolling="no"
#     width="820px"
#     height="620"
#     src="iframe_figures/figure_191.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %% [markdown]
# ### Projection tSNE

# %%
tsne = TSNE(n_components=2, random_state=0)
X_embedded = tsne.fit_transform(X)
df_experiments = log_experiment(df_experiments, algo, "cleaned_product_name", "tSNE", X_embedded, df["category0"])
# Out:
# Silhouette score = 0.12331737577915192

# %%
show_scatter_graph(
    x=X_embedded[:,0],
    y=X_embedded[:,1],
    colors=df["category0"],
    title="Project tSNE de X sur les 2 premiers axes"
)
# Out:
# <iframe
#     scrolling="no"
#     width="820px"
#     height="620"
#     src="iframe_figures/figure_193.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
tsne = TSNE(n_components=2, random_state=0)
X_embedded = tsne.fit_transform(X_pca)
df_experiments = log_experiment(df_experiments, algo, "cleaned_product_name", "PCA-50 + tSNE", X_embedded, df["category0"])
# Out:
# Silhouette score = 0.1255994290113449

# %%
show_scatter_graph(
    x=X_embedded[:,0],
    y=X_embedded[:,1],
    colors=df["category0"],
    title="Project tSNE de X_pca sur les 2 premiers axes"
)
# Out:
# <iframe
#     scrolling="no"
#     width="820px"
#     height="620"
#     src="iframe_figures/figure_195.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %% [markdown]
# # Utilisation d'un plongement USE (Universal Sentence Encoder)

# %%
algo = "USE"
embed = hub.load("https://tfhub.dev/google/universal-sentence-encoder-large/5")
# Out:
# 2023-05-26 14:48:24.989293: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-05-26 14:48:24.995517: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-05-26 14:48:24.995740: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-05-26 14:48:24.996846: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-05-26 14:48:24.997048: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-05-26 14:48:24.997216: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-05-26 14:48:25.584753: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-05-26 14:48:25.584983: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-05-26 14:48:25.585144: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-05-26 14:48:25.585266: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1635] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 3167 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1050 Ti, pci bus id: 0000:01:00.0, compute capability: 6.1

# %%
df = pd.read_csv("assets/Flipkart/flipkart_com-ecommerce_sample_1050.csv")

# %%
import re

def clean_text_use(x, col, _stop_words):
    brand = x["brand"].lower() if not pd.isna(x["brand"]) else ""
    return x[col].lower().replace(brand, "")
        
df["cleaned_description"] = df.apply(lambda x: clean_text_use(x, "description", stop_words2 + ["key feature", "key features", "buy", "specification", "specifications"]), axis=1)
df["cleaned_product_name"] = df.apply(lambda x: clean_text_use(x, "product_name", stop_words2), axis=1)

# %%
df.head()
# Out:
#                             uniq_id            crawl_timestamp
# 0  55b85ea15a1536d46b7190ad6fff8ce7  2016-04-30 03:22:56 +0000  \
# 1  7b72c92c2f6c40268628ec5f14c6d590  2016-04-30 03:22:56 +0000
# 2  64d5d4a258243731dc7bbb1eef49ad74  2016-04-30 03:22:56 +0000
# 3  d4684dcdc759dd9cdf41504698d737d8  2016-06-20 08:49:52 +0000
# 4  6325b6870c54cd47be6ebfbffa620ec7  2016-06-20 08:49:52 +0000
#
#                                          product_url
# 0  http://www.flipkart.com/elegance-polyester-mul...  \
# 1  http://www.flipkart.com/sathiyas-cotton-bath-t...
# 2  http://www.flipkart.com/eurospa-cotton-terry-f...
# 3  http://www.flipkart.com/santosh-royal-fashion-...
# 4  http://www.flipkart.com/jaipur-print-cotton-fl...
#
#                                         product_name
# 0  Elegance Polyester Multicolor Abstract Eyelet ...  \
# 1                         Sathiyas Cotton Bath Towel
# 2                Eurospa Cotton Terry Face Towel Set
# 3  SANTOSH ROYAL FASHION Cotton Printed King size...
# 4  Jaipur Print Cotton Floral King sized Double B...
#
#                                product_category_tree               pid
# 0  ["Home Furnishing >> Curtains & Accessories >>...  CRNEG7BKMFFYHQ8Z  \
# 1  ["Baby Care >> Baby Bath & Skin >> Baby Bath T...  BTWEGFZHGBXPHZUH
# 2  ["Baby Care >> Baby Bath & Skin >> Baby Bath T...  BTWEG6SHXTDB2A2Y
# 3  ["Home Furnishing >> Bed Linen >> Bedsheets >>...  BDSEJT9UQWHDUBH4
# 4  ["Home Furnishing >> Bed Linen >> Bedsheets >>...  BDSEJTHNGWVGWWQU
#
#    retail_price  discounted_price                                 image
# 0        1899.0             899.0  55b85ea15a1536d46b7190ad6fff8ce7.jpg  \
# 1         600.0             449.0  7b72c92c2f6c40268628ec5f14c6d590.jpg
# 2           NaN               NaN  64d5d4a258243731dc7bbb1eef49ad74.jpg
# 3        2699.0            1299.0  d4684dcdc759dd9cdf41504698d737d8.jpg
# 4        2599.0             698.0  6325b6870c54cd47be6ebfbffa620ec7.jpg
#
#    is_FK_Advantage_product                                        description
# 0                    False  Key Features of Elegance Polyester Multicolor ...  \
# 1                    False  Specifications of Sathiyas Cotton Bath Towel (...
# 2                    False  Key Features of Eurospa Cotton Terry Face Towe...
# 3                    False  Key Features of SANTOSH ROYAL FASHION Cotton P...
# 4                    False  Key Features of Jaipur Print Cotton Floral Kin...
#
#         product_rating       overall_rating                  brand
# 0  No rating available  No rating available               Elegance  \
# 1  No rating available  No rating available               Sathiyas
# 2  No rating available  No rating available                Eurospa
# 3  No rating available  No rating available  SANTOSH ROYAL FASHION
# 4  No rating available  No rating available           Jaipur Print
#
#                               product_specifications
# 0  {"product_specification"=>[{"key"=>"Brand", "v...  \
# 1  {"product_specification"=>[{"key"=>"Machine Wa...
# 2  {"product_specification"=>[{"key"=>"Material",...
# 3  {"product_specification"=>[{"key"=>"Brand", "v...
# 4  {"product_specification"=>[{"key"=>"Machine Wa...
#
#                                  cleaned_description
# 0  key features of  polyester multicolor abstract...  \
# 1  specifications of  cotton bath towel (3 bath t...
# 2  key features of  cotton terry face towel set s...
# 3  key features of  cotton printed king sized dou...
# 4  key features of  cotton floral king sized doub...
#
#                                 cleaned_product_name
# 0   polyester multicolor abstract eyelet door cur...
# 1                                  cotton bath towel
# 2                        cotton terry face towel set
# 3          cotton printed king sized double bedsheet
# 4           cotton floral king sized double bedsheet

# %% [markdown]
# ## Expérience 1
#
# Nous allons créer un vecteur de document à partir de la concaténation de cleaned_product_name et cleaned_description

# %%
df["category0"] = df.apply(lambda x: get_category_level_0(x), axis=1)

# %%
def get_use_vect(s):
    return embed(s)[0].numpy()

df["use_vect"] = df.apply(lambda x: get_use_vect([x.cleaned_product_name + " " + x.cleaned_description]), axis=1)
# Out:
# 2023-05-26 14:48:34.475521: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype string
# 	 [[{{node inputs}}]]

# %%
df.head()
# Out:
#                             uniq_id            crawl_timestamp
# 0  55b85ea15a1536d46b7190ad6fff8ce7  2016-04-30 03:22:56 +0000  \
# 1  7b72c92c2f6c40268628ec5f14c6d590  2016-04-30 03:22:56 +0000
# 2  64d5d4a258243731dc7bbb1eef49ad74  2016-04-30 03:22:56 +0000
# 3  d4684dcdc759dd9cdf41504698d737d8  2016-06-20 08:49:52 +0000
# 4  6325b6870c54cd47be6ebfbffa620ec7  2016-06-20 08:49:52 +0000
#
#                                          product_url
# 0  http://www.flipkart.com/elegance-polyester-mul...  \
# 1  http://www.flipkart.com/sathiyas-cotton-bath-t...
# 2  http://www.flipkart.com/eurospa-cotton-terry-f...
# 3  http://www.flipkart.com/santosh-royal-fashion-...
# 4  http://www.flipkart.com/jaipur-print-cotton-fl...
#
#                                         product_name
# 0  Elegance Polyester Multicolor Abstract Eyelet ...  \
# 1                         Sathiyas Cotton Bath Towel
# 2                Eurospa Cotton Terry Face Towel Set
# 3  SANTOSH ROYAL FASHION Cotton Printed King size...
# 4  Jaipur Print Cotton Floral King sized Double B...
#
#                                product_category_tree               pid
# 0  ["Home Furnishing >> Curtains & Accessories >>...  CRNEG7BKMFFYHQ8Z  \
# 1  ["Baby Care >> Baby Bath & Skin >> Baby Bath T...  BTWEGFZHGBXPHZUH
# 2  ["Baby Care >> Baby Bath & Skin >> Baby Bath T...  BTWEG6SHXTDB2A2Y
# 3  ["Home Furnishing >> Bed Linen >> Bedsheets >>...  BDSEJT9UQWHDUBH4
# 4  ["Home Furnishing >> Bed Linen >> Bedsheets >>...  BDSEJTHNGWVGWWQU
#
#    retail_price  discounted_price                                 image
# 0        1899.0             899.0  55b85ea15a1536d46b7190ad6fff8ce7.jpg  \
# 1         600.0             449.0  7b72c92c2f6c40268628ec5f14c6d590.jpg
# 2           NaN               NaN  64d5d4a258243731dc7bbb1eef49ad74.jpg
# 3        2699.0            1299.0  d4684dcdc759dd9cdf41504698d737d8.jpg
# 4        2599.0             698.0  6325b6870c54cd47be6ebfbffa620ec7.jpg
#
#    is_FK_Advantage_product                                        description
# 0                    False  Key Features of Elegance Polyester Multicolor ...  \
# 1                    False  Specifications of Sathiyas Cotton Bath Towel (...
# 2                    False  Key Features of Eurospa Cotton Terry Face Towe...
# 3                    False  Key Features of SANTOSH ROYAL FASHION Cotton P...
# 4                    False  Key Features of Jaipur Print Cotton Floral Kin...
#
#         product_rating       overall_rating                  brand
# 0  No rating available  No rating available               Elegance  \
# 1  No rating available  No rating available               Sathiyas
# 2  No rating available  No rating available                Eurospa
# 3  No rating available  No rating available  SANTOSH ROYAL FASHION
# 4  No rating available  No rating available           Jaipur Print
#
#                               product_specifications
# 0  {"product_specification"=>[{"key"=>"Brand", "v...  \
# 1  {"product_specification"=>[{"key"=>"Machine Wa...
# 2  {"product_specification"=>[{"key"=>"Material",...
# 3  {"product_specification"=>[{"key"=>"Brand", "v...
# 4  {"product_specification"=>[{"key"=>"Machine Wa...
#
#                                  cleaned_description
# 0  key features of  polyester multicolor abstract...  \
# 1  specifications of  cotton bath towel (3 bath t...
# 2  key features of  cotton terry face towel set s...
# 3  key features of  cotton printed king sized dou...
# 4  key features of  cotton floral king sized doub...
#
#                                 cleaned_product_name        category0
# 0   polyester multicolor abstract eyelet door cur...  home furnishing  \
# 1                                  cotton bath towel        baby care
# 2                        cotton terry face towel set        baby care
# 3          cotton printed king sized double bedsheet  home furnishing
# 4           cotton floral king sized double bedsheet  home furnishing
#
#                                             use_vect
# 0  [-0.0121524725, 0.050306052, 0.020168325, -0.0...
# 1  [-0.0015769581, 0.07231682, -0.06705219, 0.003...
# 2  [-0.06447609, 0.09360065, 0.045228582, 0.00150...
# 3  [-0.04073421, 0.042960763, -0.04055849, 0.0782...
# 4  [0.0043815714, 0.018268155, -0.028277976, 0.04...

# %%
scaler = MinMaxScaler()
X = scaler.fit_transform(df["use_vect"].tolist())
df_experiments = log_experiment(df_experiments, algo, "cleaned_product_name + cleaned_description", "None", X, df["category0"])
# Out:
# Silhouette score = 0.09252713206332097

# %% [markdown]
# ### Projection PCA

# %%
pca = PCA(n_components=512)

pca.fit(df["use_vect"].tolist())
# Out:
# PCA(n_components=512)

# %%
show_pca_variance_graph(pca)
# Out:
# <iframe
#     scrolling="no"
#     width="820px"
#     height="820"
#     src="iframe_figures/figure_205.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
pca = PCA(n_components=200)

X_pca = pca.fit_transform(X)
df_experiments = log_experiment(df_experiments, algo, "cleaned_product_name + cleaned_description", "PCA-200", X_pca, df["category0"])
# Out:
# Silhouette score = 0.0964525086658286

# %%
show_scatter_graph(
    x=X_pca[:,0],
    y=X_pca[:,1],
    colors=df["category0"],
    title="Projection PCA sur les 2 premiers axes",
)
# Out:
# <iframe
#     scrolling="no"
#     width="820px"
#     height="620"
#     src="iframe_figures/figure_207.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
show_scatter_graph(
    x=X_pca[:,2],
    y=X_pca[:,3],
    colors=df["category0"],
    title="Projection PCA sur les axes 2 et 3",
)
# Out:
# <iframe
#     scrolling="no"
#     width="820px"
#     height="620"
#     src="iframe_figures/figure_208.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %% [markdown]
# ### Projection tSNE

# %%
tsne = TSNE(n_components=2, random_state=0)
X_embedded = tsne.fit_transform(np.array(X))
df_experiments = log_experiment(df_experiments, algo, "cleaned_product_name + cleaned_description", "tSNE", X_embedded, df["category0"])
# Out:
# Silhouette score = 0.3008273243904114

# %%
show_scatter_graph(
    x=X_embedded[:,0],
    y=X_embedded[:,1],
    colors=df["category0"],
    title="Project tSNE de X sur les 2 premiers axes"
)
# Out:
# <iframe
#     scrolling="no"
#     width="820px"
#     height="620"
#     src="iframe_figures/figure_210.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
tsne = TSNE(n_components=2, random_state=0)
X_embedded = tsne.fit_transform(X_pca)
df_experiments = log_experiment(df_experiments, algo, "cleaned_product_name + cleaned_description", "PCA-200 + tSNE", X_embedded, df["category0"])
# Out:
# Silhouette score = 0.3009657561779022

# %%
show_scatter_graph(
    x=X_embedded[:,0],
    y=X_embedded[:,1],
    colors=df["category0"],
    title="Project tSNE de X_pca sur les 2 premiers axes"
)
# Out:
# <iframe
#     scrolling="no"
#     width="820px"
#     height="620"
#     src="iframe_figures/figure_212.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %% [markdown]
# ## Expérience 2
#
# Ici on va utiliser la feature cleaned_product_name seule

# %%
df["use_vect"] = df.apply(lambda x: get_use_vect([x.cleaned_product_name]), axis=1)
X = np.array(df["use_vect"].tolist())
scaler = MinMaxScaler()
X = scaler.fit_transform(df["use_vect"].tolist())
df_experiments = log_experiment(df_experiments, algo, "cleaned_product_name", "None", X, df["category0"])
# Out:
# Silhouette score = 0.09908656978807422

# %% [markdown]
# ### Projection PCA

# %%
pca = PCA(n_components=512)
pca.fit(X)
show_pca_variance_graph(pca)
# Out:
# <iframe
#     scrolling="no"
#     width="820px"
#     height="820"
#     src="iframe_figures/figure_214.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
pca = PCA(n_components=200)

X_pca = pca.fit_transform(X)
df_experiments = log_experiment(df_experiments, algo, "cleaned_product_name", "PCA-200", X_pca, df["category0"])
# Out:
# Silhouette score = 0.10386453023827512

# %%
show_scatter_graph(
    x=X_pca[:,0],
    y=X_pca[:,1],
    colors=df["category0"],
    title="Projection PCA sur les 2 premiers axes",
)
# Out:
# <iframe
#     scrolling="no"
#     width="820px"
#     height="620"
#     src="iframe_figures/figure_216.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
show_scatter_graph(
    x=X_pca[:,2],
    y=X_pca[:,3],
    colors=df["category0"],
    title="Projection PCA sur les axes 2 et 3",
)
# Out:
# <iframe
#     scrolling="no"
#     width="820px"
#     height="620"
#     src="iframe_figures/figure_217.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
show_scatter_graph(
    x=X_pca[:,4],
    y=X_pca[:,5],
    colors=df["category0"],
    title="Projection PCA sur les axes 4 et 5",
)
# Out:
# <iframe
#     scrolling="no"
#     width="820px"
#     height="620"
#     src="iframe_figures/figure_218.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %% [markdown]
# ### Projection tSNE

# %%
tsne = TSNE(n_components=2, random_state=0)
X_embedded = tsne.fit_transform(X)
df_experiments = log_experiment(df_experiments, algo, "cleaned_product_name", "tSNE", X_embedded, df["category0"])
# Out:
# Silhouette score = 0.3604941666126251

# %%
show_scatter_graph(
    x=X_embedded[:,0],
    y=X_embedded[:,1],
    colors=df["category0"],
    title="Project tSNE de X"
)
# Out:
# <iframe
#     scrolling="no"
#     width="820px"
#     height="620"
#     src="iframe_figures/figure_220.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
tsne = TSNE(n_components=2, random_state=0)
X_embedded = tsne.fit_transform(np.array(X_pca))
df_experiments = log_experiment(df_experiments, algo, "cleaned_product_name", "PCA-200 + tSNE", X_embedded, df["category0"])
# Out:
# Silhouette score = 0.3695208430290222

# %%
show_scatter_graph(
    x=X_embedded[:,0],
    y=X_embedded[:,1],
    colors=df["category0"],
    title="Project tSNE de X_pca sur les 2 premiers axes"
)
# Out:
# <iframe
#     scrolling="no"
#     width="820px"
#     height="620"
#     src="iframe_figures/figure_222.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %% [markdown]
# ## Expérience 3
#
# Ici on va utiliser la feature cleaned_description seule

# %%
df["use_vect"] = df.apply(lambda x: get_use_vect([x.cleaned_description]), axis=1)
X = np.array(df["use_vect"].tolist())
df_experiments = log_experiment(df_experiments, algo, "cleaned_description", "None", X, df["category0"])
# Out:
# Silhouette score = 0.09138680249452591

# %% [markdown]
# ### Projection PCA

# %%
pca = PCA(n_components=512)
pca.fit(X)
show_pca_variance_graph(pca)
# Out:
# <iframe
#     scrolling="no"
#     width="820px"
#     height="820"
#     src="iframe_figures/figure_224.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
pca = PCA(n_components=200)

X_pca = pca.fit_transform(X)
df_experiments = log_experiment(df_experiments, algo, "cleaned_description", "PCA-200", X_pca, df["category0"])
# Out:
# Silhouette score = 0.09486521780490875

# %%
show_scatter_graph(
    x=X_pca[:,0],
    y=X_pca[:,1],
    colors=df["category0"],
    title="Projection PCA sur les 2 premiers axes",
)
# Out:
# <iframe
#     scrolling="no"
#     width="820px"
#     height="620"
#     src="iframe_figures/figure_226.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
show_scatter_graph(
    x=X_pca[:,2],
    y=X_pca[:,3],
    colors=df["category0"],
    title="Projection PCA sur les axes 2 et 3",
)
# Out:
# <iframe
#     scrolling="no"
#     width="820px"
#     height="620"
#     src="iframe_figures/figure_227.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
show_scatter_graph(
    x=X_pca[:,2],
    y=X_pca[:,3],
    colors=df["category0"],
    title="Projection PCA sur les axes 4 et 5",
)
# Out:
# <iframe
#     scrolling="no"
#     width="820px"
#     height="620"
#     src="iframe_figures/figure_228.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %% [markdown]
# ### Projection tSNE

# %%
tsne = TSNE(n_components=2, random_state=0)
X_embedded = tsne.fit_transform(X)
df_experiments = log_experiment(df_experiments, algo, "cleaned_description", "tSNE", X_embedded, df["category0"])
# Out:
# Silhouette score = 0.2302923947572708

# %%
show_scatter_graph(
    x=X_embedded[:,0],
    y=X_embedded[:,1],
    colors=df["category0"],
    title="Project tSNE de X"
)
# Out:
# <iframe
#     scrolling="no"
#     width="820px"
#     height="620"
#     src="iframe_figures/figure_230.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
tsne = TSNE(n_components=2, random_state=0)
X_embedded = tsne.fit_transform(X_pca)
df_experiments = log_experiment(df_experiments, algo, "cleaned_description", "PCA-200 + tSNE", X_embedded, df["category0"])
# Out:
# Silhouette score = 0.23002611100673676

# %%
show_scatter_graph(
    x=X_embedded[:,0],
    y=X_embedded[:,1],
    colors=df["category0"],
    title="Project tSNE de X_pca"
)
# Out:
# <iframe
#     scrolling="no"
#     width="820px"
#     height="620"
#     src="iframe_figures/figure_232.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %% [markdown]
# # Bert

# %%
algo = "BERT"

# %%
text_input = tf.keras.layers.Input(shape=(), dtype=tf.string)

# %%
preprocessor = hub.KerasLayer("https://tfhub.dev/tensorflow/bert_en_uncased_preprocess/3")
# Out:
# 2023-05-26 14:50:22.786920: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'seq_length' with dtype int32
# 	 [[{{node seq_length}}]]
# 2023-05-26 14:50:22.787624: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'seq_length' with dtype int32
# 	 [[{{node seq_length}}]]
# 2023-05-26 14:50:22.787829: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'seq_length' with dtype int32
# 	 [[{{node seq_length}}]]
# 2023-05-26 14:50:22.788471: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'seq_length' with dtype int32
# 	 [[{{node seq_length}}]]
# 2023-05-26 14:50:22.788730: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'seq_length' with dtype int32
# 	 [[{{node seq_length}}]]
# 2023-05-26 14:50:22.788870: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'seq_length' with dtype int32
# 	 [[{{node seq_length}}]]
# 2023-05-26 14:50:22.789002: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'seq_length' with dtype int32
# 	 [[{{node seq_length}}]]
# 2023-05-26 14:50:22.893376: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'seq_length' with dtype int32
# 	 [[{{node seq_length}}]]
# 2023-05-26 14:50:22.894274: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'seq_length' with dtype int32
# 	 [[{{node seq_length}}]]
# 2023-05-26 14:50:22.894467: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'seq_length' with dtype int32
# 	 [[{{node seq_length}}]]
# 2023-05-26 14:50:22.895324: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'seq_length' with dtype int32
# 	 [[{{node seq_length}}]]
# 2023-05-26 14:50:22.895576: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'seq_length' with dtype int32
# 	 [[{{node seq_length}}]]
# 2023-05-26 14:50:22.895713: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'seq_length' with dtype int32
# 	 [[{{node seq_length}}]]
# 2023-05-26 14:50:22.895848: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'seq_length' with dtype int32
# 	 [[{{node seq_length}}]]
# 2023-05-26 14:50:23.291553: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'seq_length' with dtype int32
# 	 [[{{node seq_length}}]]
# 2023-05-26 14:50:23.291961: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'seq_length' with dtype int32
# 	 [[{{node seq_length}}]]
# 2023-05-26 14:50:23.292093: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'seq_length' with dtype int32
# 	 [[{{node seq_length}}]]
# 2023-05-26 14:50:23.292459: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'seq_length' with dtype int32
# 	 [[{{node seq_length}}]]
# 2023-05-26 14:50:23.292638: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'seq_length' with dtype int32
# 	 [[{{node seq_length}}]]
# 2023-05-26 14:50:23.292741: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'seq_length' with dtype int32
# 	 [[{{node seq_length}}]]
# 2023-05-26 14:50:23.292839: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'seq_length' with dtype int32
# 	 [[{{node seq_length}}]]
# 2023-05-26 14:50:23.462726: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'seq_length' with dtype int32
# 	 [[{{node seq_length}}]]
# 2023-05-26 14:50:23.463236: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'seq_length' with dtype int32
# 	 [[{{node seq_length}}]]
# 2023-05-26 14:50:23.463365: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'seq_length' with dtype int32
# 	 [[{{node seq_length}}]]
# 2023-05-26 14:50:23.463846: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'seq_length' with dtype int32
# 	 [[{{node seq_length}}]]
# 2023-05-26 14:50:23.464022: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'seq_length' with dtype int32
# 	 [[{{node seq_length}}]]
# 2023-05-26 14:50:23.464123: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'seq_length' with dtype int32
# 	 [[{{node seq_length}}]]
# 2023-05-26 14:50:23.464220: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'seq_length' with dtype int32
# 	 [[{{node seq_length}}]]

# %%
encoder_inputs = preprocessor(text_input)
encoder = hub.KerasLayer(
    "https://tfhub.dev/tensorflow/bert_en_uncased_L-12_H-768_A-12/4",
    trainable=True)
outputs = encoder(encoder_inputs)
pooled_output = outputs["pooled_output"]      # [batch_size, 768].
sequence_output = outputs["sequence_output"]  # [batch_size, seq_length, 768].
# Out:
# 2023-05-26 14:50:23.859184: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype string and shape [?]
# 	 [[{{node inputs}}]]
# 2023-05-26 14:50:23.877751: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder' with dtype string and shape [?]
# 	 [[{{node Placeholder}}]]
# 2023-05-26 14:50:30.298172: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype int32 and shape [?,128]
# 	 [[{{node inputs}}]]
# 2023-05-26 14:50:30.298256: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs_2' with dtype int32 and shape [?,128]
# 	 [[{{node inputs_2}}]]
# 2023-05-26 14:50:30.377040: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder_1' with dtype int32 and shape [?,128]
# 	 [[{{node Placeholder_1}}]]
# 2023-05-26 14:50:30.377126: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder_2' with dtype int32 and shape [?,128]
# 	 [[{{node Placeholder_2}}]]

# %%
embedding_model = tf.keras.Model(text_input, pooled_output)

# %%
df = pd.read_csv("assets/Flipkart/flipkart_com-ecommerce_sample_1050.csv")

# %%
def clean_text_bert(x, col):
    brand = x["brand"].lower() if not pd.isna(x["brand"]) else ""
    r = f"""{x[col].lower().replace(brand, "").replace(".", "[SEP]")}"""
    if not r.endswith("[SEP]"):
        r = r + "[SEP]"
    return r
        
df["cleaned_product_name"] = df.apply(lambda x: clean_text_bert(x, "product_name"), axis=1)
df["cleaned_description"] = df.apply(lambda x: clean_text_bert(x, "description"), axis=1)
df["category0"] = df.apply(lambda x: get_category_level_0(x), axis=1)

# %%
df.head()
# Out:
#                             uniq_id            crawl_timestamp
# 0  55b85ea15a1536d46b7190ad6fff8ce7  2016-04-30 03:22:56 +0000  \
# 1  7b72c92c2f6c40268628ec5f14c6d590  2016-04-30 03:22:56 +0000
# 2  64d5d4a258243731dc7bbb1eef49ad74  2016-04-30 03:22:56 +0000
# 3  d4684dcdc759dd9cdf41504698d737d8  2016-06-20 08:49:52 +0000
# 4  6325b6870c54cd47be6ebfbffa620ec7  2016-06-20 08:49:52 +0000
#
#                                          product_url
# 0  http://www.flipkart.com/elegance-polyester-mul...  \
# 1  http://www.flipkart.com/sathiyas-cotton-bath-t...
# 2  http://www.flipkart.com/eurospa-cotton-terry-f...
# 3  http://www.flipkart.com/santosh-royal-fashion-...
# 4  http://www.flipkart.com/jaipur-print-cotton-fl...
#
#                                         product_name
# 0  Elegance Polyester Multicolor Abstract Eyelet ...  \
# 1                         Sathiyas Cotton Bath Towel
# 2                Eurospa Cotton Terry Face Towel Set
# 3  SANTOSH ROYAL FASHION Cotton Printed King size...
# 4  Jaipur Print Cotton Floral King sized Double B...
#
#                                product_category_tree               pid
# 0  ["Home Furnishing >> Curtains & Accessories >>...  CRNEG7BKMFFYHQ8Z  \
# 1  ["Baby Care >> Baby Bath & Skin >> Baby Bath T...  BTWEGFZHGBXPHZUH
# 2  ["Baby Care >> Baby Bath & Skin >> Baby Bath T...  BTWEG6SHXTDB2A2Y
# 3  ["Home Furnishing >> Bed Linen >> Bedsheets >>...  BDSEJT9UQWHDUBH4
# 4  ["Home Furnishing >> Bed Linen >> Bedsheets >>...  BDSEJTHNGWVGWWQU
#
#    retail_price  discounted_price                                 image
# 0        1899.0             899.0  55b85ea15a1536d46b7190ad6fff8ce7.jpg  \
# 1         600.0             449.0  7b72c92c2f6c40268628ec5f14c6d590.jpg
# 2           NaN               NaN  64d5d4a258243731dc7bbb1eef49ad74.jpg
# 3        2699.0            1299.0  d4684dcdc759dd9cdf41504698d737d8.jpg
# 4        2599.0             698.0  6325b6870c54cd47be6ebfbffa620ec7.jpg
#
#    is_FK_Advantage_product                                        description
# 0                    False  Key Features of Elegance Polyester Multicolor ...  \
# 1                    False  Specifications of Sathiyas Cotton Bath Towel (...
# 2                    False  Key Features of Eurospa Cotton Terry Face Towe...
# 3                    False  Key Features of SANTOSH ROYAL FASHION Cotton P...
# 4                    False  Key Features of Jaipur Print Cotton Floral Kin...
#
#         product_rating       overall_rating                  brand
# 0  No rating available  No rating available               Elegance  \
# 1  No rating available  No rating available               Sathiyas
# 2  No rating available  No rating available                Eurospa
# 3  No rating available  No rating available  SANTOSH ROYAL FASHION
# 4  No rating available  No rating available           Jaipur Print
#
#                               product_specifications
# 0  {"product_specification"=>[{"key"=>"Brand", "v...  \
# 1  {"product_specification"=>[{"key"=>"Machine Wa...
# 2  {"product_specification"=>[{"key"=>"Material",...
# 3  {"product_specification"=>[{"key"=>"Brand", "v...
# 4  {"product_specification"=>[{"key"=>"Machine Wa...
#
#                                 cleaned_product_name
# 0   polyester multicolor abstract eyelet door cur...  \
# 1                             cotton bath towel[SEP]
# 2                   cotton terry face towel set[SEP]
# 3     cotton printed king sized double bedsheet[SEP]
# 4      cotton floral king sized double bedsheet[SEP]
#
#                                  cleaned_description        category0
# 0  key features of  polyester multicolor abstract...  home furnishing
# 1  specifications of  cotton bath towel (3 bath t...        baby care
# 2  key features of  cotton terry face towel set s...        baby care
# 3  key features of  cotton printed king sized dou...  home furnishing
# 4  key features of  cotton floral king sized doub...  home furnishing

# %% [markdown]
# ## Expérience 1

# %%
def get_bert_vect(s):
    sentences = tf.constant([s])
    return embedding_model(sentences)[0].numpy()

df["bert_vect"] = df.apply(lambda x: get_bert_vect(["[CLS]" + x.cleaned_product_name + "[SEP]" +  x.cleaned_description]), axis=1)

# %%
X = df["bert_vect"].tolist()
df_experiments = log_experiment(df_experiments, algo, "cleaned_product_name + cleaned_description", "None", X, df["category0"])
# Out:
# Silhouette score = -0.033369649201631546

# %% [markdown]
# ### Projection PCA

# %%
pca = PCA(n_components=768)

pca.fit(X)
# Out:
# PCA(n_components=768)

# %%
show_pca_variance_graph(pca)
# Out:
# <iframe
#     scrolling="no"
#     width="820px"
#     height="820"
#     src="iframe_figures/figure_244.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
pca = PCA(n_components=100)
X_pca = pca.fit_transform(X)
df_experiments = log_experiment(df_experiments, algo, "cleaned_product_name + cleaned_description", "PCA-100", X_pca, df["category0"])
# Out:
# Silhouette score = -0.03291826838213285

# %%
show_scatter_graph(
    x=X_pca[:,0],
    y=X_pca[:,1],
    colors=df["category0"],
    title="Projection PCA sur les 2 premiers axes",
)
# Out:
# <iframe
#     scrolling="no"
#     width="820px"
#     height="620"
#     src="iframe_figures/figure_246.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
show_scatter_graph(
    x=X_pca[:,2],
    y=X_pca[:,3],
    colors=df["category0"],
    title="Projection PCA sur les axes 2 et 3",
)
# Out:
# <iframe
#     scrolling="no"
#     width="820px"
#     height="620"
#     src="iframe_figures/figure_247.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %% [markdown]
# ### Projection tSNE

# %%
tsne = TSNE(n_components=2, random_state=0)
X_embedded = tsne.fit_transform(np.array(X))
df_experiments = log_experiment(df_experiments, algo, "cleaned_product_name + cleaned_description", "tSNE", X_embedded, df["category0"])
# Out:
# Silhouette score = -0.04440812021493912

# %%
tsne = TSNE(n_components=2, random_state=0)
X_embedded = tsne.fit_transform(np.array(X_pca))
df_experiments = log_experiment(df_experiments, algo, "cleaned_product_name + cleaned_description", "PCA-100 + tSNE", X_embedded, df["category0"])
# Out:
# Silhouette score = -0.04144354537129402

# %% [markdown]
# ## Expérience 2
#
# Ici on va utiliser la feature cleaned_product_name seule

# %%
df["bert_vect"] = df.apply(lambda x: get_bert_vect(["[CLS]" + x.cleaned_product_name]), axis=1)
X = df["bert_vect"].tolist()
df_experiments = log_experiment(df_experiments, algo, "cleaned_product_name", "None", X, df["category0"])
# Out:
# Silhouette score = 0.015190399251878262

# %% [markdown]
# ### Projection PCA

# %%
pca = PCA(n_components=768)
pca.fit(X)
show_pca_variance_graph(pca)
# Out:
# <iframe
#     scrolling="no"
#     width="820px"
#     height="820"
#     src="iframe_figures/figure_251.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
pca = PCA(n_components=100)

X_pca = pca.fit_transform(X)
df_experiments = log_experiment(df_experiments, algo, "cleaned_product_name", "PCA-100", X_pca, df["category0"])
# Out:
# Silhouette score = 0.0158794694024108

# %%
show_scatter_graph(
    x=X_pca[:,0],
    y=X_pca[:,1],
    colors=df["category0"],
    title="Projection PCA sur les 2 premiers axes",
)
# Out:
# <iframe
#     scrolling="no"
#     width="820px"
#     height="620"
#     src="iframe_figures/figure_253.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %% [markdown]
# ### Projection tSNE

# %%
tsne = TSNE(n_components=2, random_state=0)
X_embedded = tsne.fit_transform(np.array(X))
df_experiments = log_experiment(df_experiments, algo, "cleaned_product_name", "tSNE", X_embedded, df["category0"])
# Out:
# Silhouette score = 0.02609102614223957

# %%
tsne = TSNE(n_components=2, random_state=0)
X_embedded = tsne.fit_transform(np.array(X_pca))
df_experiments = log_experiment(df_experiments, algo, "cleaned_product_name", "PCA-100 + tSNE", X_embedded, df["category0"])
# Out:
# Silhouette score = 0.027066148817539215

# %% [markdown]
# ## Expérience 3
#
# Ici on va utiliser la feature cleaned_description seule

# %%
df["bert_vect"] = df.apply(lambda x: get_bert_vect(["[CLS]" + x.cleaned_description]), axis=1)
X = df["bert_vect"].tolist()
df_experiments = log_experiment(df_experiments, algo, "cleaned_description", "None", X, df["category0"])
# Out:
# Silhouette score = -0.041214194148778915

# %% [markdown]
# ### Projection PCA

# %%
pca = PCA(n_components=768)
pca.fit(X)
show_pca_variance_graph(pca)
# Out:
# <iframe
#     scrolling="no"
#     width="820px"
#     height="820"
#     src="iframe_figures/figure_257.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
pca = PCA(n_components=100)
X_pca = pca.fit_transform(X)
df_experiments = log_experiment(df_experiments, algo, "cleaned_description", "PCA-100", X_pca, df["category0"])
# Out:
# Silhouette score = -0.04079406516291461

# %% [markdown]
# ### Projection tSNE

# %%
tsne = TSNE(n_components=2, random_state=0)
X_embedded = tsne.fit_transform(np.array(X))
df_experiments = log_experiment(df_experiments, algo, "cleaned_description", "tSNE", X_embedded, df["category0"])
# Out:
# Silhouette score = -0.02301255241036415

# %%
tsne = TSNE(n_components=2, random_state=0)
X_embedded = tsne.fit_transform(np.array(X_pca))
df_experiments = log_experiment(df_experiments, algo, "cleaned_description", "PCA-100 + tSNE", X_embedded, df["category0"])
# Out:
# Silhouette score = -0.02225908823311329

# %%
df_experiments.to_parquet(f"{working_dir}/df_experiments.parquet")

# %% [markdown]
# # Conclusion

# %%
df_experiments.sort_values("silhouette", ascending=False).head(50)
# Out:
#           algorithm                                          used_text
# 53              USE                               cleaned_product_name  \
# 52              USE                               cleaned_product_name
# 49              USE         cleaned_product_name + cleaned_description
# 48              USE         cleaned_product_name + cleaned_description
# 56              USE                                cleaned_description
# 57              USE                                cleaned_description
# 45         word2vec                               cleaned_product_name
# 44         word2vec                               cleaned_product_name
# 51              USE                               cleaned_product_name
# 50              USE                               cleaned_product_name
# 47              USE         cleaned_product_name + cleaned_description
# 55              USE                                cleaned_description
# 46              USE         cleaned_product_name + cleaned_description
# 54              USE                                cleaned_description
# 27            TfIdf  cleaned_product_name(fit,transform) + cleaned_...
# 4   CountVectorizer         cleaned_product_name + cleaned_description
# 16  CountVectorizer                                cleaned_description
# 22            TfIdf         cleaned_product_name + cleaned_description
# 9   CountVectorizer  cleaned_product_name(fit,transform) + cleaned_...
# 10  CountVectorizer  cleaned_product_name(fit,transform) + cleaned_...
# 42         word2vec                               cleaned_product_name
# 43         word2vec                               cleaned_product_name
# 21            TfIdf         cleaned_product_name + cleaned_description
# 3   CountVectorizer         cleaned_product_name + cleaned_description
# 37         word2vec         cleaned_product_name + cleaned_description
# 36         word2vec         cleaned_product_name + cleaned_description
# 65             BERT                               cleaned_product_name
# 64             BERT                               cleaned_product_name
# 13  CountVectorizer                                cleaned_description
# 12  CountVectorizer                                cleaned_description
# 33            TfIdf                                cleaned_description
# 31            TfIdf                                cleaned_description
# 30            TfIdf                                cleaned_description
# 40         word2vec  cleaned_product_name(fit,transform) + cleaned_...
# 28            TfIdf  cleaned_product_name(fit,transform) + cleaned_...
# 63             BERT                               cleaned_product_name
# 15  CountVectorizer                                cleaned_description
# 62             BERT                               cleaned_product_name
# 41         word2vec  cleaned_product_name(fit,transform) + cleaned_...
# 35         word2vec         cleaned_product_name + cleaned_description
# 34         word2vec         cleaned_product_name + cleaned_description
# 25            TfIdf  cleaned_product_name(fit,transform) + cleaned_...
# 24            TfIdf  cleaned_product_name(fit,transform) + cleaned_...
# 8   CountVectorizer  cleaned_product_name(fit,transform) + cleaned_...
# 14  CountVectorizer                                cleaned_description
# 20            TfIdf         cleaned_product_name + cleaned_description
# 2   CountVectorizer         cleaned_product_name + cleaned_description
# 32            TfIdf                                cleaned_description
# 38         word2vec  cleaned_product_name(fit,transform) + cleaned_...
# 39         word2vec  cleaned_product_name(fit,transform) + cleaned_...
#
#         projection  silhouette
# 53  PCA-200 + tSNE    0.369521
# 52            tSNE    0.360494
# 49  PCA-200 + tSNE    0.300966
# 48            tSNE    0.300827
# 56            tSNE    0.230292
# 57  PCA-200 + tSNE    0.230026
# 45   PCA-50 + tSNE    0.125599
# 44            tSNE    0.123317
# 51         PCA-200    0.103865
# 50            None    0.099087
# 47         PCA-200    0.096453
# 55         PCA-200    0.094865
# 46            None    0.092527
# 54            None    0.091387
# 27            tSNE    0.070875
# 4    PCA-623+ tSNE    0.057414
# 16  PCA-560 + tSNE    0.057138
# 22  PCA-620 + tSNE    0.051414
# 9             tSNE    0.044785
# 10  PCA-590 + tSNE    0.044317
# 42            None    0.036247
# 43          PCA-50    0.032551
# 21            tSNE    0.031903
# 3             tSNE    0.031903
# 37    PCA-8 + tSNE    0.029972
# 36            tSNE    0.029573
# 65  PCA-100 + tSNE    0.027066
# 64            tSNE    0.026091
# 13         PCA-560    0.024790
# 12            None    0.024019
# 33  PCA-600 + tSNE    0.019548
# 31         PCA-600    0.018497
# 30            None    0.018067
# 40            tSNE    0.016497
# 28  PCA-700 + tSNE    0.016197
# 63         PCA-100    0.015879
# 15            tSNE    0.015636
# 62            None    0.015190
# 41    PCA-6 + tSNE    0.013381
# 35           PCA-8    0.012543
# 34            None    0.012521
# 25         PCA-700    0.011521
# 24            None    0.011375
# 8              LDA    0.002372
# 14             LDA   -0.003718
# 20             LDA   -0.004601
# 2              LDA   -0.004601
# 32            tSNE   -0.011902
# 38            None   -0.014924
# 39           PCA-6   -0.015893

# %% [markdown]
# Effectuons une clusterisation non supervisée sur le cas USE / cleaned_product_name / PCA-200 + tSNE

# %%
df["cleaned_description"] = df.apply(lambda x: clean_text_use(x, "description", stop_words2 + ["key feature", "key features", "buy", "specification", "specifications"]), axis=1)
df["cleaned_product_name"] = df.apply(lambda x: clean_text_use(x, "product_name", stop_words2), axis=1)
df["category0"] = df.apply(lambda x: get_category_level_0(x), axis=1)

df["use_vect"] = df.apply(lambda x: get_use_vect([x.cleaned_product_name]), axis=1)
X = np.array(df["use_vect"].tolist())
scaler = MinMaxScaler()
X = scaler.fit_transform(df["use_vect"].tolist())

pca = PCA(n_components=200)
X_pca = pca.fit_transform(X)

tsne = TSNE(n_components=2, random_state=0)
X_embedded = tsne.fit_transform(np.array(X_pca))

# %%
kmeans = KMeans(n_clusters=7, init="k-means++", random_state=0, n_init="auto")
visualizer = SilhouetteVisualizer(kmeans)

visualizer.fit(X_embedded)  # Fit the data to the visualizer
visualizer.poof()  # Draw/show/poof the data
# Out:
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# <Axes: title={'center': 'Silhouette Plot of KMeans Clustering for 1050 Samples in 7 Centers'}, xlabel='silhouette coefficient values', ylabel='cluster label'>

# %%
df["kmeans_label"] = kmeans.labels_.astype(str)

# %%
ari_score = adjusted_rand_score(df["category0"], kmeans.labels_)

# %%
print(ari_score)
# Out:
# 0.6527944357381641

# %%
show_scatter_graph(
    x=X_embedded[:,0],
    y=X_embedded[:,1],
    colors=df["kmeans_label"],
    title="Projection tSNE de X-PCA (200 composants) avec USE sur cleaned_product_name <br>avec partitionnement Kmeans"
)
# Out:
# <iframe
#     scrolling="no"
#     width="820px"
#     height="620"
#     src="iframe_figures/figure_268.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
show_scatter_graph(
    x=X_embedded[:,0],
    y=X_embedded[:,1],
    colors=df["category0"],
    title="Projection tSNE de X-PCA (200 composants) avec USE sur cleaned_product_name <br>avec catégorie de produit"
)
# Out:
# <iframe
#     scrolling="no"
#     width="820px"
#     height="620"
#     src="iframe_figures/figure_269.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
pd.crosstab(df["category0"], df["kmeans_label"])
# Out:
# kmeans_label                  0    1    2    3    4    5   6
# category0
# baby care                     6   30    1    0    3   22  88
# beauty and personal care    137    1    0    2    4    5   1
# computers                     0    0  123    0   25    2   0
# home decor & festive needs    0    6   10    3  108   23   0
# home furnishing               0  145    0    0    4    1   0
# kitchen & dining              0    1   28    0    9  111   1
# watches                       0    0    0  150    0    0   0

# %% [markdown]
# En regardant les classes kmeans_labels majoritaires, on voit les correspondances:
#
# |classe kmeans|classe réelle majoritaire|
# |--------------|-------------|
# |0|beauty and personal care|
# |1|home furnishing|
# |2|computers|
# |3|watches |
# |4|home decor & festive needs|
# |5|kitchen & dining|
# |6|baby care|

# %%
from matplotlib import rc

rc('text', usetex=False)
rc('font', **{'family': 'serif', 'serif': ['cmr10']})

# %%
df["category_pred"] = ""

corr_labels = [
    "beauty and personal care",
    "home furnishing",
    "computers",
    "watches",
    "home decor & festive needs",
    "kitchen & dining",
    "baby care",
]

for i in range(0, len(corr_labels)):
    df.loc[df["kmeans_label"]==f"{i}", "category_pred"] = corr_labels[i]


conf_mat = confusion_matrix(df["category0"], df["category_pred"])

df_cm = pd.DataFrame(conf_mat, index = pd.crosstab(df["category0"], df["kmeans_label"]).reset_index()["category0"],
                  columns = [i for i in "0123456"])
plt.figure(figsize = (6,4))
sns.heatmap(df_cm, annot=True, cmap="Blues")
# Out:
# /home/jupyter/.local/lib/python3.8/site-packages/seaborn/matrix.py:456: UserWarning:
#
# cmr10 font should ideally be used with mathtext, set axes.formatter.use_mathtext to True
#
# /home/jupyter/.local/lib/python3.8/site-packages/seaborn/matrix.py:316: UserWarning:
#
# cmr10 font should ideally be used with mathtext, set axes.formatter.use_mathtext to True
# <Axes: ylabel='category0'>

# %%
print(classification_report(df["category0"], df["category_pred"]))
# Out:
#                             precision    recall  f1-score   support
#
#                  baby care       0.98      0.59      0.73       150
#   beauty and personal care       0.96      0.91      0.94       150
#                  computers       0.76      0.82      0.79       150
# home decor & festive needs       0.71      0.72      0.71       150
#            home furnishing       0.79      0.97      0.87       150
#           kitchen & dining       0.68      0.74      0.71       150
#                    watches       0.97      1.00      0.98       150
#
#                   accuracy                           0.82      1050
#                  macro avg       0.83      0.82      0.82      1050
#               weighted avg       0.83      0.82      0.82      1050

# %% [markdown]
# Avec la classification à partir du plongement USE / cleaned_product_name / PCA-200 + tSNE, nous obtenons des résultats tout à fait acceptables.
#
# L'utilisation de l'algorithme USE auquel on ajouterait une couche de décision est à envisager pour obtenir un classifieur à partir du texte fourni. On peut aussi envisager un classifieur du genre SVM et comparer les résultats.
