# %%
# !pip install --upgrade pip
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pip in /home/jupyter/.local/lib/python3.8/site-packages (23.1.2)

# %%
# !pip install fastparquet
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: fastparquet in /home/jupyter/.local/lib/python3.8/site-packages (2023.4.0)
# Requirement already satisfied: pandas>=1.5.0 in /home/jupyter/.local/lib/python3.8/site-packages (from fastparquet) (2.0.1)
# Requirement already satisfied: numpy>=1.20.3 in /usr/local/lib/python3.8/dist-packages (from fastparquet) (1.23.5)
# Requirement already satisfied: cramjam>=2.3 in /home/jupyter/.local/lib/python3.8/site-packages (from fastparquet) (2.6.2)
# Requirement already satisfied: fsspec in /home/jupyter/.local/lib/python3.8/site-packages (from fastparquet) (2023.5.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.8/dist-packages (from fastparquet) (23.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/jupyter/.local/lib/python3.8/site-packages (from pandas>=1.5.0->fastparquet) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/jupyter/.local/lib/python3.8/site-packages (from pandas>=1.5.0->fastparquet) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in /home/jupyter/.local/lib/python3.8/site-packages (from pandas>=1.5.0->fastparquet) (2023.3)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.8.2->pandas>=1.5.0->fastparquet) (1.14.0)

# %%
# !pip install pathvalidate
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pathvalidate in /home/jupyter/.local/lib/python3.8/site-packages (3.0.0)

# %%
# !pip install plot_keras_history
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: plot_keras_history in /home/jupyter/.local/lib/python3.8/site-packages (1.1.38)
# Requirement already satisfied: matplotlib in /home/jupyter/.local/lib/python3.8/site-packages (from plot_keras_history) (3.7.1)
# Requirement already satisfied: pandas in /home/jupyter/.local/lib/python3.8/site-packages (from plot_keras_history) (2.0.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.8/dist-packages (from plot_keras_history) (1.10.1)
# Requirement already satisfied: support-developer>=1.0.2 in /home/jupyter/.local/lib/python3.8/site-packages (from plot_keras_history) (1.0.5)
# Requirement already satisfied: sanitize-ml-labels>=1.0.48 in /home/jupyter/.local/lib/python3.8/site-packages (from plot_keras_history) (1.0.50)
# Requirement already satisfied: compress-json in /home/jupyter/.local/lib/python3.8/site-packages (from sanitize-ml-labels>=1.0.48->plot_keras_history) (1.0.8)
# Requirement already satisfied: contourpy>=1.0.1 in /home/jupyter/.local/lib/python3.8/site-packages (from matplotlib->plot_keras_history) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in /home/jupyter/.local/lib/python3.8/site-packages (from matplotlib->plot_keras_history) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /home/jupyter/.local/lib/python3.8/site-packages (from matplotlib->plot_keras_history) (4.39.4)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/jupyter/.local/lib/python3.8/site-packages (from matplotlib->plot_keras_history) (1.4.4)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.8/dist-packages (from matplotlib->plot_keras_history) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.8/dist-packages (from matplotlib->plot_keras_history) (23.0)
# Requirement already satisfied: pillow>=6.2.0 in /home/jupyter/.local/lib/python3.8/site-packages (from matplotlib->plot_keras_history) (9.5.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/jupyter/.local/lib/python3.8/site-packages (from matplotlib->plot_keras_history) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /home/jupyter/.local/lib/python3.8/site-packages (from matplotlib->plot_keras_history) (2.8.2)
# Requirement already satisfied: importlib-resources>=3.2.0 in /home/jupyter/.local/lib/python3.8/site-packages (from matplotlib->plot_keras_history) (5.12.0)
# Requirement already satisfied: pytz>=2020.1 in /home/jupyter/.local/lib/python3.8/site-packages (from pandas->plot_keras_history) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in /home/jupyter/.local/lib/python3.8/site-packages (from pandas->plot_keras_history) (2023.3)
# Requirement already satisfied: zipp>=3.1.0 in /usr/local/lib/python3.8/dist-packages (from importlib-resources>=3.2.0->matplotlib->plot_keras_history) (3.15.0)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.7->matplotlib->plot_keras_history) (1.14.0)

# %%
import pandas as pd
import numpy as np

import tensorflow as tf
import os
import shutil
import time
from pathvalidate import sanitize_filename
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report

from plot_keras_history import show_history, plot_history

import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# 2023-06-01 16:32:41.518474: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
batch_size = 32

# %% [markdown]
# # Préparation des données

# %% [markdown]
# On commence par préparer le dossier d'images. En effet, toutes les images sont mélangées dans le même dossier, or la fonction que nous allons utiliser
# tf.keras.utils.image_dataset_from_directory s'attend à un sous-répertoire par catégorie

# %%
df = pd.read_parquet("../../etude_classification_texte/working/cleaned.parquet")
df_train = pd.read_parquet("../df_train.parquet")
df_test = pd.read_parquet("../df_test.parquet")

# %%
df_train
# Out:
#                                 uniq_id            crawl_timestamp
# index
# 240    7e4c1d31e279a700c6b8e66d820e8601  2015-12-01 12:40:44 +0000  \
# 516    d77279c8268e231b685cdbaf299e83f2  2016-01-07 05:50:25 +0000
# 117    be09f5a3a88ac10ae14c791fc8ac0dae  2016-01-03 09:39:44 +0000
# 739    52877a6306aef18af67ab54c8233c931  2016-04-21 16:46:08 +0000
# 882    a6c820b76bc29bbe2d85eecad3de03f8  2015-12-20 08:26:17 +0000
# ...                                 ...                        ...
# 750    a18d4ddb1a1c3463d6719e526573c4ba  2015-12-12 11:46:53 +0000
# 44     8050d31bffe6827c804b8222338aafb2  2016-03-20 14:44:44 +0000
# 674    2bf0ca6d25501c067cd12a2a4939443f  2015-12-31 09:19:31 +0000
# 910    23b0bdd337f7d1b4b70ad13726a122ab  2016-04-02 19:26:28 +0000
# 172    c5590e238d44b370337624f5987fb9b8  2015-12-01 12:40:44 +0000
#
#                                              product_url
# index
# 240    http://www.flipkart.com/kosher-kadhai-5-l/p/it...  \
# 516    http://www.flipkart.com/sonata-7016ym09-watch/...
# 117    http://www.flipkart.com/anthill-baby-boy-s-gir...
# 739    http://www.flipkart.com/buyer-s-beach-bb349/p/...
# 882    http://www.flipkart.com/mandhania-cotton-bath-...
# ...                                                  ...
# 750    http://www.flipkart.com/rajasthan-crafts-abstr...
# 44     http://www.flipkart.com/akup-i-loves-music-cer...
# 674    http://www.flipkart.com/home-fashion-gallery-p...
# 910    http://www.flipkart.com/beebay-baby-boy-s-chec...
# 172    http://www.flipkart.com/rockmantra-abstrcts-8-...
#
#                                             product_name
# index
# 240                                    Kosher Kadhai 5 L  \
# 516                                Sonata 7016YM09 Watch
# 117             Anthill Baby Boy's, Baby Girl's Bodysuit
# 739                                  Buyer's Beach BB349
# 882                          Mandhania Cotton Bath Towel
# ...                                                  ...
# 750    Rajasthan Crafts Abstract Single Quilts & Comf...
# 44                        AKUP i-loves-music Ceramic Mug
# 674    Home Fashion Gallery Polyester Black Plain Eye...
# 910             Beebay Baby Boy's Checkered Casual Shirt
# 172                    Rockmantra Abstrcts 8 Ceramic Mug
#
#                                    product_category_tree               pid
# index
# 240    ["Kitchen & Dining >> Cookware >> Pots & Pans ...  PTPEANCHNPTDUUQK  \
# 516    ["Watches >> Wrist Watches >> Sonata Wrist Wat...  WATDZ2ZQK6VS9DB4
# 117    ["Baby Care >> Infant Wear >> Baby Boys' Cloth...  BOLEDQ9GWZHESQF8
# 739    ["Kitchen & Dining >> Dinnerware & Crockery >>...  CNSEHWGRNCSHGNPC
# 882          ["Home Furnishing >> Bath Linen >> Towels"]  BTWE5QUGZHGG8YZH
# ...                                                  ...               ...
# 750    ["Home Furnishing >> Bed Linen >> Blankets, Qu...  BLAE8YHUYQG5JBBF
# 44     ["Kitchen & Dining >> Coffee Mugs >> AKUP Coff...  MUGEGZUHVZ4Y85DV
# 674    ["Home Furnishing >> Curtains & Accessories >>...  CRNECSYF7U72GEQH
# 910    ["Baby Care >> Infant Wear >> Baby Boys' Cloth...  SHTEFGG5HZYKCFTT
# 172    ["Kitchen & Dining >> Coffee Mugs >> Rockmantr...  MUGEAGGKJFVYQGDF
#
#        retail_price  discounted_price                                 image
# index
# 240           592.0             592.0  7e4c1d31e279a700c6b8e66d820e8601.jpg  \
# 516           968.0             968.0  d77279c8268e231b685cdbaf299e83f2.jpg
# 117           405.0             405.0  be09f5a3a88ac10ae14c791fc8ac0dae.jpg
# 739           999.0             449.0  52877a6306aef18af67ab54c8233c931.jpg
# 882           490.0             280.0  a6c820b76bc29bbe2d85eecad3de03f8.jpg
# ...             ...               ...                                   ...
# 750           950.0             840.0  a18d4ddb1a1c3463d6719e526573c4ba.jpg
# 44            500.0             259.0  8050d31bffe6827c804b8222338aafb2.jpg
# 674          2498.0            1499.0  2bf0ca6d25501c067cd12a2a4939443f.jpg
# 910           845.0             845.0  23b0bdd337f7d1b4b70ad13726a122ab.jpg
# 172           499.0             199.0  c5590e238d44b370337624f5987fb9b8.jpg
#
#        is_FK_Advantage_product
# index
# 240                      False  \
# 516                      False
# 117                      False
# 739                      False
# 882                      False
# ...                        ...
# 750                      False
# 44                       False
# 674                      False
# 910                      False
# 172                      False
#
#                                              description       product_rating
# index
# 240    Buy Kosher Kadhai 5 L for Rs.592 online. Koshe...  No rating available  \
# 516    Sonata 7016YM09 Watch - Buy Sonata 7016YM09 Wa...  No rating available
# 117    Anthill Baby Boy's, Baby Girl's Bodysuit - Buy...  No rating available
# 739    Buyer's Beach BB349 (Brown) Price: Rs. 449 Sty...  No rating available
# 882    Buy Mandhania Cotton Bath Towel at Rs. 280 at ...                    5
# ...                                                  ...                  ...
# 750    Buy Rajasthan Crafts Abstract Single Quilts & ...                    3
# 44     Key Features of AKUP i-loves-music Ceramic Mug...  No rating available
# 674    Buy Home Fashion Gallery Polyester Black Plain...  No rating available
# 910    Specifications of Beebay Baby Boy's Checkered ...  No rating available
# 172    Rockmantra Abstrcts 8 Ceramic Mug (5.5 l)\r\n ...  No rating available
#
#             overall_rating                 brand
# index
# 240    No rating available                Kosher  \
# 516    No rating available                  None
# 117    No rating available                  None
# 739    No rating available         Buyer's Beach
# 882                      5             Mandhania
# ...                    ...                   ...
# 750                      3      Rajasthan Crafts
# 44     No rating available                  AKUP
# 674    No rating available  Home Fashion Gallery
# 910    No rating available                Beebay
# 172    No rating available                  None
#
#                                   product_specifications         category0
# index
# 240    {"product_specification"=>[{"key"=>"Brand", "v...  kitchen & dining  \
# 516    {"product_specification"=>{"key"=>"Style Code"...           watches
# 117    {"product_specification"=>[{"key"=>"Age Group"...         baby care
# 739    {"product_specification"=>[{"key"=>"Brand", "v...  kitchen & dining
# 882    {"product_specification"=>[{"key"=>"Machine Wa...   home furnishing
# ...                                                  ...               ...
# 750    {"product_specification"=>[{"key"=>"Brand", "v...   home furnishing
# 44     {"product_specification"=>[{"key"=>"Type", "va...  kitchen & dining
# 674    {"product_specification"=>[{"key"=>"Reversible...   home furnishing
# 910    {"product_specification"=>[{"key"=>"Pattern", ...         baby care
# 172    {"product_specification"=>[{"key"=>"Type", "va...  kitchen & dining
#
#                           cleaned_product_name
# index
# 240                                     kadhai  \
# 516                               sonata watch
# 117             anthil babi babi girl bodysuit
# 739
# 882                          cotton bath towel
# ...                                        ...
# 750    abstract singl quilt comfort multicolor
# 44                                       ceram
# 674    polyest black plain eyelet door curtain
# 910                  babi checker casual shirt
# 172                   rockmantra abstrct ceram
#
#                                      cleaned_description
# index
# 240                                   kadhai kadhai best
# 516                sonata watch sonata watch india great
# 117    anthil babi babi girl bodysuit yellow anthil b...
# 739    brown stylish everi discern multicolor procur ...
# 882                                    cotton bath towel
# ...                                                  ...
# 750              abstract singl quilt comfort multicolor
# 44     ceram ceram ceram coffe give best love provid ...
# 674              polyest black plain eyelet door curtain
# 910    babi checker casual shirt pattern checker occa...
# 172    rockmantra abstrct ceram give thrill fresh sta...
#
# [787 rows x 18 columns]

# %%
def dataset_fct(path, validation_split=0, data_type=None) :
    dataset = tf.keras.utils.image_dataset_from_directory(
        path, labels='inferred', label_mode='categorical',
        class_names=None, batch_size=batch_size, image_size=(299,299), shuffle=True,
        validation_split=validation_split, subset=data_type, seed=42
    )
    return dataset

# %%
dataset_train = dataset_fct("../assets/train", validation_split=0.25, data_type='training')
dataset_val = dataset_fct("../assets/train", validation_split=0.25, data_type='validation')
dataset_test = dataset_fct("../assets/test", validation_split=0, data_type=None)
# Out:
# Found 787 files belonging to 7 classes.
# Using 591 files for training.
# Found 787 files belonging to 7 classes.
# Using 196 files for validation.
# Found 263 files belonging to 7 classes.
# 2023-06-01 16:32:43.802389: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-06-01 16:32:43.810310: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-06-01 16:32:43.810618: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-06-01 16:32:43.812000: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-06-01 16:32:43.812274: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-06-01 16:32:43.812518: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-06-01 16:32:44.397839: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-06-01 16:32:44.398038: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-06-01 16:32:44.398179: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-06-01 16:32:44.398291: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1635] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 3257 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1050 Ti, pci bus id: 0000:01:00.0, compute capability: 6.1

# %% [markdown]
# # Création du modèle

# %%
def create_model() :
    # Data augmentation : les fonctions de data augmentations ne sont actives que durant les fit
    data_augmentation = tf.keras.models.Sequential([
        tf.keras.layers.RandomFlip("horizontal", input_shape=(299, 299, 3)),
        tf.keras.layers.RandomRotation(0.1),
        tf.keras.layers.RandomZoom(0.1),
      ])
    
    # Récupération modèle pré-entraîné
    model_base = tf.keras.applications.inception_resnet_v2.InceptionResNetV2(include_top=False, weights="imagenet", input_shape=(299, 299, 3))
    for layer in model_base.layers:
        layer.trainable = False

    # Définition du nouveau modèle
    model = tf.keras.models.Sequential([
        data_augmentation,
        tf.keras.layers.Lambda(tf.keras.applications.inception_resnet_v2.preprocess_input, input_shape=(299, 299, 3)),
        tf.keras.layers.Rescaling(1./127.5, offset=-1),
        model_base,
        tf.keras.layers.GlobalAveragePooling2D(),
        tf.keras.layers.Dense(256, activation='relu'),
        tf.keras.layers.Dropout(0.5),
        tf.keras.layers.Dense(7, activation='softmax')
    ])

    # compilation du modèle 
    model.compile(loss="categorical_crossentropy", optimizer='adam', metrics=["accuracy"])

    return model

# %%
model = create_model()

# %%
model_save_path = "./model_best_weights_inceptionresnet.h5"
checkpoint_cb = tf.keras.callbacks.ModelCheckpoint(model_save_path, monitor="val_loss", verbose=1, save_best_only=True, mode="min")
earlystopping_cb = tf.keras.callbacks.EarlyStopping(monitor="val_loss", mode="min", verbose=1, patience=10)

# %% [markdown]
# # Entrainement

# %%
t0 = time.time()
history = model.fit(dataset_train,
          validation_data=dataset_val,
          batch_size=32, epochs=100, callbacks=[checkpoint_cb, earlystopping_cb], verbose=1)
print(f"Durée de l'entrainement: {time.time() - t0}")
# Out:
# Epoch 1/100
# 2023-06-01 16:32:50.601994: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_4' with dtype int32 and shape [591]
# 	 [[{{node Placeholder/_4}}]]
# 2023-06-01 16:32:50.602501: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype string and shape [591]
# 	 [[{{node Placeholder/_0}}]]
# 2023-06-01 16:32:59.801262: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:424] Loaded cuDNN version 8600
# 2023-06-01 16:33:05.568181: W tensorflow/tsl/framework/bfc_allocator.cc:296] Allocator (GPU_0_bfc) ran out of memory trying to allocate 3.50GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2023-06-01 16:33:07.058970: W tensorflow/tsl/framework/bfc_allocator.cc:296] Allocator (GPU_0_bfc) ran out of memory trying to allocate 7.03GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2023-06-01 16:33:07.067737: I tensorflow/compiler/xla/service/service.cc:169] XLA service 0x1efb1200 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2023-06-01 16:33:07.067760: I tensorflow/compiler/xla/service/service.cc:177]   StreamExecutor device (0): NVIDIA GeForce GTX 1050 Ti, Compute Capability 6.1
# 2023-06-01 16:33:07.072433: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2023-06-01 16:33:07.190542: I ./tensorflow/compiler/jit/device_compiler.h:180] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 18/19 [===========================>..] - ETA: 0s - loss: 2.0643 - accuracy: 0.1806
# 2023-06-01 16:33:21.477615: W tensorflow/tsl/framework/bfc_allocator.cc:296] Allocator (GPU_0_bfc) ran out of memory trying to allocate 3.45GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 19/19 [==============================] - ETA: 0s - loss: 2.0561 - accuracy: 0.1844
# 2023-06-01 16:33:22.360007: W tensorflow/tsl/framework/bfc_allocator.cc:296] Allocator (GPU_0_bfc) ran out of memory trying to allocate 6.95GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2023-06-01 16:33:22.394531: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype string and shape [196]
# 	 [[{{node Placeholder/_0}}]]
# 2023-06-01 16:33:22.394843: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype string and shape [196]
# 	 [[{{node Placeholder/_0}}]]
# Epoch 1: val_loss improved from inf to 1.96478, saving model to ./model_best_weights_inceptionresnet.h5
# 19/19 [==============================] - 42s 1s/step - loss: 2.0561 - accuracy: 0.1844 - val_loss: 1.9648 - val_accuracy: 0.2194
# Epoch 2/100
# 19/19 [==============================] - ETA: 0s - loss: 1.8813 - accuracy: 0.2657
# Epoch 2: val_loss improved from 1.96478 to 1.81949, saving model to ./model_best_weights_inceptionresnet.h5
# 19/19 [==============================] - 19s 973ms/step - loss: 1.8813 - accuracy: 0.2657 - val_loss: 1.8195 - val_accuracy: 0.3112
# Epoch 3/100
# 19/19 [==============================] - ETA: 0s - loss: 1.8182 - accuracy: 0.2775
# Epoch 3: val_loss improved from 1.81949 to 1.80816, saving model to ./model_best_weights_inceptionresnet.h5
# 19/19 [==============================] - 19s 972ms/step - loss: 1.8182 - accuracy: 0.2775 - val_loss: 1.8082 - val_accuracy: 0.2857
# Epoch 4/100
# 19/19 [==============================] - ETA: 0s - loss: 1.7565 - accuracy: 0.3012
# Epoch 4: val_loss improved from 1.80816 to 1.76357, saving model to ./model_best_weights_inceptionresnet.h5
# 19/19 [==============================] - 19s 974ms/step - loss: 1.7565 - accuracy: 0.3012 - val_loss: 1.7636 - val_accuracy: 0.3367
# Epoch 5/100
# 19/19 [==============================] - ETA: 0s - loss: 1.7208 - accuracy: 0.3503
# Epoch 5: val_loss improved from 1.76357 to 1.72481, saving model to ./model_best_weights_inceptionresnet.h5
# 19/19 [==============================] - 19s 980ms/step - loss: 1.7208 - accuracy: 0.3503 - val_loss: 1.7248 - val_accuracy: 0.3929
# Epoch 6/100
# 19/19 [==============================] - ETA: 0s - loss: 1.7199 - accuracy: 0.3080
# Epoch 6: val_loss did not improve from 1.72481
# 19/19 [==============================] - 18s 906ms/step - loss: 1.7199 - accuracy: 0.3080 - val_loss: 1.7296 - val_accuracy: 0.3367
# Epoch 7/100
# 19/19 [==============================] - ETA: 0s - loss: 1.6847 - accuracy: 0.3587
# Epoch 7: val_loss did not improve from 1.72481
# 19/19 [==============================] - 18s 905ms/step - loss: 1.6847 - accuracy: 0.3587 - val_loss: 1.7285 - val_accuracy: 0.3724
# Epoch 8/100
# 19/19 [==============================] - ETA: 0s - loss: 1.6667 - accuracy: 0.3638
# Epoch 8: val_loss improved from 1.72481 to 1.68151, saving model to ./model_best_weights_inceptionresnet.h5
# 19/19 [==============================] - 19s
# Epoch 80/100
# 19/19 [==============================] - ETA: 0s - loss: 1.1344 - accuracy: 0.5550
# Epoch 80: val_loss did not improve from 1.32476
# 19/19 [==============================] - 18s 905ms/step - loss: 1.1344 - accuracy: 0.5550 - val_loss: 1.3813 - val_accuracy: 0.5153
# Epoch 81/100
# 19/19 [==============================] - ETA: 0s - loss: 1.1864 - accuracy: 0.5567
# Epoch 81: val_loss did not improve from 1.32476
# 19/19 [==============================] - 18s 903ms/step - loss: 1.1864 - accuracy: 0.5567 - val_loss: 1.3829 - val_accuracy: 0.5102
# Epoch 82/100
# 19/19 [==============================] - ETA: 0s - loss: 1.1931 - accuracy: 0.5465
# Epoch 82: val_loss did not improve from 1.32476
# 19/19 [==============================] - 18s 901ms/step - loss: 1.1931 - accuracy: 0.5465 - val_loss: 1.3574 - val_accuracy: 0.5408
# Epoch 83/100
# 19/19 [==============================] - ETA: 0s - loss: 1.1906 - accuracy: 0.5228
# Epoch 83: val_loss did not improve from 1.32476
# 19/19 [==============================] - 18s 900ms/step - loss: 1.1906 - accuracy: 0.5228 - val_loss: 1.3488 - val_accuracy: 0.5408
# Epoch 84/100
# 19/19 [==============================] - ETA: 0s - loss: 1.1559 - accuracy: 0.5550
# Epoch 84: val_loss did not improve from 1.32476
# 19/19 [==============================] - 18s 905ms/step - loss: 1.1559 - accuracy: 0.5550 - val_loss: 1.3557 - val_accuracy: 0.5153
# Epoch 85/100
# 19/19 [==============================] - ETA: 0s - loss: 1.1823 - accuracy: 0.5550
# Epoch 85: val_loss did not improve from 1.32476
# 19/19 [==============================] - 18s 906ms/step - loss: 1.1823 - accuracy: 0.5550 - val_loss: 1.3627 - val_accuracy: 0.5255
# Epoch 86/100
# 19/19 [==============================] - ETA: 0s - loss: 1.1283 - accuracy: 0.5516
# Epoch 86: val_loss did not improve from 1.32476
# 19/19 [==============================] - 18s 904ms/step - loss: 1.1283 - accuracy: 0.5516 - val_loss: 1.3709 - val_accuracy: 0.5357
# Epoch 86: early stopping
# Durée de l'entrainement: 1594.8941164016724

# %% [markdown]
# # Evaluation

# %%
loss, accuracy = model.evaluate(dataset_train, verbose=True)
print("Training Accuracy   : {:.4f}".format(accuracy))
print()
loss, accuracy = model.evaluate(dataset_val, verbose=True)
print("Validation Accuracy :  {:.4f}".format(accuracy))
# Out:
# 19/19 [==============================] - 13s 627ms/step - loss: 1.0377 - accuracy: 0.6362
# Training Accuracy   : 0.6362
#
# 7/7 [==============================] - 5s 559ms/step - loss: 1.3709 - accuracy: 0.5357
# Validation Accuracy :  0.5357

# %%
# Score de l'epoch optimal

model.load_weights(model_save_path)

loss, accuracy = model.evaluate(dataset_val, verbose=False)
print("Validation Accuracy :  {:.4f}".format(accuracy))
print("Validation Loss     :  {:.4f}".format(loss))
# Out:
# Validation Accuracy :  0.5306
# Validation Loss     :  1.3248

# %%
show_history(history)
plot_history(history, path="standard.png")
plt.close()

# %% [markdown]
# Calculons sur l'ensemble de test

# %%
loss, accuracy = model.evaluate(dataset_test, verbose=False)
print("Test Accuracy       :  {:.4f}".format(accuracy))
print("Test Loss           :  {:.4f}".format(loss))
# Out:
# 2023-06-01 16:59:48.994898: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_4' with dtype int32 and shape [263]
# 	 [[{{node Placeholder/_4}}]]
# 2023-06-01 16:59:48.995267: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype string and shape [263]
# 	 [[{{node Placeholder/_0}}]]
# Test Accuracy       :  0.4715
# Test Loss           :  1.4476

# %% [markdown]
# # Conclusion

# %%
dataset_test.class_names
# Out:
# ['baby care',
#  'beauty and personal care',
#  'computers',
#  'home decor & festive needs',
#  'home furnishing',
#  'kitchen & dining',
#  'watches']

# %%
df_test.head()
# Out:
#                                 uniq_id            crawl_timestamp
# index
# 830    4354b7418ee0fab2fd9f8eb493556529  2015-12-29 05:07:38 +0000  \
# 883    7bbcbd91b8865a9f7b254760e5e2e10a  2015-12-20 08:26:17 +0000
# 789    389197b67a189c703f3deb9ca6f1f678  2015-12-12 11:46:53 +0000
# 820    00d84a518e0550612fcfcba3b02b6255  2015-12-12 11:46:53 +0000
# 115    8e8f5dc78f80eff3c77a9714303f59d2  2016-01-03 09:39:44 +0000
#
#                                              product_url
# index
# 830    http://www.flipkart.com/memore-portable-flexib...  \
# 883    http://www.flipkart.com/shagun-gold-tea-tree-e...
# 789    http://www.flipkart.com/love-baby-cartoon-set-...
# 820    http://www.flipkart.com/mxofere-combo-rose-soa...
# 115    http://www.flipkart.com/filink-310-black-toner...
#
#                                             product_name
# index
# 830    Memore Portable and Flexible MMULL-White USB L...  \
# 883     Shagun Gold Tea Tree Essential Aroma Therapy Oil
# 789                      Love Baby Cartoon Set of Towels
# 820    Mxofere Combo Rose Soap And Aloevera Lemon Fac...
# 115                               Filink 310 Black Toner
#
#                                    product_category_tree               pid
# index
# 830    ["Computers >> Laptop Accessories >> USB Gadge...  USGEE3GGGGYWM8ZZ  \
# 883    ["Baby Care >> Baby Grooming >> Baby Massage O...  MSOE7D95ZBVSDKSX
# 789    ["Baby Care >> Baby Bath & Skin >> Baby Bath T...  BTWDN9FZJWX4TBMZ
# 820    ["Beauty and Personal Care >> Combos and Kits ...  CBKEBVA8PUFUPRW4
# 115    ["Computers >> Computer Peripherals >> Printer...  INKDYGGGBYXZXYBZ
#
#        retail_price  discounted_price                                 image
# index
# 830           499.0             195.0  4354b7418ee0fab2fd9f8eb493556529.jpg  \
# 883           296.0             269.0  7bbcbd91b8865a9f7b254760e5e2e10a.jpg
# 789           638.0             425.0  389197b67a189c703f3deb9ca6f1f678.jpg
# 820           285.0             285.0  00d84a518e0550612fcfcba3b02b6255.jpg
# 115          6000.0            1390.0  8e8f5dc78f80eff3c77a9714303f59d2.jpg
#
#        is_FK_Advantage_product
# index
# 830                      False  \
# 883                      False
# 789                      False
# 820                      False
# 115                      False
#
#                                              description       product_rating
# index
# 830    Memore Portable and Flexible MMULL-White USB L...  No rating available  \
# 883    Shagun Gold Tea Tree Essential Aroma Therapy O...  No rating available
# 789    Buy Love Baby Cartoon Set of Towels at Rs. 425...                  4.3
# 820    Buy Mxofere Combo Rose Soap And Aloevera Lemon...  No rating available
# 115    Filink 310 Black Toner (Black)\r\n            ...  No rating available
#
#             overall_rating      brand
# index
# 830    No rating available     Memore  \
# 883    No rating available       None
# 789                    4.3  Love Baby
# 820    No rating available       None
# 115    No rating available     Filink
#
#                                   product_specifications
# index
# 830    {"product_specification"=>[{"key"=>"Lamp Adjus...  \
# 883    {"product_specification"=>[{"key"=>"Organic Ty...
# 789    {"product_specification"=>[{"key"=>"Material",...
# 820    {"product_specification"=>[{"key"=>"Organic Ty...
# 115    {"product_specification"=>[{"key"=>"Brand", "v...
#
#                       category0
# index
# 830                   computers  \
# 883                   baby care
# 789                   baby care
# 820    beauty and personal care
# 115                   computers
#
#                                  cleaned_product_name
# index
# 830                             portabl flexibl light  \
# 883            shagun gold tree essenti aroma therapi
# 789                                     cartoon towel
# 820    mxofer combo rose soap aloevera lemon facewash
# 115                                       black toner
#
#                                      cleaned_description
# index
# 830    portabl flexibl light white high read light we...
# 883    shagun gold tree essenti aroma therapi tree de...
# 789                                        cartoon towel
# 820    mxofer combo rose soap aloevera lemon facewash...
# 115    black toner black compat follow printer canon ...

# %%
my_image = tf.keras.preprocessing.image.load_img('../assets/test/computers/b1c7aa8e0f50e7ee73ed30d12af1a961.jpg', target_size=(299, 299))
my_image = tf.keras.preprocessing.image.img_to_array(my_image)
print(my_image.shape)
my_image = my_image.reshape((1, my_image.shape[0], my_image.shape[1], my_image.shape[2]))
prediction = model.predict(my_image)
# Out:
# (299, 299, 3)
# 1/1 [==============================] - 4s 4s/step

# %%
dataset_test.class_names[prediction.argmax(axis=-1)[0]]
# Out:
# 'computers'

# %%
df_comp = pd.DataFrame(columns=["uniq_id", "category", "predicted"])
for uniq_id, category in df_test.loc[:, ["uniq_id", "category0"]].values:
    my_image = tf.keras.preprocessing.image.load_img(f'../assets/test/{sanitize_filename(category)}/{uniq_id}.jpg', target_size=(299, 299))
    my_image = tf.keras.preprocessing.image.img_to_array(my_image)
    my_image = my_image.reshape((1, my_image.shape[0], my_image.shape[1], my_image.shape[2]))
    prediction = model.predict(my_image, verbose=0)
    predicted = dataset_test.class_names[prediction.argmax(axis=-1)[0]]
    df_comp = pd.concat([df_comp, pd.DataFrame({"uniq_id": uniq_id, "category": category, "predicted": predicted}, index=[0])]).reset_index(drop=True)

# %%
df_comp
# Out:
#                               uniq_id                    category
# 0    4354b7418ee0fab2fd9f8eb493556529                   computers  \
# 1    7bbcbd91b8865a9f7b254760e5e2e10a                   baby care
# 2    389197b67a189c703f3deb9ca6f1f678                   baby care
# 3    00d84a518e0550612fcfcba3b02b6255    beauty and personal care
# 4    8e8f5dc78f80eff3c77a9714303f59d2                   computers
# ..                                ...                         ...
# 258  f0938b0d88eac91deee6d5add54097d3  home decor & festive needs
# 259  90e56526f4c5892beac49f262b85150a                   baby care
# 260  f559fdabbcc1f4980f215f847bfdd589                     watches
# 261  a79117ea49a0533f641facdb4c99f502             home furnishing
# 262  6e6694c52c9273cde2163d34d5b44e94  home decor & festive needs
#
#                       predicted
# 0                     computers
# 1      beauty and personal care
# 2                       watches
# 3      beauty and personal care
# 4      beauty and personal care
# ..                          ...
# 258  home decor & festive needs
# 259                   computers
# 260                     watches
# 261             home furnishing
# 262                   computers
#
# [263 rows x 3 columns]

# %% [markdown]
# ## Matrice de confusion

# %%
conf_mat = confusion_matrix(df_comp["category"], df_comp["predicted"])
conf_mat
# Out:
# array([[12,  3,  5,  5,  9,  0,  4],
#        [ 8, 21,  0,  2,  0,  5,  1],
#        [ 3,  6, 19,  4,  2,  3,  1],
#        [ 8,  2,  3, 11,  1,  2, 10],
#        [14,  3,  3,  5, 11,  1,  0],
#        [ 6,  4,  2,  3,  1, 20,  2],
#        [ 4,  1,  0,  1,  1,  1, 30]])

# %%
df_cm = pd.DataFrame(conf_mat, index = dataset_test.class_names,
                  columns = dataset_test.class_names)

plt.figure(figsize = (6,4))
sns.heatmap(df_cm, annot=True, cmap="Blues")
# Out:
# <Axes: >

# %% [markdown]
# ## Score de classification

# %%
print(classification_report(df_comp["category"], df_comp["predicted"]))
# Out:
#                             precision    recall  f1-score   support
#
#                  baby care       0.22      0.32      0.26        38
#   beauty and personal care       0.53      0.57      0.55        37
#                  computers       0.59      0.50      0.54        38
# home decor & festive needs       0.35      0.30      0.32        37
#            home furnishing       0.44      0.30      0.35        37
#           kitchen & dining       0.62      0.53      0.57        38
#                    watches       0.62      0.79      0.70        38
#
#                   accuracy                           0.47       263
#                  macro avg       0.48      0.47      0.47       263
#               weighted avg       0.48      0.47      0.47       263

# %% [markdown]
# Nous avons ici un score F1 global de 73%.

# %% [markdown]
# ## Analyse des erreurs
#
# La catégorie de produits qui a donné le plus grand taux de faux négatifs est "Beauty and personal care". Visualisons les images correspondantes.

# %%
df_comp.loc[(df_comp["category"]=="beauty and personal care") & (df_comp["predicted"]!="beauty and personal care")]
# Out:
#                               uniq_id                  category
# 15   020d2daba55a723128e4e07c0b0393a9  beauty and personal care  \
# 23   afc829d45be38102afaa20f4bce2f627  beauty and personal care
# 27   b6c339777814451815fe7950fd4c8536  beauty and personal care
# 72   d61b368146f83075937e144dab93c6a1  beauty and personal care
# 109  6b5cdfe68595fbcab0e05dc625d3d66a  beauty and personal care
# 113  648b52926285610670a756923b8a6f99  beauty and personal care
# 138  7821fb1cbf8d3bb294c3c20527119f15  beauty and personal care
# 141  9613f2f1e65fb1fc7e181e7f83c217da  beauty and personal care
# 170  a11773bc4188f1c6226b941ec61c2024  beauty and personal care
# 216  23704dd51c975e845c574b044aae0a9f  beauty and personal care
# 221  ead122f4b1da293eb2d719baf104dfc9  beauty and personal care
# 225  911a6efe69bde398fbbddcb0b4bb466f  beauty and personal care
# 233  02a53d335775b652f22f41b529b9d646  beauty and personal care
# 245  17582ae953860b5320683768b8e97d3a  beauty and personal care
# 247  2d4f1232af970bd19881ceacad6ccfe3  beauty and personal care
# 249  4e09d5a71d46d61de3d4c9c5aedb73f2  beauty and personal care
#
#                       predicted
# 15   home decor & festive needs
# 23             kitchen & dining
# 27                    baby care
# 72                    baby care
# 109                   baby care
# 113                   baby care
# 138                   baby care
# 141                   baby care
# 170                     watches
# 216            kitchen & dining
# 221            kitchen & dining
# 225            kitchen & dining
# 233                   baby care
# 245  home decor & festive needs
# 247            kitchen & dining
# 249                   baby care

# %%
for uniq_id, category, predicted in df_comp.loc[(df_comp["category"]=="beauty and personal care") & (df_comp["predicted"]!="beauty and personal care"), ["uniq_id", "category", "predicted"]].values:
    print(f"""{uniq_id} : Prédit "{predicted}" au lieu de "{category}" """)
    img = plt.imread(f'assets/test/{sanitize_filename(category)}/{uniq_id}.jpg')
    imgplot = plt.imshow(img)
    plt.show()
# Out:
# 020d2daba55a723128e4e07c0b0393a9 : Prédit "home decor & festive needs" au lieu de "beauty and personal care"
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[29], line 3
#       1 for uniq_id, category, predicted in df_comp.loc[(df_comp["category"]=="beauty and personal care") & (df_comp["predicted"]!="beauty and personal care"), ["uniq_id", "category", "predicted"]].values:
#       2     print(f"""{uniq_id} : Prédit "{predicted}" au lieu de "{category}" """)
# ----> 3     img = plt.imread(f'assets/test/{sanitize_filename(category)}/{uniq_id}.jpg')
#       4     imgplot = plt.imshow(img)
#       5     plt.show()
#
# File ~/.local/lib/python3.8/site-packages/matplotlib/pyplot.py:2195, in imread(fname, format)
#    2193 @_copy_docstring_and_deprecators(matplotlib.image.imread)
#    2194 def imread(fname, format=None):
# -> 2195     return matplotlib.image.imread(fname, format)
#
# File ~/.local/lib/python3.8/site-packages/matplotlib/image.py:1563, in imread(fname, format)
#    1556 if isinstance(fname, str) and len(parse.urlparse(fname).scheme) > 1:
#    1557     # Pillow doesn't handle URLs directly.
#    1558     raise ValueError(
#    1559         "Please open the URL for reading and pass the "
#    1560         "result to Pillow, e.g. with "
#    1561         "``np.array(PIL.Image.open(urllib.request.urlopen(url)))``."
#    1562         )
# -> 1563 with img_open(fname) as image:
#    1564     return (_pil_png_to_float_array(image)
#    1565             if isinstance(image, PIL.PngImagePlugin.PngImageFile) else
#    1566             pil_to_array(image))
#
# File ~/.local/lib/python3.8/site-packages/PIL/Image.py:3236, in open(fp, mode, formats)
#    3233     filename = fp
#    3235 if filename:
# -> 3236     fp = builtins.open(filename, "rb")
#    3237     exclusive_fp = True
#    3239 try:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'assets/test/beauty and personal care/020d2daba55a723128e4e07c0b0393a9.jpg'

# %%
df.loc[df["uniq_id"]=="b6c339777814451815fe7950fd4c8536"]

# %% [markdown]
# Parmi les produits mal classifiés, on constate:
# - 9613f2f1e65fb1fc7e181e7f83c217da : la photo fait penser à un matelas
# - a11773bc4188f1c6226b941ec61c2024 : la photo fait penser à un tableau
# - 059493eeb88ebb4cc08d1522f3f87c3f : ressemblance avec un sac d'ordinateur portable

# %%
for uniq_id, category, predicted in df_comp.loc[(df_comp["category"]=="computers") & (df_comp["predicted"]!="computers"), ["uniq_id", "category", "predicted"]].values:
    print(f"""{uniq_id} : Prédit "{predicted}" au lieu de "{category}" """)
    img = plt.imread(f'assets/test/{sanitize_filename(category)}/{uniq_id}.jpg')
    imgplot = plt.imshow(img)
    plt.show()
