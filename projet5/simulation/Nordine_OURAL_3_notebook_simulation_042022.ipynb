# %%
import pandas as pd
import numpy as np
import os
import sys
import sqlite3
import datetime

from sklearn.metrics import adjusted_rand_score
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA

import plotly.io as pio
import plotly.express as px
import plotly.graph_objects as go
from plotly.subplots import make_subplots

import jupyter_black

jupyter_black.load()

module_path = os.path.abspath(os.path.join(".."))
if module_path not in sys.path:
    sys.path.append(module_path)

from lib.olist import get_olist_dataframe
from lib.clean import clean

from lib.graphUtils import (
    show_lines,
)

pio.renderers.default = "iframe"

working_dir = "working"
if not os.path.exists(working_dir):
    os.mkdir(working_dir)


db_file = f"{working_dir}/olist.sqlite3"
# Out:
#                 <script type="application/javascript" id="jupyter_black">
#                 (function() {
#                     if (window.IPython === undefined) {
#                         return
#                     }
#                     var msg = "WARNING: it looks like you might have loaded " +
#                         "jupyter_black in a non-lab notebook with " +
#                         "`is_lab=True`. Please double check, and if " +
#                         "loading with `%load_ext` please review the README!"
#                     console.log(msg)
#                     alert(msg)
#                 })()
#                 </script>

# %% [markdown]
# # Création du dataframe de référence

# %%
date_1_y = datetime.datetime.strptime("2017-09-30 23:59:59", "%Y-%m-%d %H:%M:%S")

# %% [markdown]
# ## Filtrage de la base de données

# %%
df = get_olist_dataframe(
    db_file=db_file, dir_path="../assets/olist", to_purchase_date=date_1_y
)

# %%
df.sort_values("last_timestamp")
# Out:
#                      customer_unique_id                     last_order_id  \
# 18878  b7d76e111c89f7ebf14761390f0f7d17  2e7a8482f6fb09756ca50c10d7bfc047
# 13534  830d5b7aaa3b6f1e9ad63703bec97d23  bfbd0f9bdef84302105ad712db648a6c
# 5273   32ea3bdedab835c3aa6cb68ce66565ef  3b697a20d9e427646d92567910af6d57
# 4912   2f64e403852e6893ae37485d5fcacdaf  be5bc2f0da14d8071e2d45451ad119d9
# 10188  61db744d2f835035a5625b59350c6b63  a41c8759fbe7aab36ea07e038b2d4465
# ...                                 ...                               ...
# 2661   19090a836e2392cd957ed43d61804ba3  90f3963bbaa0e66ce36c4f9be2ed2914
# 24841  f1e036dfac59643f7bdd306447f92402  349af77e71491a1aed28d6bf0528e09b
# 5550   3581031fd294025f4c16cd754bc4c90e  ed5495fbd35104360dbf954d7fece421
# 4622   2cb6e1938aa20ae2f3416b4c3f9f7847  b5c5a6fb605260058c01713e1fb97aba
# 19825  c0d1c485cc68748f953bedc0b453a5d4  f825ff64b7a15cd4f3483fb00b6ad59c
#
#       customer_state  customer_latitude  customer_longitude  nb_all_purchases  \
# 18878             RR           2.813808          -60.701637                 1
# 13534             SP         -20.585829          -47.863559                 1
# 5273              SP         -23.581469          -46.635030                 2
# 4912              RS         -28.294429          -53.502746                 1
# 10188             RS         -30.041351          -51.213096                 1
# ...              ...                ...                 ...               ...
# 2661              SP         -23.549429          -46.545728                 1
# 24841             PA          -1.460540          -48.483061                 1
# 5550              RJ         -22.886669          -43.279084                 1
# 4622              SP         -23.556070          -46.653327                 1
# 19825             MG         -22.434662          -45.451195                 1
#
#        average_amount       last_timestamp  last_nb_items  \
# 18878           72.89  2016-09-04 21:15:19              2
# 13534          134.97  2016-09-15 12:16:38              3
# 5273            63.95  2016-10-03 09:44:50              1
# 4912            21.90  2016-10-03 16:56:50              1
# 10188           36.49  2016-10-03 21:13:36              1
# ...               ...                  ...            ...
# 2661            39.00  2017-09-30 22:52:23              1
# 24841          109.90  2017-09-30 22:59:50              1
# 5550            69.90  2017-09-30 23:05:06              1
# 4622            59.90  2017-09-30 23:17:17              1
# 19825          109.00  2017-09-30 23:59:15              1
#
#                                          last_categories  ...  \
# 18878         furniture_decor:39.99,furniture_decor:32.9  ...
# 13534  health_beauty:44.99,health_beauty:44.99,health...  ...
# 5273                                  watches_gifts:29.9  ...
# 4912                                 sports_leisure:21.9  ...
# 10188                               sports_leisure:36.49  ...
# ...                                                  ...  ...
# 2661                                 sports_leisure:39.0  ...
# 24841                               sports_leisure:109.9  ...
# 5550                                           baby:69.9  ...
# 4622                                   garden_tools:59.9  ...
# 19825                              books_technical:109.0  ...
#
#        last_review_score                 all_purchases_timestamps  \
# 18878                1.0                      2016-09-04 21:15:19
# 13534                1.0                      2016-09-15 12:16:38
# 5273                 4.0  2017-09-27 08:20:09,2016-10-03 09:44:50
# 4912                 4.0                      2016-10-03 16:56:50
# 10188                3.0                      2016-10-03 21:13:36
# ...                  ...                                      ...
# 2661                 5.0                      2017-09-30 22:52:23
# 24841                5.0                      2017-09-30 22:59:50
# 5550                 5.0                      2017-09-30 23:05:06
# 4622                 5.0                      2017-09-30 23:17:17
# 19825                5.0                      2017-09-30 23:59:15
#
#                                 all_purchases_categories  \
# 18878         furniture_decor:39.99,furniture_decor:32.9
# 13534  health_beauty:44.99,health_beauty:44.99,health...
# 5273   stationery:25.99,watches_gifts:29.9,watches_gi...
# 4912                                 sports_leisure:21.9
# 10188                               sports_leisure:36.49
# ...                                                  ...
# 2661                                 sports_leisure:39.0
# 24841                               sports_leisure:109.9
# 5550                                           baby:69.9
# 4622                                   garden_tools:59.9
# 19825                              books_technical:109.0
#
#        all_purchases_amount  \
# 18878                 72.89
# 13534                134.97
# 5273                 104.89
# 4912                  21.90
# 10188                 36.49
# ...                     ...
# 2661                  39.00
# 24841                109.90
# 5550                  69.90
# 4622                  59.90
# 19825                109.00
#
#                                   all_purchases_payments  \
# 18878                                 credit_card:136.23
# 13534                                               None
# 5273   credit_card:34.92,boleto:45.46,credit_card:6.7...
# 4912                                        boleto:39.09
# 10188                                       boleto:53.73
# ...                                                  ...
# 2661                                   credit_card:50.73
# 24841                                       boleto:135.7
# 5550                                   credit_card:89.63
# 4622                                   credit_card:73.34
# 19825                                      boleto:125.39
#
#       all_purchases_review_score  all_expected_delivery_delay  \
# 18878                   1.000000                    45.114363
# 13534                   1.000000                    18.488449
# 5273                    4.666667                    19.623270
# 4912                    4.000000                    34.293866
# 10188                   3.000000                    56.115556
# ...                          ...                          ...
# 2661                    5.000000                    17.046956
# 24841                   5.000000                    39.041782
# 5550                    5.000000                    26.038125
# 4622                    5.000000                    23.029664
# 19825                   5.000000                    25.000521
#
#       all_effective_delivery_delay all_freight_value  all_photos_quantity
# 18878                          NaN             63.34                  5.0
# 13534                    54.813194              8.49                  3.0
# 5273                     15.299138             15.56                  3.5
# 4912                     24.057500             17.19                  1.0
# 10188                    30.572581             17.24                  1.0
# ...                            ...               ...                  ...
# 2661                      2.722234             11.73                  1.0
# 24841                    22.796782             25.80                  8.0
# 5550                     17.972407             19.73                  3.0
# 4622                      8.750602             13.44                  2.0
# 19825                    12.700706             16.39                  1.0
#
# [26301 rows x 26 columns]

# %% [markdown]
# ## Nettoyage du dataframe

# %%
r = clean(
    df,
    use_features=[
        "review",
        "weekday",
        "categories",
        "delivery",
        "customer_location",
        "payment_types",
        "photos_quantity_customer",
        "freight_value",
        "customer_unique_id",
    ],
)
df = r["data"]
scaler = r["scaler"]
pipe = r["pipe"]
# Out:
# featureSplitterTransformer, from_column=last_categories
# featureSplitterTransformer, from_column=all_purchases_categories
# featureSplitterTransformer, from_column=last_payments
# featureSplitterTransformer, from_column=all_purchases_payments
# last_categories
# all_purchases_categories
# last_payments
# all_purchases_payments

# %%
df
# Out:
#        customer_latitude  customer_longitude    f         m  \
# 0               0.131649            0.451567  0.0  0.004964
# 1               0.241766            0.575165  0.0  0.009876
# 2               0.270467            0.610770  0.0  0.000864
# 3               0.078575            0.395345  0.0  0.005559
# 4               0.217710            0.495528  0.0  0.002434
# ...                  ...                 ...  ...       ...
# 26296           0.383170            0.468312  0.0  0.006148
# 26297           0.217652            0.495443  0.0  0.002799
# 26298           0.542440            0.715874  0.0  0.116665
# 26299           0.468078            0.301095  0.0  0.006520
# 26300           0.176568            0.433889  0.0  0.004071
#
#        all_purchases_review_score  all_freight_value  all_cats_home_office  \
# 0                           0.500           0.009074              0.010245
# 1                           0.750           0.007967              0.000000
# 2                           0.500           0.007957              0.002064
# 3                           0.750           0.007530              0.000000
# 4                           0.875           0.006244              0.000000
# ...                           ...                ...                   ...
# 26296                       1.000           0.009401              0.000000
# 26297                       0.750           0.007957              0.000000
# 26298                       1.000           0.262109              0.000000
# 26299                       1.000           0.011888              0.000000
# 26300                       1.000           0.007677              0.000000
#
#        all_cats_clothes  all_cats_health_beauty  all_cats_electronics  ...  \
# 0              0.000000                0.000000              0.000000  ...
# 1              0.039029                0.000000              0.000000  ...
# 2              0.000000                0.000000              0.000000  ...
# 3              0.000000                0.032082              0.000000  ...
# 4              0.010119                0.000000              0.000000  ...
# ...                 ...                     ...                   ...  ...
# 26296          0.024545                0.000000              0.000000  ...
# 26297          0.000000                0.000000              0.002969  ...
# 26298          0.000000                0.654221              0.000000  ...
# 26299          0.000000                0.000000              0.000000  ...
# 26300          0.000000                0.023748              0.000000  ...
#
#        all_cats_food_drink  all_cats_construction  all_payments_credit_card  \
# 0                      0.0                    0.0                  0.006310
# 1                      0.0                    0.0                  0.010986
# 2                      0.0                    0.0                  0.002122
# 3                      0.0                    0.0                  0.006680
# 4                      0.0                    0.0                  0.003429
# ...                    ...                    ...                       ...
# 26296                  0.0                    0.0                  0.007519
# 26297                  0.0                    0.0                  0.000000
# 26298                  0.0                    0.0                  0.151303
# 26299                  0.0                    0.0                  0.008230
# 26300                  0.0                    0.0                  0.005237
#
#        all_payments_cash  all_payments_voucher  all_payments_debit_card  \
# 0               0.000000                   0.0                      0.0
# 1               0.000000                   0.0                      0.0
# 2               0.000000                   0.0                      0.0
# 3               0.000000                   0.0                      0.0
# 4               0.000000                   0.0                      0.0
# ...                  ...                   ...                      ...
# 26296           0.000000                   0.0                      0.0
# 26297           0.008176                   0.0                      0.0
# 26298           0.000000                   0.0                      0.0
# 26299           0.000000                   0.0                      0.0
# 26300           0.000000                   0.0                      0.0
#
#        most_purchased_weekday  all_delivery_delay         r  \
# 0                    0.666667            0.429922  0.521739
# 1                    0.833333            0.348136  0.537084
# 2                    0.166667            0.399298  0.189258
# 3                    0.666667            0.390245  0.127877
# 4                    0.666667            0.395550  0.002558
# ...                       ...                 ...       ...
# 26296                0.666667            0.414725  0.127877
# 26297                0.666667            0.415157  0.074169
# 26298                0.500000            0.351357  0.291560
# 26299                0.166667            0.342450  0.601023
# 26300                0.166667            0.385649  0.386189
#
#                      customer_unique_id
# 0      0000f46a3911fa3c0805444483337064
# 1      0005e1862207bf6ccc02e4228effd9a0
# 2      0006fdc98a402fceb4eb0ee528f6a8d4
# 3      000a5ad9c4601d2bbdd9ed765d5213b3
# 4      000bfa1d2f1a41876493be685390d6d3
# ...                                 ...
# 26296  fff3a9369e4b7102fab406a334a678c3
# 26297  fff699c184bcc967d62fa2c6171765f7
# 26298  fffcf5a5ff07b0908bd4e2dbc735a684
# 26299  ffff371b4d645b6ecea244b27531430a
# 26300  ffffd2657e2aad2907e67c3e9daecbeb
#
# [26301 rows x 23 columns]

# %%
num_cols = df.select_dtypes(include=[np.number]).columns

# %%
num_cols
# Out:
# Index(['customer_latitude', 'customer_longitude', 'f', 'm',
#        'all_purchases_review_score', 'all_freight_value',
#        'all_cats_home_office', 'all_cats_clothes', 'all_cats_health_beauty',
#        'all_cats_electronics', 'all_cats_culture_leisure',
#        'all_cats_cool_stuff', 'all_cats_other', 'all_cats_food_drink',
#        'all_cats_construction', 'all_payments_credit_card',
#        'all_payments_cash', 'all_payments_voucher', 'all_payments_debit_card',
#        'most_purchased_weekday', 'all_delivery_delay', 'r'],
#       dtype='object')

# %% [markdown]
# ## Décomposition PCA

# %%
n_components = 6
pca = PCA(n_components=n_components)

pca.fit(df.loc[:, num_cols])
pca.explained_variance_ratio_
# Out:
# array([0.39162227, 0.35537652, 0.13398936, 0.06753305, 0.0217489 ,
#        0.00535521])

# %%
X_pca = pd.DataFrame(
    pca.transform(df.loc[:, num_cols]),
    columns=["pca1", "pca2", "pca3", "pca4", "pca5", "pca6"],
)

# %%
X_pca
# Out:
#            pca1      pca2      pca3      pca4      pca5      pca6
# 0      0.199705  0.309938  0.220999 -0.156771 -0.015100 -0.011577
# 1      0.374902  0.068771  0.250523  0.003052 -0.074466 -0.005350
# 2     -0.299111  0.284474 -0.108794  0.042658 -0.091614 -0.010138
# 3      0.205564  0.038887 -0.157596 -0.223125  0.014421 -0.000620
# 4      0.210012 -0.087752 -0.277746 -0.051665 -0.011937 -0.009443
# ...         ...       ...       ...       ...       ...       ...
# 26296  0.214525 -0.203323 -0.147325  0.086579  0.084895 -0.010060
# 26297  0.206542  0.040729 -0.213208 -0.054861 -0.012382 -0.010852
# 26298  0.051149 -0.193313  0.019275  0.357363 -0.058431  0.204976
# 26299 -0.284210 -0.195653  0.331351  0.092626  0.269468 -0.011206
# 26300 -0.285934 -0.209503  0.113805 -0.108145  0.020249 -0.003977
#
# [26301 rows x 6 columns]

# %% [markdown]
# ## Clustering par KMeans

# %%
km = KMeans(init="k-means++", random_state=0, n_init="auto", n_clusters=5)
km.fit(X_pca)
# Out:
# KMeans(n_clusters=5, n_init='auto', random_state=0)

# %%
set(km.labels_)
# Out:
# {0, 1, 2, 3, 4}

# %%
df_y_1 = pd.DataFrame(
    {"customer_unique_id": df["customer_unique_id"], "cluster": km.labels_}
)

# %%
df_y_1
# Out:
#                      customer_unique_id  cluster
# 0      0000f46a3911fa3c0805444483337064        2
# 1      0005e1862207bf6ccc02e4228effd9a0        0
# 2      0006fdc98a402fceb4eb0ee528f6a8d4        3
# 3      000a5ad9c4601d2bbdd9ed765d5213b3        0
# 4      000bfa1d2f1a41876493be685390d6d3        0
# ...                                 ...      ...
# 26296  fff3a9369e4b7102fab406a334a678c3        0
# 26297  fff699c184bcc967d62fa2c6171765f7        0
# 26298  fffcf5a5ff07b0908bd4e2dbc735a684        1
# 26299  ffff371b4d645b6ecea244b27531430a        4
# 26300  ffffd2657e2aad2907e67c3e9daecbeb        4
#
# [26301 rows x 2 columns]

# %%
week_ari_scores = []
week_ari_scores.append(1)

# %% [markdown]
# # Comparaison itérative

# %%
for w in range(1, 30):
    date_m2 = date_1_y + datetime.timedelta(days=7 * w)
    df_m2 = get_olist_dataframe(
        db_file=db_file,
        dir_path="../assets/olist",
        to_purchase_date=date_m2,
    )
    r = clean(
        df_m2,
        use_features=[
            "review",
            "weekday",
            "categories",
            "delivery",
            "customer_location",
            "payment_types",
            "photos_quantity_customer",
            "freight_value",
            "customer_unique_id",
        ],
    )
    df_m2 = r["data"]

    customers_unique_ids_y_1_m2 = df_m2.loc[
        df_m2["customer_unique_id"].isin(df_y_1["customer_unique_id"])
    ]["customer_unique_id"]

    pca_m2 = PCA(n_components=n_components)
    pca_m2.fit(df_m2.loc[:, num_cols])
    pca_m2.explained_variance_ratio_

    X_pca_m2 = pd.DataFrame(
        pca_m2.transform(df_m2.loc[:, num_cols]),
        columns=["pca1", "pca2", "pca3", "pca4", "pca5", "pca6"],
    )
    df_m2 = pd.DataFrame(
        {
            "customer_unique_id": df_m2["customer_unique_id"],
            "cluster": km.predict(X_pca_m2),
        }
    )

    ari_score = adjusted_rand_score(
        df_m2.loc[
            df_m2["customer_unique_id"].isin(customers_unique_ids_y_1_m2)
        ].sort_values("customer_unique_id")["cluster"],
        df_y_1.loc[
            df_y_1["customer_unique_id"].isin(customers_unique_ids_y_1_m2)
        ].sort_values("customer_unique_id")["cluster"],
    )
    print(f"w={w}, ari score={ari_score}")
    week_ari_scores.append(ari_score)
# Out:
# featureSplitterTransformer, from_column=last_categories
# featureSplitterTransformer, from_column=all_purchases_categories
# featureSplitterTransformer, from_column=last_payments
# featureSplitterTransformer, from_column=all_purchases_payments
# last_categories
# all_purchases_categories
# last_payments
# all_purchases_payments
# w=1, ari score=0.9990100317659075
# featureSplitterTransformer, from_column=last_categories
# featureSplitterTransformer, from_column=all_purchases_categories
# featureSplitterTransformer, from_column=last_payments
# featureSplitterTransformer, from_column=all_purchases_payments
# last_categories
# all_purchases_categories
# last_payments
# all_purchases_payments
# w=2, ari score=0.9987862258883178
# featureSplitterTransformer, from_column=last_categories
# featureSplitterTransformer, from_column=all_purchases_categories
# featureSplitterTransformer, from_column=last_payments
# featureSplitterTransformer, from_column=all_purchases_payments
# last_categories
# all_purchases_categories
# last_payments
# all_purchases_payments
# w=3, ari score=0.9976601529050461
# featureSplitterTransformer, from_column=last_categories
# featureSplitterTransformer, from_column=all_purchases_categories
# featureSplitterTransformer, from_column=last_payments
# featureSplitterTransformer, from_column=all_purchases_payments
# last_categories
# all_purchases_categories
# last_payments
# all_purchases_payments
# w=4, ari score=0.9926910841599182
# featureSplitterTransformer, from_column=last_categories
# featureSplitterTransformer, from_column=all_purchases_categories
# featureSplitterTransformer, from_column=last_payments
# featureSplitterTransformer, from_column=all_purchases_payments
# last_categories
# all_purchases_categories
# last_payments
# all_purchases_payments
# w=5, ari score=0.9911002346725954
# featureSplitterTransformer, from_column=last_categories
# featureSplitterTransformer, from_column=all_purchases_categories
# featureSplitterTransformer, from_column=last_payments
# featureSplitterTransformer, from_column=all_purchases_payments
# last_categories
# all_purchases_categories
# last_payments
# all_purchases_payments
# w=6, ari score=0.993853684793964
# featureSplitterTransformer, from_column=last_categories
# featureSplitterTransformer, from_column=all_purchases_categories
# featureSplitterTransformer, from_column=last_payments
# featureSplitterTransformer, from_column=all_purchases_payments
# last_categories
# all_purchases_categories
# last_payments
# all_purchases_payments
# w=7, ari score=0.9954719079448778
# featureSplitterTransformer, from_column=last_categories
# featureSplitterTransformer, from_column=all_purchases_categories
# featureSplitterTransformer, from_column=last_payments
# featureSplitterTransformer, from_column=all_purchases_payments
# last_categories
# all_purchases_categories
# last_payments
# all_purchases_payments
# w=8, ari score=0.7614424639061915
# featureSplitterTransformer, from_column=last_categories
# featureSplitterTransformer, from_column=all_purchases_categories
# featureSplitterTransformer, from_column=last_payments
# featureSplitterTransformer, from_column=all_purchases_payments
# last_categories
# all_purchases_categories
# last_payments
# all_purchases_payments
# w=9, ari score=0.7414539889678889
# featureSplitterTransformer, from_column=last_categories
# featureSplitterTransformer, from_column=all_purchases_categories
# featureSplitterTransformer, from_column=last_payments
# featureSplitterTransformer, from_column=all_purchases_payments
# last_categories
# all_purchases_categories
# last_payments
# all_purchases_payments
# w=10, ari score=0.7307739156582891
# featureSplitterTransformer, from_column=last_categories
# featureSplitterTransformer, from_column=all_purchases_categories
# featureSplitterTransformer, from_column=last_payments
# featureSplitterTransformer, from_column=all_purchases_payments
# last_categories
# all_purchases_categories
# last_payments
# all_purchases_payments
# w=11, ari score=0.7371860564879044
# featureSplitterTransformer, from_column=last_categories
# featureSplitterTransformer, from_column=all_purchases_categories
# featureSplitterTransformer, from_column=last_payments
# featureSplitterTransformer, from_column=all_purchases_payments
# last_categories
# all_purchases_categories
# last_payments
# all_purchases_payments
# w=12, ari score=0.7348929919396155
# featureSplitterTransformer, from_column=last_categories
# featureSplitterTransformer, from_column=all_purchases_categories
# featureSplitterTransformer, from_column=last_payments
# featureSplitterTransformer, from_column=all_purchases_payments
# last_categories
# all_purchases_categories
# last_payments
# all_purchases_payments
# w=13, ari score=0.7321984802480047
# featureSplitterTransformer, from_column=last_categories
# featureSplitterTransformer, from_column=all_purchases_categories
# featureSplitterTransformer, from_column=last_payments
# featureSplitterTransformer, from_column=all_purchases_payments
# last_categories
# all_purchases_categories
# last_payments
# all_purchases_payments
# w=14, ari score=0.5950866030247
# featureSplitterTransformer, from_column=last_categories
# featureSplitterTransformer, from_column=all_purchases_categories
# featureSplitterTransformer, from_column=last_payments
# featureSplitterTransformer, from_column=all_purchases_payments
# last_categories
# all_purchases_categories
# last_payments
# all_purchases_payments
# w=15, ari score=0.6197797800566726
# featureSplitterTransformer, from_column=last_categories
# featureSplitterTransformer, from_column=all_purchases_categories
# featureSplitterTransformer, from_column=last_payments
# featureSplitterTransformer, from_column=all_purchases_payments
# last_categories
# all_purchases_categories
# last_payments
# all_purchases_payments
# w=16, ari score=0.5840050233585126
# featureSplitterTransformer, from_column=last_categories
# featureSplitterTransformer, from_column=all_purchases_categories
# featureSplitterTransformer, from_column=last_payments
# featureSplitterTransformer, from_column=all_purchases_payments
# last_categories
# all_purchases_categories
# last_payments
# all_purchases_payments
# w=17, ari score=0.5299104580625004
# featureSplitterTransformer, from_column=last_categories
# featureSplitterTransformer, from_column=all_purchases_categories
# featureSplitterTransformer, from_column=last_payments
# featureSplitterTransformer, from_column=all_purchases_payments
# last_categories
# all_purchases_categories
# last_payments
# all_purchases_payments
# w=18, ari score=0.5448072183435333
# featureSplitterTransformer, from_column=last_categories
# featureSplitterTransformer, from_column=all_purchases_categories
# featureSplitterTransformer, from_column=last_payments
# featureSplitterTransformer, from_column=all_purchases_payments
# last_categories
# all_purchases_categories
# last_payments
# all_purchases_payments
# w=19, ari score=0.5434660373779232
# featureSplitterTransformer, from_column=last_categories
# featureSplitterTransformer, from_column=all_purchases_categories
# featureSplitterTransformer, from_column=last_payments
# featureSplitterTransformer, from_column=all_purchases_payments
# last_categories
# all_purchases_categories
# last_payments
# all_purchases_payments
# w=20, ari score=0.47367599181266745
# featureSplitterTransformer, from_column=last_categories
# featureSplitterTransformer, from_column=all_purchases_categories
# featureSplitterTransformer, from_column=last_payments
# featureSplitterTransformer, from_column=all_purchases_payments
# last_categories
# all_purchases_categories
# last_payments
# all_purchases_payments
# w=21, ari score=0.7780561945591771
# featureSplitterTransformer, from_column=last_categories
# featureSplitterTransformer, from_column=all_purchases_categories
# featureSplitterTransformer, from_column=last_payments
# featureSplitterTransformer, from_column=all_purchases_payments
# last_categories
# all_purchases_categories
# last_payments
# all_purchases_payments
# w=22, ari score=0.47732742822149005
# featureSplitterTransformer, from_column=last_categories
# featureSplitterTransformer, from_column=all_purchases_categories
# featureSplitterTransformer, from_column=last_payments
# featureSplitterTransformer, from_column=all_purchases_payments
# last_categories
# all_purchases_categories
# last_payments
# all_purchases_payments
# w=23, ari score=0.47774744779679973
# featureSplitterTransformer, from_column=last_categories
# featureSplitterTransformer, from_column=all_purchases_categories
# featureSplitterTransformer, from_column=last_payments
# featureSplitterTransformer, from_column=all_purchases_payments
# last_categories
# all_purchases_categories
# last_payments
# all_purchases_payments
# w=24, ari score=0.47772812395128333
# featureSplitterTransformer, from_column=last_categories
# featureSplitterTransformer, from_column=all_purchases_categories
# featureSplitterTransformer, from_column=last_payments
# featureSplitterTransformer, from_column=all_purchases_payments
# last_categories
# all_purchases_categories
# last_payments
# all_purchases_payments
# w=25, ari score=0.4776129136415101
# featureSplitterTransformer, from_column=last_categories
# featureSplitterTransformer, from_column=all_purchases_categories
# featureSplitterTransformer, from_column=last_payments
# featureSplitterTransformer, from_column=all_purchases_payments
# last_categories
# all_purchases_categories
# last_payments
# all_purchases_payments
# w=26, ari score=0.47790610331182387
# featureSplitterTransformer, from_column=last_categories
# featureSplitterTransformer, from_column=all_purchases_categories
# featureSplitterTransformer, from_column=last_payments
# featureSplitterTransformer, from_column=all_purchases_payments
# last_categories
# all_purchases_categories
# last_payments
# all_purchases_payments
# w=27, ari score=0.4776840280325966
# featureSplitterTransformer, from_column=last_categories
# featureSplitterTransformer, from_column=all_purchases_categories
# featureSplitterTransformer, from_column=last_payments
# featureSplitterTransformer, from_column=all_purchases_payments
# last_categories
# all_purchases_categories
# last_payments
# all_purchases_payments
# w=28, ari score=0.4771628956647741
# featureSplitterTransformer, from_column=last_categories
# featureSplitterTransformer, from_column=all_purchases_categories
# featureSplitterTransformer, from_column=last_payments
# featureSplitterTransformer, from_column=all_purchases_payments
# last_categories
# all_purchases_categories
# last_payments
# all_purchases_payments
# w=29, ari score=0.47665031507980804

# %% [markdown]
# # Conclusion

# %%
show_lines(
    list(range(0, len(week_ari_scores))),
    {"ari": week_ari_scores},
    title="Evolution score ARI par semaine",
    h=700,
)
# Out:
# <iframe
#     scrolling="no"
#     width="100%"
#     height="720"
#     src="iframe_figures/figure_21.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %% [markdown]
# Le modèles est valable 7 semaines
